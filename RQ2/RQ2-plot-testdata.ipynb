# %%
import numpy as np
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from scipy.stats import kendalltau
import statistics 
import torch
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
def readfile(filepath):
    data = np.load(filepath)
    return data

# %%
codebert4vdcwe_small = 'codebert4vdcwe-small/'
codebert4vdcwe_base = 'codebert4vdcwe-base/'
codegen4vdcwe_small = 'codegen4vdcwe-small/'
codegen4vdcwe_base = 'codegen4vdcwe-base/'
codet54vdcwe_small = 'codet54vdcwe-small/'
codet54vdcwe_base = 'codet54vdcwe-base/'
codet54vdcwe_large = 'codet54vdcwe-large/'
polycoder4vdcwe_small = 'polycoder4vdcwe-small/'
polycoder4vdcwe_base = 'polycoder4vdcwe-base/'
polycoder4vdcwe_large = 'polycoder4vdcwe-large/'

trained_codexglue_path = 'CLS/trained_codexglue/CLS/'
trained_reveal_path = 'CLS/trained_reveal/CLS/'
trained_cwe119_path = 'CLS/trained_cwe119/CLS/'
trained_cwe399_path = 'CLS/trained_cwe399/CLS/'

# %%
codebert4vdcwe_small_codexglue = readfile(codebert4vdcwe_small+trained_codexglue_path+'codexglue_test-data.npy')
codebert4vdcwe_base_codexglue = readfile(codebert4vdcwe_base+trained_codexglue_path+'codexglue_test-data.npy')
codegen4vdcwe_small_codexglue = readfile(codegen4vdcwe_small+trained_codexglue_path+'codexglue_test-data.npy')
codegen4vdcwe_base_codexglue = readfile(codegen4vdcwe_base+trained_codexglue_path+'codexglue_test-data.npy')
codet54vdcwe_small_codexglue = readfile(codet54vdcwe_small+trained_codexglue_path+'codexglue_test-data.npy')
codet54vdcwe_base_codexglue = readfile(codet54vdcwe_base+trained_codexglue_path+'codexglue_test-data.npy')
codet54vdcwe_large_codexglue = readfile(codet54vdcwe_large+trained_codexglue_path+'codexglue_test-data.npy')
polycoder4vdcwe_small_codexglue = readfile(polycoder4vdcwe_small+trained_codexglue_path+'codexglue_test-data.npy')
polycoder4vdcwe_base_codexglue = readfile(polycoder4vdcwe_base+trained_codexglue_path+'codexglue_test-data.npy')
polycoder4vdcwe_large_codexglue = readfile(polycoder4vdcwe_large+trained_codexglue_path+'codexglue_test-data.npy')

codebert4vdcwe_small_reveal = readfile(codebert4vdcwe_small+trained_reveal_path+'reveal_test-data.npy')
codebert4vdcwe_base_reveal = readfile(codebert4vdcwe_base+trained_reveal_path+'reveal_test-data.npy')
codegen4vdcwe_small_reveal = readfile(codegen4vdcwe_small+trained_reveal_path+'reveal_test-data.npy')
codegen4vdcwe_base_reveal = readfile(codegen4vdcwe_base+trained_reveal_path+'reveal_test-data.npy')
codet54vdcwe_small_reveal = readfile(codet54vdcwe_small+trained_reveal_path+'reveal_test-data.npy')
codet54vdcwe_base_reveal = readfile(codet54vdcwe_base+trained_reveal_path+'reveal_test-data.npy')
codet54vdcwe_large_reveal = readfile(codet54vdcwe_large+trained_reveal_path+'reveal_test-data.npy')
polycoder4vdcwe_small_reveal = readfile(polycoder4vdcwe_small+trained_reveal_path+'reveal_test-data.npy')
polycoder4vdcwe_base_reveal = readfile(polycoder4vdcwe_base+trained_reveal_path+'reveal_test-data.npy')
polycoder4vdcwe_large_reveal = readfile(polycoder4vdcwe_large+trained_reveal_path+'reveal_test-data.npy')

codebert4vdcwe_small_cwe119 = readfile(codebert4vdcwe_small+trained_cwe119_path+'cwe119_test-data.npy')
codebert4vdcwe_base_cwe119 = readfile(codebert4vdcwe_base+trained_cwe119_path+'cwe119_test-data.npy')
codegen4vdcwe_small_cwe119 = readfile(codegen4vdcwe_small+trained_cwe119_path+'cwe119_test-data.npy')
codegen4vdcwe_base_cwe119 = readfile(codegen4vdcwe_base+trained_cwe119_path+'cwe119_test-data.npy')
codet54vdcwe_small_cwe119 = readfile(codet54vdcwe_small+trained_cwe119_path+'cwe119_test-data.npy')
codet54vdcwe_base_cwe119 = readfile(codet54vdcwe_base+trained_cwe119_path+'cwe119_test-data.npy')
codet54vdcwe_large_cwe119 = readfile(codet54vdcwe_large+trained_cwe119_path+'cwe119_test-data.npy')
polycoder4vdcwe_small_cwe119 = readfile(polycoder4vdcwe_small+trained_cwe119_path+'cwe119_test-data.npy')
polycoder4vdcwe_base_cwe119 = readfile(polycoder4vdcwe_base+trained_cwe119_path+'cwe119_test-data.npy')
polycoder4vdcwe_large_cwe119 = readfile(polycoder4vdcwe_large+trained_cwe119_path+'cwe119_test-data.npy')


codebert4vdcwe_small_cwe399 = readfile(codebert4vdcwe_small+trained_cwe399_path+'cwe399_test-data.npy')
codebert4vdcwe_base_cwe399 = readfile(codebert4vdcwe_base+trained_cwe399_path+'cwe399_test-data.npy')
codegen4vdcwe_small_cwe399 = readfile(codegen4vdcwe_small+trained_cwe399_path+'cwe399_test-data.npy')
codegen4vdcwe_base_cwe399 = readfile(codegen4vdcwe_base+trained_cwe399_path+'cwe399_test-data.npy')
codet54vdcwe_small_cwe399 = readfile(codet54vdcwe_small+trained_cwe399_path+'cwe399_test-data.npy')
codet54vdcwe_base_cwe399 = readfile(codet54vdcwe_base+trained_cwe399_path+'cwe399_test-data.npy')
codet54vdcwe_large_cwe399 = readfile(codet54vdcwe_large+trained_cwe399_path+'cwe399_test-data.npy')
polycoder4vdcwe_small_cwe399 = readfile(polycoder4vdcwe_small+trained_cwe399_path+'cwe399_test-data.npy')
polycoder4vdcwe_base_cwe399 = readfile(polycoder4vdcwe_base+trained_cwe399_path+'cwe399_test-data.npy')
polycoder4vdcwe_large_cwe399 = readfile(polycoder4vdcwe_large+trained_cwe399_path+'cwe399_test-data.npy')



print(np.shape(codebert4vdcwe_small_cwe399))
print(np.shape(codebert4vdcwe_base_cwe399))
print(np.shape(codegen4vdcwe_small_cwe399))
print(np.shape(codegen4vdcwe_base_cwe399))
print(np.shape(codet54vdcwe_small_cwe399))
print(np.shape(codet54vdcwe_base_cwe399))
print(np.shape(codet54vdcwe_large_cwe399))
print(np.shape(polycoder4vdcwe_small_cwe399))
print(np.shape(polycoder4vdcwe_base_cwe399))
print(np.shape(polycoder4vdcwe_large_cwe399))

# %%
import matplotlib.pyplot as plt
import numpy as np

data00 = codebert4vdcwe_small_codexglue.flatten()
data01 = codebert4vdcwe_base_codexglue.flatten()
data02 = codegen4vdcwe_small_codexglue.flatten()
data03 = codegen4vdcwe_base_codexglue.flatten()
data04 = codet54vdcwe_small_codexglue.flatten()
data05 = codet54vdcwe_base_codexglue.flatten()
data06 = codet54vdcwe_large_codexglue.flatten()
data07 = polycoder4vdcwe_small_codexglue.flatten()
data08 = polycoder4vdcwe_base_codexglue.flatten()
data09 = polycoder4vdcwe_large_codexglue.flatten()

data10 = codebert4vdcwe_small_reveal.flatten()
data11 = codebert4vdcwe_base_reveal.flatten()
data12 = codegen4vdcwe_small_reveal.flatten()
data13 = codegen4vdcwe_base_reveal.flatten()
data14 = codet54vdcwe_small_reveal.flatten()
data15 = codet54vdcwe_base_reveal.flatten()
data16 = codet54vdcwe_large_reveal.flatten()
data17 = polycoder4vdcwe_small_reveal.flatten()
data18 = polycoder4vdcwe_base_reveal.flatten()
data19 = polycoder4vdcwe_large_reveal.flatten()

data20 = codebert4vdcwe_small_cwe119.flatten()
data21 = codebert4vdcwe_base_cwe119.flatten()
data22 = codegen4vdcwe_small_cwe119.flatten()
data23 = codegen4vdcwe_base_cwe119.flatten()
data24 = codet54vdcwe_small_cwe119.flatten()
data25 = codet54vdcwe_base_cwe119.flatten()
data26 = codet54vdcwe_large_cwe119.flatten()
data27 = polycoder4vdcwe_small_cwe119.flatten()
data28 = polycoder4vdcwe_base_cwe119.flatten()
data29 = polycoder4vdcwe_large_cwe119.flatten()

data30 = codebert4vdcwe_small_cwe399.flatten()
data31 = codebert4vdcwe_base_cwe399.flatten()
data32 = codegen4vdcwe_small_cwe399.flatten()
data33 = codegen4vdcwe_base_cwe399.flatten()
data34 = codet54vdcwe_small_cwe399.flatten()
data35 = codet54vdcwe_base_cwe399.flatten()
data36 = codet54vdcwe_large_cwe399.flatten()
data37 = polycoder4vdcwe_small_cwe399.flatten()
data38 = polycoder4vdcwe_base_cwe399.flatten()
data39 = polycoder4vdcwe_large_cwe399.flatten()


fig, axes = plt.subplots(nrows=4, ncols=10, figsize=(20, 10), dpi=350)

axes[0, 0].hist(data00, bins=30, alpha=0.5,color='green')
axes[0, 0].set_title('Histogram 1')
axes[0, 0].set_xlabel('Value')
axes[0, 0].set_ylabel('Density')
axes[0, 0].set_yscale('log')
axes[0, 1].hist(data01, bins=30, alpha=0.5, color='orange')
axes[0, 1].set_title('Histogram 2')
axes[0, 1].set_xlabel('Value')
axes[0, 1].set_ylabel('Density')
axes[0, 1].set_yscale('log')
axes[0, 2].hist(data02, bins=30, alpha=0.5, color='red')
axes[0, 2].set_title('Histogram 2')
axes[0, 2].set_xlabel('Value')
axes[0, 2].set_ylabel('Density')
axes[0, 2].set_yscale('log')
axes[0, 3].hist(data03, bins=30, alpha=0.5, color='blue')
axes[0, 3].set_title('Histogram 2')
axes[0, 3].set_xlabel('Value')
axes[0, 3].set_ylabel('Density')
axes[0, 3].set_yscale('log')
axes[0, 4].hist(data04, bins=30, alpha=0.5, color='purple')
axes[0, 4].set_title('Histogram 2')
axes[0, 4].set_xlabel('Value')
axes[0, 4].set_ylabel('Density')
axes[0, 4].set_yscale('log')
axes[0, 5].hist(data05, bins=30, alpha=0.5, color='purple')
axes[0, 5].set_title('Histogram 2')
axes[0, 5].set_xlabel('Value')
axes[0, 5].set_ylabel('Density')
axes[0, 5].set_yscale('log')
axes[0, 6].hist(data06, bins=30, alpha=0.5, color='purple')
axes[0, 6].set_title('Histogram 2')
axes[0, 6].set_xlabel('Value')
axes[0, 6].set_ylabel('Density')
axes[0, 6].set_yscale('log')
axes[0, 7].hist(data07, bins=30, alpha=0.5, color='purple')
axes[0, 7].set_title('Histogram 2')
axes[0, 7].set_xlabel('Value')
axes[0, 7].set_ylabel('Density')
axes[0, 7].set_yscale('log')
axes[0, 8].hist(data08, bins=30, alpha=0.5, color='purple')
axes[0, 8].set_title('Histogram 2')
axes[0, 8].set_xlabel('Value')
axes[0, 8].set_ylabel('Density')
axes[0, 8].set_yscale('log')
axes[0, 9].hist(data09, bins=30, alpha=0.5, color='purple')
axes[0, 9].set_title('Histogram 2')
axes[0, 9].set_xlabel('Value')
axes[0, 9].set_ylabel('Density')
axes[0, 9].set_yscale('log')

axes[1, 0].hist(data10, bins=30, alpha=0.5,color='green')
axes[1, 0].set_title('Histogram 1')
axes[1, 0].set_xlabel('Value')
axes[1, 0].set_ylabel('Density')
axes[1, 0].set_yscale('log')
axes[1, 1].hist(data11, bins=30, alpha=0.5, color='orange')
axes[1, 1].set_title('Histogram 2')
axes[1, 1].set_xlabel('Value')
axes[1, 1].set_ylabel('Density')
axes[1, 1].set_yscale('log')
axes[1, 2].hist(data12, bins=30, alpha=0.5, color='red')
axes[1, 2].set_title('Histogram 2')
axes[1, 2].set_xlabel('Value')
axes[1, 2].set_ylabel('Density')
axes[1, 2].set_yscale('log')
axes[1, 3].hist(data13, bins=30, alpha=0.5, color='blue')
axes[1, 3].set_title('Histogram 2')
axes[1, 3].set_xlabel('Value')
axes[1, 3].set_ylabel('Density')
axes[1, 3].set_yscale('log')
axes[1, 4].hist(data14, bins=30, alpha=0.5, color='purple')
axes[1, 4].set_title('Histogram 2')
axes[1, 4].set_xlabel('Value')
axes[1, 4].set_ylabel('Density')
axes[1, 4].set_yscale('log')
axes[1, 5].hist(data15, bins=30, alpha=0.5, color='purple')
axes[1, 5].set_title('Histogram 2')
axes[1, 5].set_xlabel('Value')
axes[1, 5].set_ylabel('Density')
axes[1, 5].set_yscale('log')
axes[1, 6].hist(data16, bins=30, alpha=0.5, color='purple')
axes[1, 6].set_title('Histogram 2')
axes[1, 6].set_xlabel('Value')
axes[1, 6].set_ylabel('Density')
axes[1, 6].set_yscale('log')
axes[1, 7].hist(data17, bins=30, alpha=0.5, color='purple')
axes[1, 7].set_title('Histogram 2')
axes[1, 7].set_xlabel('Value')
axes[1, 7].set_ylabel('Density')
axes[1, 7].set_yscale('log')
axes[1, 8].hist(data18, bins=30, alpha=0.5, color='purple')
axes[1, 8].set_title('Histogram 2')
axes[1, 8].set_xlabel('Value')
axes[1, 8].set_ylabel('Density')
axes[1, 8].set_yscale('log')
axes[1, 9].hist(data19, bins=30, alpha=0.5, color='purple')
axes[1, 9].set_title('Histogram 2')
axes[1, 9].set_xlabel('Value')
axes[1, 9].set_ylabel('Density')
axes[1, 9].set_yscale('log')


axes[2, 0].hist(data20, bins=30, alpha=0.5,color='green')
axes[2, 0].set_title('Histogram 1')
axes[2, 0].set_xlabel('Value')
axes[2, 0].set_ylabel('Density')
axes[2, 0].set_yscale('log')
axes[2, 1].hist(data21, bins=30, alpha=0.5, color='orange')
axes[2, 1].set_title('Histogram 2')
axes[2, 1].set_xlabel('Value')
axes[2, 1].set_ylabel('Density')
axes[2, 1].set_yscale('log')
axes[2, 2].hist(data22, bins=30, alpha=0.5, color='red')
axes[2, 2].set_title('Histogram 2')
axes[2, 2].set_xlabel('Value')
axes[2, 2].set_ylabel('Density')
axes[2, 2].set_yscale('log')
axes[2, 3].hist(data23, bins=30, alpha=0.5, color='blue')
axes[2, 3].set_title('Histogram 2')
axes[2, 3].set_xlabel('Value')
axes[2, 3].set_ylabel('Density')
axes[2, 3].set_yscale('log')
axes[2, 4].hist(data24, bins=30, alpha=0.5, color='purple')
axes[2, 4].set_title('Histogram 2')
axes[2, 4].set_xlabel('Value')
axes[2, 4].set_ylabel('Density')
axes[2, 4].set_yscale('log')
axes[2, 5].hist(data25, bins=30, alpha=0.5, color='purple')
axes[2, 5].set_title('Histogram 2')
axes[2, 5].set_xlabel('Value')
axes[2, 5].set_ylabel('Density')
axes[2, 5].set_yscale('log')
axes[2, 6].hist(data26, bins=30, alpha=0.5, color='purple')
axes[2, 6].set_title('Histogram 2')
axes[2, 6].set_xlabel('Value')
axes[2, 6].set_ylabel('Density')
axes[2, 6].set_yscale('log')
axes[2, 7].hist(data27, bins=30, alpha=0.5, color='purple')
axes[2, 7].set_title('Histogram 2')
axes[2, 7].set_xlabel('Value')
axes[2, 7].set_ylabel('Density')
axes[2, 7].set_yscale('log')
axes[2, 8].hist(data28, bins=30, alpha=0.5, color='purple')
axes[2, 8].set_title('Histogram 2')
axes[2, 8].set_xlabel('Value')
axes[2, 8].set_ylabel('Density')
axes[2, 8].set_yscale('log')
axes[2, 9].hist(data29, bins=30, alpha=0.5, color='purple')
axes[2, 9].set_title('Histogram 2')
axes[2, 9].set_xlabel('Value')
axes[2, 9].set_ylabel('Density')
axes[2, 9].set_yscale('log')

axes[3, 0].hist(data30, bins=30, alpha=0.5,color='green')
axes[3, 0].set_title('Histogram 1')
axes[3, 0].set_xlabel('Value')
axes[3, 0].set_ylabel('Density')
axes[3, 0].set_yscale('log')
axes[3, 1].hist(data31, bins=30, alpha=0.5, color='orange')
axes[3, 1].set_title('Histogram 2')
axes[3, 1].set_xlabel('Value')
axes[3, 1].set_ylabel('Density')
axes[3, 1].set_yscale('log')
axes[3, 2].hist(data32, bins=30, alpha=0.5, color='red')
axes[3, 2].set_title('Histogram 2')
axes[3, 2].set_xlabel('Value')
axes[3, 2].set_ylabel('Density')
axes[3, 2].set_yscale('log')
axes[3, 3].hist(data33, bins=30, alpha=0.5, color='blue')
axes[3, 3].set_title('Histogram 2')
axes[3, 3].set_xlabel('Value')
axes[3, 3].set_ylabel('Density')
axes[3, 3].set_yscale('log')
axes[3, 4].hist(data34, bins=30, alpha=0.5, color='purple')
axes[3, 4].set_title('Histogram 2')
axes[3, 4].set_xlabel('Value')
axes[3, 4].set_ylabel('Density')
axes[3, 4].set_yscale('log')
axes[3, 5].hist(data35, bins=30, alpha=0.5, color='purple')
axes[3, 5].set_title('Histogram 2')
axes[3, 5].set_xlabel('Value')
axes[3, 5].set_ylabel('Density')
axes[3, 5].set_yscale('log')
axes[3, 6].hist(data36, bins=30, alpha=0.5, color='purple')
axes[3, 6].set_title('Histogram 2')
axes[3, 6].set_xlabel('Value')
axes[3, 6].set_ylabel('Density')
axes[3, 6].set_yscale('log')
axes[3, 7].hist(data37, bins=30, alpha=0.5, color='purple')
axes[3, 7].set_title('Histogram 2')
axes[3, 7].set_xlabel('Value')
axes[3, 7].set_ylabel('Density')
axes[3, 7].set_yscale('log')
axes[3, 8].hist(data38, bins=30, alpha=0.5, color='purple')
axes[3, 8].set_title('Histogram 2')
axes[3, 8].set_xlabel('Value')
axes[3, 8].set_ylabel('Density')
axes[3, 8].set_yscale('log')
axes[3, 9].hist(data39, bins=30, alpha=0.5, color='purple')
axes[3, 9].set_title('Histogram 2')
axes[3, 9].set_xlabel('Value')
axes[3, 9].set_ylabel('Density')
axes[3, 9].set_yscale('log')


plt.tight_layout()


plt.show()

# %%
#%matplotlib inline

#%matplotlib widget
#%matplotlib qt5

import matplotlib.pyplot as plt
import numpy as np


data00 = codebert4vdcwe_small_codexglue.flatten()
data01 = codebert4vdcwe_base_codexglue.flatten()
data02 = codegen4vdcwe_small_codexglue.flatten()
data03 = codegen4vdcwe_base_codexglue.flatten()
data04 = codet54vdcwe_small_codexglue.flatten()
data05 = codet54vdcwe_base_codexglue.flatten()
data06 = codet54vdcwe_large_codexglue.flatten()
data07 = polycoder4vdcwe_small_codexglue.flatten()
data08 = polycoder4vdcwe_base_codexglue.flatten()
data09 = polycoder4vdcwe_large_codexglue.flatten()


data10 = codebert4vdcwe_small_reveal.flatten()
data11 = codebert4vdcwe_base_reveal.flatten()
data12 = codegen4vdcwe_small_reveal.flatten()
data13 = codegen4vdcwe_base_reveal.flatten()
data14 = codet54vdcwe_small_reveal.flatten()
data15 = codet54vdcwe_base_reveal.flatten()
data16 = codet54vdcwe_large_reveal.flatten()
data17 = polycoder4vdcwe_small_reveal.flatten()
data18 = polycoder4vdcwe_base_reveal.flatten()
data19 = polycoder4vdcwe_large_reveal.flatten()

data20 = codebert4vdcwe_small_cwe119.flatten()
data21 = codebert4vdcwe_base_cwe119.flatten()
data22 = codegen4vdcwe_small_cwe119.flatten()
data23 = codegen4vdcwe_base_cwe119.flatten()
data24 = codet54vdcwe_small_cwe119.flatten()
data25 = codet54vdcwe_base_cwe119.flatten()
data26 = codet54vdcwe_large_cwe119.flatten()
data27 = polycoder4vdcwe_small_cwe119.flatten()
data28 = polycoder4vdcwe_base_cwe119.flatten()
data29 = polycoder4vdcwe_large_cwe119.flatten()

data30 = codebert4vdcwe_small_cwe399.flatten()
data31 = codebert4vdcwe_base_cwe399.flatten()
data32 = codegen4vdcwe_small_cwe399.flatten()
data33 = codegen4vdcwe_base_cwe399.flatten()
data34 = codet54vdcwe_small_cwe399.flatten()
data35 = codet54vdcwe_base_cwe399.flatten()
data36 = codet54vdcwe_large_cwe399.flatten()
data37 = polycoder4vdcwe_small_cwe399.flatten()
data38 = polycoder4vdcwe_base_cwe399.flatten()
data39 = polycoder4vdcwe_large_cwe399.flatten()

data_vdcwe_codebert_small = np.hstack((data00,data10,data20,data30))
data_vdcwe_codebert_base = np.hstack((data01,data11,data21,data31))
data_vdcwe_codegen_small = np.hstack((data02, data12, data22, data32))
data_vdcwe_codegen_base = np.hstack((data03, data13, data23, data33))
data_vdcwe_codet5_small = np.hstack((data04, data14, data24, data34))
data_vdcwe_codet5_base = np.hstack((data05, data15, data25, data35))
data_vdcwe_codet5_large = np.hstack((data06, data16, data26, data36))
data_vdcwe_polycoder_small = np.hstack((data07, data17, data27, data37))
data_vdcwe_polycoder_base = np.hstack((data08, data18, data28, data38))
data_vdcwe_polycoder_large = np.hstack((data09, data19, data29, data39))


fig, axes = plt.subplots(nrows=1, ncols=10, figsize=(30, 4), sharey=True)
axes[0].hist(data_vdcwe_codebert_small, bins=30, alpha=0.5,color='green')
axes[0].set_title('CodeBERT-small',fontsize=20)
#axes[0].set_ylabel('vdcwe',fontsize=20)
axes[0].set_yscale('log')
axes[0].tick_params(axis='x', labelsize=15)  
axes[0].tick_params(axis='y', labelsize=15)  
#axes[0].set_xlim(-5,20)

axes[1].hist(data_vdcwe_codebert_base, bins=30, alpha=0.5, color='orange')
axes[1].set_title('CodeBERT-base',fontsize=20)
axes[1].set_yscale('log')
axes[1].tick_params(axis='x', labelsize=15)  
axes[1].tick_params(axis='y', labelsize=15)  
#axes[1].set_xlim(-1,5)


axes[2].hist(data_vdcwe_codegen_small, bins=30, alpha=0.5, color='red')
axes[2].set_title('CodeGen-small',fontsize=20)
axes[2].set_yscale('log')
axes[2].tick_params(axis='x', labelsize=15)  
axes[2].tick_params(axis='y', labelsize=15)  
#axes[2].set_xlim(-1,4)

axes[3].hist(data_vdcwe_codegen_base, bins=30, alpha=0.5, color='blue')
axes[3].set_title('CodeGen-base',fontsize=20)

axes[3].set_yscale('log')
axes[3].tick_params(axis='x', labelsize=15)  
axes[3].tick_params(axis='y', labelsize=15)  
#axes[3].set_xlim(-4,4)

axes[4].hist(data_vdcwe_codet5_small, bins=30, alpha=0.5, color='purple')
axes[4].set_title('CodeT5-small',fontsize=20)
axes[4].set_yscale('log')
axes[4].tick_params(axis='x', labelsize=15)  
axes[4].tick_params(axis='y', labelsize=15)  
#axes[4].set_xlim(-60,60)

axes[5].hist(data_vdcwe_codet5_base, bins=30, alpha=0.5, color='purple')
axes[5].set_title('CodeT5-base',fontsize=20)
axes[5].set_yscale('log')
axes[5].tick_params(axis='x', labelsize=15)  
axes[5].tick_params(axis='y', labelsize=15)  
#axes[5].set_xlim(-60,60)

axes[6].hist(data_vdcwe_codet5_large, bins=30, alpha=0.5, color='purple')
axes[6].set_title('CodeT5-large',fontsize=20)
axes[6].set_yscale('log')
axes[6].tick_params(axis='x', labelsize=15)  
axes[6].tick_params(axis='y', labelsize=15)  
#axes[5].set_xlim(-60,60)

axes[7].hist(data_vdcwe_polycoder_small, bins=30, alpha=0.5, color='purple')
axes[7].set_title('PolyCoder-small',fontsize=20)
axes[7].set_yscale('log')
axes[7].tick_params(axis='x', labelsize=15)  
axes[7].tick_params(axis='y', labelsize=15)  
#axes[7].set_xlim(-60,60)

axes[8].hist(data_vdcwe_polycoder_base, bins=30, alpha=0.5, color='purple')
axes[8].set_title('PolyCoder-base',fontsize=20)
axes[8].set_yscale('log')
axes[8].tick_params(axis='x', labelsize=15)  
axes[8].tick_params(axis='y', labelsize=15) 
#axes[8].set_xlim(-60,60)

axes[9].hist(data_vdcwe_polycoder_large, bins=30, alpha=0.5, color='purple')
axes[9].set_title('PolyCoder-large',fontsize=20)
axes[9].set_yscale('log')
axes[9].tick_params(axis='x', labelsize=15)  
axes[9].tick_params(axis='y', labelsize=15)  
#axes[9].set_xlim(-60,60)

for ax in axes.flat:
    ax.yaxis.grid(True, linestyle='dashed')
    

plt.tight_layout()


plt.savefig('test.png', dpi=350,bbox_inches = 'tight')
plt.show()

# %%
#%matplotlib inline

#%matplotlib widget
#%matplotlib qt5

import matplotlib.pyplot as plt
import numpy as np


plt.rcParams['font.family'] = 'Times New Roman'


plt.rcParams['font.size'] = 11


plt.rcParams['font.weight'] = 'bold'

data00 = codebert4vdcwe_small_codexglue.flatten()
data01 = codebert4vdcwe_base_codexglue.flatten()
data02 = codegen4vdcwe_small_codexglue.flatten()
data03 = codegen4vdcwe_base_codexglue.flatten()
data04 = codet54vdcwe_small_codexglue.flatten()
data05 = codet54vdcwe_base_codexglue.flatten()
data06 = codet54vdcwe_large_codexglue.flatten()
data07 = polycoder4vdcwe_small_codexglue.flatten()
data08 = polycoder4vdcwe_base_codexglue.flatten()
data09 = polycoder4vdcwe_large_codexglue.flatten()


data10 = codebert4vdcwe_small_reveal.flatten()
data11 = codebert4vdcwe_base_reveal.flatten()
data12 = codegen4vdcwe_small_reveal.flatten()
data13 = codegen4vdcwe_base_reveal.flatten()
data14 = codet54vdcwe_small_reveal.flatten()
data15 = codet54vdcwe_base_reveal.flatten()
data16 = codet54vdcwe_large_reveal.flatten()
data17 = polycoder4vdcwe_small_reveal.flatten()
data18 = polycoder4vdcwe_base_reveal.flatten()
data19 = polycoder4vdcwe_large_reveal.flatten()

data20 = codebert4vdcwe_small_cwe119.flatten()
data21 = codebert4vdcwe_base_cwe119.flatten()
data22 = codegen4vdcwe_small_cwe119.flatten()
data23 = codegen4vdcwe_base_cwe119.flatten()
data24 = codet54vdcwe_small_cwe119.flatten()
data25 = codet54vdcwe_base_cwe119.flatten()
data26 = codet54vdcwe_large_cwe119.flatten()
data27 = polycoder4vdcwe_small_cwe119.flatten()
data28 = polycoder4vdcwe_base_cwe119.flatten()
data29 = polycoder4vdcwe_large_cwe119.flatten()

data30 = codebert4vdcwe_small_cwe399.flatten()
data31 = codebert4vdcwe_base_cwe399.flatten()
data32 = codegen4vdcwe_small_cwe399.flatten()
data33 = codegen4vdcwe_base_cwe399.flatten()
data34 = codet54vdcwe_small_cwe399.flatten()
data35 = codet54vdcwe_base_cwe399.flatten()
data36 = codet54vdcwe_large_cwe399.flatten()
data37 = polycoder4vdcwe_small_cwe399.flatten()
data38 = polycoder4vdcwe_base_cwe399.flatten()
data39 = polycoder4vdcwe_large_cwe399.flatten()

data_vdcwe_codebert_small = np.hstack((data00,data10,data20,data30))
data_vdcwe_codebert_base = np.hstack((data01,data11,data21,data31))
data_vdcwe_codegen_small = np.hstack((data02, data12, data22, data32))
data_vdcwe_codegen_base = np.hstack((data03, data13, data23, data33))
data_vdcwe_codet5_small = np.hstack((data04, data14, data24, data34))
data_vdcwe_codet5_base = np.hstack((data05, data15, data25, data35))
data_vdcwe_codet5_large = np.hstack((data06, data16, data26, data36))
data_vdcwe_polycoder_small = np.hstack((data07, data17, data27, data37))
data_vdcwe_polycoder_base = np.hstack((data08, data18, data28, data38))
data_vdcwe_polycoder_large = np.hstack((data09, data19, data29, data39))


fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(24, 10), sharey=True)
axes[0][0].hist(data_vdcwe_codebert_small, bins=30, alpha=0.5, color='green')
axes[0][0].set_title('coebert-small',fontsize=25, fontweight='bold')
#axes[0][0].set_ylabel('vdcwe',fontsize=20)
axes[0][0].set_yscale('log')
axes[0][0].tick_params(axis='x', labelsize=15)  
axes[0][0].tick_params(axis='y', labelsize=15)  
#axes[0][0].set_xlim(-5,20)

axes[0][1].hist(data_vdcwe_codebert_base, bins=30, alpha=0.5, color='orange')
axes[0][1].set_title('coebert-base',fontsize=25, fontweight='bold')
axes[0][1].set_yscale('log')
axes[0][1].tick_params(axis='x', labelsize=15)  
axes[0][1].tick_params(axis='y', labelsize=15)  
#axes[0][1].set_xlim(-1,5)


axes[0][2].hist(data_vdcwe_codegen_small, bins=30, alpha=0.5, color='red')
axes[0][2].set_title('codegen-small',fontsize=20, fontweight='bold')
axes[0][2].set_yscale('log')
axes[0][2].tick_params(axis='x', labelsize=15) 
axes[0][2].tick_params(axis='y', labelsize=15)  
#axes[0][2].set_xlim(-1,4)

axes[0][3].hist(data_vdcwe_codegen_base, bins=30, alpha=0.5, color='blue')
axes[0][3].set_title('codegen-base',fontsize=25, fontweight='bold')

axes[0][3].set_yscale('log')
axes[0][3].tick_params(axis='x', labelsize=15)  
axes[0][3].tick_params(axis='y', labelsize=15) 
#axes[0][3].set_xlim(-4,4)

axes[0][4].hist(data_vdcwe_codet5_small, bins=30, alpha=0.5, color='purple')
axes[0][4].set_title('codet5-small',fontsize=25, fontweight='bold')
axes[0][4].set_yscale('log')
axes[0][4].tick_params(axis='x', labelsize=15) 
axes[0][4].tick_params(axis='y', labelsize=15)  
#axes[0][4].set_xlim(-60,60)

axes[1][0].hist(data_vdcwe_codet5_base, bins=30, alpha=0.5, color='yellow')
axes[1][0].set_title('codet5-base',fontsize=25, fontweight='bold')
axes[1][0].set_yscale('log')
axes[1][0].tick_params(axis='x', labelsize=15)  
axes[1][0].tick_params(axis='y', labelsize=15)  
#axes[1][0].set_xlim(-60,60)
axes[1][1].hist(data_vdcwe_codet5_large, bins=30, alpha=0.5, color='green')
axes[1][1].set_title('codet5-large',fontsize=25, fontweight='bold')
axes[1][1].set_yscale('log')
axes[1][1].tick_params(axis='x', labelsize=15)  
axes[1][1].tick_params(axis='y', labelsize=15)  
#axes[1][1].set_xlim(-60,60)

axes[1][2].hist(data_vdcwe_polycoder_small, bins=30, alpha=0.5, color='purple')
axes[1][2].set_title('polycoder-small',fontsize=25, fontweight='bold')
axes[1][2].set_yscale('log')
axes[1][2].tick_params(axis='x', labelsize=15)  
axes[1][2].tick_params(axis='y', labelsize=15)  
#axes[1][2].set_xlim(-60,60)

axes[1][3].hist(data_vdcwe_polycoder_base, bins=30, alpha=0.5, color='orange')
axes[1][3].set_title('polycoder-base',fontsize=25, fontweight='bold')
axes[1][3].set_yscale('log')
axes[1][3].tick_params(axis='x', labelsize=15)  
axes[1][3].tick_params(axis='y', labelsize=15)  
#axes[1][3].set_xlim(-60,60)

axes[1][4].hist(data_vdcwe_polycoder_large, bins=30, alpha=0.5, color='red')
axes[1][4].set_title('polycoder-large',fontsize=25, fontweight='bold')
axes[1][4].set_yscale('log')
axes[1][4].tick_params(axis='x', labelsize=15) 
axes[1][4].tick_params(axis='y', labelsize=15)  
#axes[1][4].set_xlim(-60,60)


for ax in axes.flat:
    ax.yaxis.grid(True, linestyle='dashed')
    

plt.tight_layout()


plt.savefig('rq2-1-test.png', dpi=350,bbox_inches = 'tight')
plt.show()

# %%
codebert4vdcwe_small_codexglue_norm_F = np.linalg.norm(codebert4vdcwe_small_codexglue, axis=1)
codebert4vdcwe_base_codexglue_norm_F = np.linalg.norm(codebert4vdcwe_base_codexglue, axis=1)
codegen4vdcwe_small_codexglue_norm_F = np.linalg.norm(codegen4vdcwe_small_codexglue, axis=1)
codegen4vdcwe_base_codexglue_norm_F = np.linalg.norm(codegen4vdcwe_base_codexglue, axis=1)
codet54vdcwe_small_codexglue_norm_F = np.linalg.norm(codet54vdcwe_small_codexglue, axis=1)
codet54vdcwe_base_codexglue_norm_F = np.linalg.norm(codet54vdcwe_base_codexglue, axis=1)
codet54vdcwe_large_codexglue_norm_F = np.linalg.norm(codet54vdcwe_large_codexglue, axis=1)
polycoder4vdcwe_small_codexglue_norm_F = np.linalg.norm(polycoder4vdcwe_small_codexglue, axis=1)
polycoder4vdcwe_base_codexglue_norm_F = np.linalg.norm(polycoder4vdcwe_base_codexglue, axis=1)
polycoder4vdcwe_large_codexglue_norm_F = np.linalg.norm(polycoder4vdcwe_large_codexglue, axis=1)

codebert4vdcwe_small_reveal_norm_F = np.linalg.norm(codebert4vdcwe_small_reveal, axis=1)
codebert4vdcwe_base_reveal_norm_F = np.linalg.norm(codebert4vdcwe_base_reveal, axis=1)
codegen4vdcwe_small_reveal_norm_F = np.linalg.norm(codegen4vdcwe_small_reveal, axis=1)
codegen4vdcwe_base_reveal_norm_F = np.linalg.norm(codegen4vdcwe_base_reveal, axis=1)
codet54vdcwe_small_reveal_norm_F = np.linalg.norm(codet54vdcwe_small_reveal, axis=1)
codet54vdcwe_base_reveal_norm_F = np.linalg.norm(codet54vdcwe_base_reveal, axis=1)
codet54vdcwe_large_reveal_norm_F = np.linalg.norm(codet54vdcwe_large_reveal, axis=1)
polycoder4vdcwe_small_reveal_norm_F = np.linalg.norm(polycoder4vdcwe_small_reveal, axis=1)
polycoder4vdcwe_base_reveal_norm_F = np.linalg.norm(polycoder4vdcwe_base_reveal, axis=1)
polycoder4vdcwe_large_reveal_norm_F = np.linalg.norm(polycoder4vdcwe_large_reveal, axis=1)

codebert4vdcwe_small_cwe119_norm_F = np.linalg.norm(codebert4vdcwe_small_cwe119, axis=1)
codebert4vdcwe_base_cwe119_norm_F = np.linalg.norm(codebert4vdcwe_base_cwe119, axis=1)
codegen4vdcwe_small_cwe119_norm_F = np.linalg.norm(codegen4vdcwe_small_cwe119, axis=1)
codegen4vdcwe_base_cwe119_norm_F = np.linalg.norm(codegen4vdcwe_base_cwe119, axis=1)
codet54vdcwe_small_cwe119_norm_F = np.linalg.norm(codet54vdcwe_small_cwe119, axis=1)
codet54vdcwe_base_cwe119_norm_F = np.linalg.norm(codet54vdcwe_base_cwe119, axis=1)
codet54vdcwe_large_cwe119_norm_F = np.linalg.norm(codet54vdcwe_large_cwe119, axis=1)
polycoder4vdcwe_small_cwe119_norm_F = np.linalg.norm(polycoder4vdcwe_small_cwe119, axis=1)
polycoder4vdcwe_base_cwe119_norm_F = np.linalg.norm(polycoder4vdcwe_base_cwe119, axis=1)
polycoder4vdcwe_large_cwe119_norm_F = np.linalg.norm(polycoder4vdcwe_large_cwe119, axis=1)

codebert4vdcwe_small_cwe399_norm_F = np.linalg.norm(codebert4vdcwe_small_cwe399, axis=1)
codebert4vdcwe_base_cwe399_norm_F = np.linalg.norm(codebert4vdcwe_base_cwe399, axis=1)
codegen4vdcwe_small_cwe399_norm_F = np.linalg.norm(codegen4vdcwe_small_cwe399, axis=1)
codegen4vdcwe_base_cwe399_norm_F = np.linalg.norm(codegen4vdcwe_base_cwe399, axis=1)
codet54vdcwe_small_cwe399_norm_F = np.linalg.norm(codet54vdcwe_small_cwe399, axis=1)
codet54vdcwe_base_cwe399_norm_F = np.linalg.norm(codet54vdcwe_base_cwe399, axis=1)
codet54vdcwe_large_cwe399_norm_F = np.linalg.norm(codet54vdcwe_large_cwe399, axis=1)
polycoder4vdcwe_small_cwe399_norm_F = np.linalg.norm(polycoder4vdcwe_small_cwe399, axis=1)
polycoder4vdcwe_base_cwe399_norm_F = np.linalg.norm(polycoder4vdcwe_base_cwe399, axis=1)
polycoder4vdcwe_large_cwe399_norm_F = np.linalg.norm(polycoder4vdcwe_large_cwe399, axis=1)

# %%
data00_F = codebert4vdcwe_small_codexglue_norm_F 
data01_F = codebert4vdcwe_base_codexglue_norm_F 
data02_F = codegen4vdcwe_small_codexglue_norm_F 
data03_F = codegen4vdcwe_base_codexglue_norm_F 
data04_F = codet54vdcwe_small_codexglue_norm_F 
data05_F = codet54vdcwe_base_codexglue_norm_F 
data06_F = codet54vdcwe_large_codexglue_norm_F 
data07_F = polycoder4vdcwe_small_codexglue_norm_F 
data08_F = polycoder4vdcwe_base_codexglue_norm_F 
data09_F = polycoder4vdcwe_large_codexglue_norm_F 
 
data10_F = codebert4vdcwe_small_reveal_norm_F 
data11_F = codebert4vdcwe_base_reveal_norm_F 
data12_F = codegen4vdcwe_small_reveal_norm_F 
data13_F = codegen4vdcwe_base_reveal_norm_F 
data14_F = codet54vdcwe_small_reveal_norm_F 
data15_F = codet54vdcwe_base_reveal_norm_F 
data16_F = codet54vdcwe_large_reveal_norm_F 
data17_F = polycoder4vdcwe_small_reveal_norm_F 
data18_F = polycoder4vdcwe_base_reveal_norm_F 
data19_F = polycoder4vdcwe_large_reveal_norm_F 

data20_F = codebert4vdcwe_small_cwe119_norm_F 
data21_F = codebert4vdcwe_base_cwe119_norm_F 
data22_F = codegen4vdcwe_small_cwe119_norm_F 
data23_F = codegen4vdcwe_base_cwe119_norm_F 
data24_F = codet54vdcwe_small_cwe119_norm_F 
data25_F = codet54vdcwe_base_cwe119_norm_F 
data26_F = codet54vdcwe_large_cwe119_norm_F 
data27_F = polycoder4vdcwe_small_cwe119_norm_F 
data28_F = polycoder4vdcwe_base_cwe119_norm_F 
data29_F = polycoder4vdcwe_large_cwe119_norm_F 

data30_F = codebert4vdcwe_small_cwe399_norm_F 
data31_F = codebert4vdcwe_base_cwe399_norm_F 
data32_F = codegen4vdcwe_small_cwe399_norm_F 
data33_F = codegen4vdcwe_base_cwe399_norm_F 
data34_F = codet54vdcwe_small_cwe399_norm_F 
data35_F = codet54vdcwe_base_cwe399_norm_F 
data36_F = codet54vdcwe_large_cwe399_norm_F 
data37_F = polycoder4vdcwe_small_cwe399_norm_F 
data38_F = polycoder4vdcwe_base_cwe399_norm_F 
data39_F = polycoder4vdcwe_large_cwe399_norm_F 


fig, axes = plt.subplots(nrows=4, ncols=10, figsize=(20, 10), dpi=350)

axes[0, 0].hist(data00_F, bins=30, alpha=0.5,color='green')
axes[0, 0].set_title('Histogram 1')
axes[0, 0].set_xlabel('Value')
axes[0, 0].set_ylabel('Density')
axes[0, 0].set_yscale('log')
axes[0, 1].hist(data01_F, bins=30, alpha=0.5, color='orange')
axes[0, 1].set_title('Histogram 2')
axes[0, 1].set_xlabel('Value')
axes[0, 1].set_ylabel('Density')
axes[0, 1].set_yscale('log')
axes[0, 2].hist(data02_F, bins=30, alpha=0.5, color='red')
axes[0, 2].set_title('Histogram 2')
axes[0, 2].set_xlabel('Value')
axes[0, 2].set_ylabel('Density')
axes[0, 2].set_yscale('log')
axes[0, 3].hist(data03_F, bins=30, alpha=0.5, color='blue')
axes[0, 3].set_title('Histogram 2')
axes[0, 3].set_xlabel('Value')
axes[0, 3].set_ylabel('Density')
axes[0, 3].set_yscale('log')
axes[0, 4].hist(data04_F, bins=30, alpha=0.5, color='purple')
axes[0, 4].set_title('Histogram 2')
axes[0, 4].set_xlabel('Value')
axes[0, 4].set_ylabel('Density')
axes[0, 4].set_yscale('log')
axes[0, 5].hist(data05_F, bins=30, alpha=0.5, color='purple')
axes[0, 5].set_title('Histogram 2')
axes[0, 5].set_xlabel('Value')
axes[0, 5].set_ylabel('Density')
axes[0, 5].set_yscale('log')
axes[0, 6].hist(data06_F, bins=30, alpha=0.5, color='purple')
axes[0, 6].set_title('Histogram 2')
axes[0, 6].set_xlabel('Value')
axes[0, 6].set_ylabel('Density')
axes[0, 6].set_yscale('log')
axes[0, 7].hist(data07_F, bins=30, alpha=0.5, color='purple')
axes[0, 7].set_title('Histogram 2')
axes[0, 7].set_xlabel('Value')
axes[0, 7].set_ylabel('Density')
axes[0, 7].set_yscale('log')
axes[0, 8].hist(data08_F, bins=30, alpha=0.5, color='purple')
axes[0, 8].set_title('Histogram 2')
axes[0, 8].set_xlabel('Value')
axes[0, 8].set_ylabel('Density')
axes[0, 8].set_yscale('log')
axes[0, 9].hist(data09_F, bins=30, alpha=0.5, color='purple')
axes[0, 9].set_title('Histogram 2')
axes[0, 9].set_xlabel('Value')
axes[0, 9].set_ylabel('Density')
axes[0, 9].set_yscale('log')

axes[1, 0].hist(data10_F, bins=30, alpha=0.5,color='green')
axes[1, 0].set_title('Histogram 1')
axes[1, 0].set_xlabel('Value')
axes[1, 0].set_ylabel('Density')
axes[1, 0].set_yscale('log')
axes[1, 1].hist(data11_F, bins=30, alpha=0.5, color='orange')
axes[1, 1].set_title('Histogram 2')
axes[1, 1].set_xlabel('Value')
axes[1, 1].set_ylabel('Density')
axes[1, 1].set_yscale('log')
axes[1, 2].hist(data12_F, bins=30, alpha=0.5, color='red')
axes[1, 2].set_title('Histogram 2')
axes[1, 2].set_xlabel('Value')
axes[1, 2].set_ylabel('Density')
axes[1, 2].set_yscale('log')
axes[1, 3].hist(data13_F, bins=30, alpha=0.5, color='blue')
axes[1, 3].set_title('Histogram 2')
axes[1, 3].set_xlabel('Value')
axes[1, 3].set_ylabel('Density')
axes[1, 3].set_yscale('log')
axes[1, 4].hist(data14_F, bins=30, alpha=0.5, color='purple')
axes[1, 4].set_title('Histogram 2')
axes[1, 4].set_xlabel('Value')
axes[1, 4].set_ylabel('Density')
axes[1, 4].set_yscale('log')
axes[1, 5].hist(data15_F, bins=30, alpha=0.5, color='purple')
axes[1, 5].set_title('Histogram 2')
axes[1, 5].set_xlabel('Value')
axes[1, 5].set_ylabel('Density')
axes[1, 5].set_yscale('log')
axes[1, 6].hist(data16_F, bins=30, alpha=0.5, color='purple')
axes[1, 6].set_title('Histogram 2')
axes[1, 6].set_xlabel('Value')
axes[1, 6].set_ylabel('Density')
axes[1, 6].set_yscale('log')
axes[1, 7].hist(data17_F, bins=30, alpha=0.5, color='purple')
axes[1, 7].set_title('Histogram 2')
axes[1, 7].set_xlabel('Value')
axes[1, 7].set_ylabel('Density')
axes[1, 7].set_yscale('log')
axes[1, 8].hist(data18_F, bins=30, alpha=0.5, color='purple')
axes[1, 8].set_title('Histogram 2')
axes[1, 8].set_xlabel('Value')
axes[1, 8].set_ylabel('Density')
axes[1, 8].set_yscale('log')
axes[1, 9].hist(data19_F, bins=30, alpha=0.5, color='purple')
axes[1, 9].set_title('Histogram 2')
axes[1, 9].set_xlabel('Value')
axes[1, 9].set_ylabel('Density')
axes[1, 9].set_yscale('log')


axes[2, 0].hist(data20_F, bins=30, alpha=0.5,color='green')
axes[2, 0].set_title('Histogram 1')
axes[2, 0].set_xlabel('Value')
axes[2, 0].set_ylabel('Density')
axes[2, 0].set_yscale('log')
axes[2, 1].hist(data21_F, bins=30, alpha=0.5, color='orange')
axes[2, 1].set_title('Histogram 2')
axes[2, 1].set_xlabel('Value')
axes[2, 1].set_ylabel('Density')
axes[2, 1].set_yscale('log')
axes[2, 2].hist(data22_F, bins=30, alpha=0.5, color='red')
axes[2, 2].set_title('Histogram 2')
axes[2, 2].set_xlabel('Value')
axes[2, 2].set_ylabel('Density')
axes[2, 2].set_yscale('log')
axes[2, 3].hist(data23_F, bins=30, alpha=0.5, color='blue')
axes[2, 3].set_title('Histogram 2')
axes[2, 3].set_xlabel('Value')
axes[2, 3].set_ylabel('Density')
axes[2, 3].set_yscale('log')
axes[2, 4].hist(data24_F, bins=30, alpha=0.5, color='purple')
axes[2, 4].set_title('Histogram 2')
axes[2, 4].set_xlabel('Value')
axes[2, 4].set_ylabel('Density')
axes[2, 4].set_yscale('log')
axes[2, 5].hist(data25_F, bins=30, alpha=0.5, color='purple')
axes[2, 5].set_title('Histogram 2')
axes[2, 5].set_xlabel('Value')
axes[2, 5].set_ylabel('Density')
axes[2, 5].set_yscale('log')
axes[2, 6].hist(data26_F, bins=30, alpha=0.5, color='purple')
axes[2, 6].set_title('Histogram 2')
axes[2, 6].set_xlabel('Value')
axes[2, 6].set_ylabel('Density')
axes[2, 6].set_yscale('log')
axes[2, 7].hist(data27_F, bins=30, alpha=0.5, color='purple')
axes[2, 7].set_title('Histogram 2')
axes[2, 7].set_xlabel('Value')
axes[2, 7].set_ylabel('Density')
axes[2, 7].set_yscale('log')
axes[2, 8].hist(data28_F, bins=30, alpha=0.5, color='purple')
axes[2, 8].set_title('Histogram 2')
axes[2, 8].set_xlabel('Value')
axes[2, 8].set_ylabel('Density')
axes[2, 8].set_yscale('log')
axes[2, 9].hist(data29_F, bins=30, alpha=0.5, color='purple')
axes[2, 9].set_title('Histogram 2')
axes[2, 9].set_xlabel('Value')
axes[2, 9].set_ylabel('Density')
axes[2, 9].set_yscale('log')

axes[3, 0].hist(data30_F, bins=30, alpha=0.5,color='green')
axes[3, 0].set_title('Histogram 1')
axes[3, 0].set_xlabel('Value')
axes[3, 0].set_ylabel('Density')
axes[3, 0].set_yscale('log')
axes[3, 1].hist(data31_F, bins=30, alpha=0.5, color='orange')
axes[3, 1].set_title('Histogram 2')
axes[3, 1].set_xlabel('Value')
axes[3, 1].set_ylabel('Density')
axes[3, 1].set_yscale('log')
axes[3, 2].hist(data32_F, bins=30, alpha=0.5, color='red')
axes[3, 2].set_title('Histogram 2')
axes[3, 2].set_xlabel('Value')
axes[3, 2].set_ylabel('Density')
axes[3, 2].set_yscale('log')
axes[3, 3].hist(data33_F, bins=30, alpha=0.5, color='blue')
axes[3, 3].set_title('Histogram 2')
axes[3, 3].set_xlabel('Value')
axes[3, 3].set_ylabel('Density')
axes[3, 3].set_yscale('log')
axes[3, 4].hist(data34_F, bins=30, alpha=0.5, color='purple')
axes[3, 4].set_title('Histogram 2')
axes[3, 4].set_xlabel('Value')
axes[3, 4].set_ylabel('Density')
axes[3, 4].set_yscale('log')
axes[3, 5].hist(data35_F, bins=30, alpha=0.5, color='purple')
axes[3, 5].set_title('Histogram 2')
axes[3, 5].set_xlabel('Value')
axes[3, 5].set_ylabel('Density')
axes[3, 5].set_yscale('log')
axes[3, 6].hist(data36_F, bins=30, alpha=0.5, color='purple')
axes[3, 6].set_title('Histogram 2')
axes[3, 6].set_xlabel('Value')
axes[3, 6].set_ylabel('Density')
axes[3, 6].set_yscale('log')
axes[3, 7].hist(data37_F, bins=30, alpha=0.5, color='purple')
axes[3, 7].set_title('Histogram 2')
axes[3, 7].set_xlabel('Value')
axes[3, 7].set_ylabel('Density')
axes[3, 7].set_yscale('log')
axes[3, 8].hist(data38_F, bins=30, alpha=0.5, color='purple')
axes[3, 8].set_title('Histogram 2')
axes[3, 8].set_xlabel('Value')
axes[3, 8].set_ylabel('Density')
axes[3, 8].set_yscale('log')
axes[3, 9].hist(data39_F, bins=30, alpha=0.5, color='purple')
axes[3, 9].set_title('Histogram 2')
axes[3, 9].set_xlabel('Value')
axes[3, 9].set_ylabel('Density')
axes[3, 9].set_yscale('log')



plt.tight_layout()


plt.show()

# %%
#%matplotlib inline

#%matplotlib widget
#%matplotlib qt5

import matplotlib.pyplot as plt
import numpy as np


data00_F = codebert4vdcwe_small_codexglue_norm_F 
data01_F = codebert4vdcwe_base_codexglue_norm_F 
data02_F = codegen4vdcwe_small_codexglue_norm_F 
data03_F = codegen4vdcwe_base_codexglue_norm_F 
data04_F = codet54vdcwe_small_codexglue_norm_F 
data05_F = codet54vdcwe_base_codexglue_norm_F 
data06_F = codet54vdcwe_large_codexglue_norm_F 
data07_F = polycoder4vdcwe_small_codexglue_norm_F 
data08_F = polycoder4vdcwe_base_codexglue_norm_F 
data09_F = polycoder4vdcwe_large_codexglue_norm_F 
 
data10_F = codebert4vdcwe_small_reveal_norm_F 
data11_F = codebert4vdcwe_base_reveal_norm_F 
data12_F = codegen4vdcwe_small_reveal_norm_F 
data13_F = codegen4vdcwe_base_reveal_norm_F 
data14_F = codet54vdcwe_small_reveal_norm_F 
data15_F = codet54vdcwe_base_reveal_norm_F 
data16_F = codet54vdcwe_large_reveal_norm_F 
data17_F = polycoder4vdcwe_small_reveal_norm_F 
data18_F = polycoder4vdcwe_base_reveal_norm_F 
data19_F = polycoder4vdcwe_large_reveal_norm_F 

data20_F = codebert4vdcwe_small_cwe119_norm_F 
data21_F = codebert4vdcwe_base_cwe119_norm_F 
data22_F = codegen4vdcwe_small_cwe119_norm_F 
data23_F = codegen4vdcwe_base_cwe119_norm_F 
data24_F = codet54vdcwe_small_cwe119_norm_F 
data25_F = codet54vdcwe_base_cwe119_norm_F 
data26_F = codet54vdcwe_large_cwe119_norm_F 
data27_F = polycoder4vdcwe_small_cwe119_norm_F 
data28_F = polycoder4vdcwe_base_cwe119_norm_F 
data29_F = polycoder4vdcwe_large_cwe119_norm_F 

data30_F = codebert4vdcwe_small_cwe399_norm_F 
data31_F = codebert4vdcwe_base_cwe399_norm_F 
data32_F = codegen4vdcwe_small_cwe399_norm_F 
data33_F = codegen4vdcwe_base_cwe399_norm_F 
data34_F = codet54vdcwe_small_cwe399_norm_F 
data35_F = codet54vdcwe_base_cwe399_norm_F 
data36_F = codet54vdcwe_large_cwe399_norm_F 
data37_F = polycoder4vdcwe_small_cwe399_norm_F 
data38_F = polycoder4vdcwe_base_cwe399_norm_F 
data39_F = polycoder4vdcwe_large_cwe399_norm_F 


data_vdcwe_codebert_small_F = np.hstack((data00_F,data10_F,data20_F,data30_F))
data_vdcwe_codebert_base_F = np.hstack((data01_F,data11_F,data21_F,data31_F))
data_vdcwe_codegen_small_F = np.hstack((data02_F, data12_F, data22_F, data32_F))
data_vdcwe_codegen_base_F = np.hstack((data03_F, data13_F, data23_F, data33_F))
data_vdcwe_codet5_small_F = np.hstack((data04_F, data14_F, data24_F, data34_F))
data_vdcwe_codet5_base_F = np.hstack((data05_F, data15_F, data25_F, data35_F))
data_vdcwe_codet5_large_F = np.hstack((data06_F, data16_F, data26_F, data36_F))
data_vdcwe_polycoder_small_F = np.hstack((data07_F, data17_F, data27_F, data37_F))
data_vdcwe_polycoder_base_F = np.hstack((data08_F, data18_F, data28_F, data38_F))
data_vdcwe_polycoder_large_F = np.hstack((data09_F, data19_F, data29_F, data39_F))


fig, axes = plt.subplots(nrows=1, ncols=10, figsize=(30, 4))
axes[0].hist(data_vdcwe_codebert_small_F, bins=30, alpha=0.5,color='green')
axes[0].set_title('CodeBERT-small',fontsize=20)
axes[0].set_ylabel('vdcwe',fontsize=20)
axes[0].set_yscale('log')
axes[0].tick_params(axis='x', labelsize=15)  
axes[0].tick_params(axis='y', labelsize=15)  
#axes[0].set_xlim(-5,20)

axes[1].hist(data_vdcwe_codebert_base_F, bins=30, alpha=0.5, color='orange')
axes[1].set_title('CodeBERT-base',fontsize=20)
axes[1].set_yscale('log')
axes[1].tick_params(axis='x', labelsize=15)  
axes[1].tick_params(axis='y', labelsize=15)  
#axes[1].set_xlim(-1,5)


axes[2].hist(data_vdcwe_codegen_small_F, bins=30, alpha=0.5, color='red')
axes[2].set_title('CodeGen-small',fontsize=20)
axes[2].set_yscale('log')
axes[2].tick_params(axis='x', labelsize=15)  
axes[2].tick_params(axis='y', labelsize=15)  
#axes[2].set_xlim(-1,4)

axes[3].hist(data_vdcwe_codegen_base_F, bins=30, alpha=0.5, color='blue')
axes[3].set_title('CodeGen-base',fontsize=20)

axes[3].set_yscale('log')
axes[3].tick_params(axis='x', labelsize=15)  
axes[3].tick_params(axis='y', labelsize=15)  
#axes[3].set_xlim(-4,4)

axes[4].hist(data_vdcwe_codet5_small_F, bins=30, alpha=0.5, color='purple')
axes[4].set_title('CodeT5-small',fontsize=20)
axes[4].set_yscale('log')
axes[4].tick_params(axis='x', labelsize=15) 
axes[4].tick_params(axis='y', labelsize=15)  
#axes[4].set_xlim(-60,60)

axes[5].hist(data_vdcwe_codet5_base_F, bins=30, alpha=0.5, color='purple')
axes[5].set_title('CodeT5-base',fontsize=20)
axes[5].set_yscale('log')
axes[5].tick_params(axis='x', labelsize=15)  
axes[5].tick_params(axis='y', labelsize=15)  
#axes[5].set_xlim(-60,60)

axes[6].hist(data_vdcwe_codet5_large_F, bins=30, alpha=0.5, color='purple')
axes[6].set_title('CodeT5-large',fontsize=20)
axes[6].set_yscale('log')
axes[6].tick_params(axis='x', labelsize=15)  
axes[6].tick_params(axis='y', labelsize=15)  
#axes[5].set_xlim(-60,60)

axes[7].hist(data_vdcwe_polycoder_small_F, bins=30, alpha=0.5, color='purple')
axes[7].set_title('polycoder-small',fontsize=20)
axes[7].set_yscale('log')
axes[7].tick_params(axis='x', labelsize=15)  
axes[7].tick_params(axis='y', labelsize=15) 
#axes[7].set_xlim(-60,60)

axes[8].hist(data_vdcwe_polycoder_base_F, bins=30, alpha=0.5, color='purple')
axes[8].set_title('polycoder-base',fontsize=20)
axes[8].set_yscale('log')
axes[8].tick_params(axis='x', labelsize=15)  
axes[8].tick_params(axis='y', labelsize=15) 
#axes[8].set_xlim(-60,60)

axes[9].hist(data_vdcwe_polycoder_large_F, bins=30, alpha=0.5, color='purple')
axes[9].set_title('polycoder-large',fontsize=20)
axes[9].set_yscale('log')
axes[9].tick_params(axis='x', labelsize=15)  
axes[9].tick_params(axis='y', labelsize=15)  
#axes[9].set_xlim(-60,60)


for ax in axes.flat:
    ax.yaxis.grid(True, linestyle='dashed')
    

plt.tight_layout()

plt.savefig('xx.png', dpi=350,bbox_inches = 'tight')
plt.show()

# %%
#%matplotlib inline

#%matplotlib widget
#%matplotlib qt5

import matplotlib.pyplot as plt
import numpy as np


plt.rcParams['font.family'] = 'Times New Roman'


plt.rcParams['font.size'] = 11


plt.rcParams['font.weight'] = 'bold'


fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(24, 10), sharey=True)
axes[0][0].hist(data_vdcwe_codebert_small_F, bins=30, alpha=0.5, color='green')
axes[0][0].set_title('coebert-small',fontsize=25, fontweight='bold')
#axes[0][0].set_ylabel('vdcwe',fontsize=20)
axes[0][0].set_yscale('log')
axes[0][0].tick_params(axis='x', labelsize=15)  
axes[0][0].tick_params(axis='y', labelsize=15)  
#axes[0][0].set_xlim(-5,20)

axes[0][1].hist(data_vdcwe_codebert_base_F, bins=30, alpha=0.5, color='orange')
axes[0][1].set_title('coebert-base',fontsize=25, fontweight='bold')
axes[0][1].set_yscale('log')
axes[0][1].tick_params(axis='x', labelsize=15)   
axes[0][1].tick_params(axis='y', labelsize=15)   
#axes[0][1].set_xlim(-1,5)


axes[0][2].hist(data_vdcwe_codegen_small_F, bins=30, alpha=0.5, color='red')
axes[0][2].set_title('codegen-small',fontsize=25, fontweight='bold')
axes[0][2].set_yscale('log')
axes[0][2].tick_params(axis='x', labelsize=15)   
axes[0][2].tick_params(axis='y', labelsize=15)   
#axes[0][2].set_xlim(-1,4)

axes[0][3].hist(data_vdcwe_codegen_base_F, bins=30, alpha=0.5, color='blue')
axes[0][3].set_title('codegen-base',fontsize=25, fontweight='bold')

axes[0][3].set_yscale('log')
axes[0][3].tick_params(axis='x', labelsize=15)   
axes[0][3].tick_params(axis='y', labelsize=15)   
#axes[0][3].set_xlim(-4,4)

axes[0][4].hist(data_vdcwe_codet5_small_F, bins=30, alpha=0.5, color='purple')
axes[0][4].set_title('codet5-small',fontsize=25, fontweight='bold')
axes[0][4].set_yscale('log')
axes[0][4].tick_params(axis='x', labelsize=15)   
axes[0][4].tick_params(axis='y', labelsize=15)   
#axes[0][4].set_xlim(-60,60)

axes[1][0].hist(data_vdcwe_codet5_base_F, bins=30, alpha=0.5, color='yellow')
axes[1][0].set_title('codet5-base',fontsize=25, fontweight='bold')
axes[1][0].set_yscale('log')
axes[1][0].tick_params(axis='x', labelsize=15)   
axes[1][0].tick_params(axis='y', labelsize=15)  # 
#axes[1][0].set_xlim(-60,60)
axes[1][1].hist(data_vdcwe_codet5_large_F, bins=30, alpha=0.5, color='green')
axes[1][1].set_title('codet5-large',fontsize=25, fontweight='bold')
axes[1][1].set_yscale('log')
axes[1][1].tick_params(axis='x', labelsize=15)   
axes[1][1].tick_params(axis='y', labelsize=15)   
#axes[1][1].set_xlim(-60,60)

axes[1][2].hist(data_vdcwe_polycoder_small_F, bins=30, alpha=0.5, color='purple')
axes[1][2].set_title('polycoder-small',fontsize=25, fontweight='bold')
axes[1][2].set_yscale('log')
axes[1][2].tick_params(axis='x', labelsize=15)   
axes[1][2].tick_params(axis='y', labelsize=15)   
#axes[1][2].set_xlim(-60,60)

axes[1][3].hist(data_vdcwe_polycoder_base_F, bins=30, alpha=0.5, color='orange')
axes[1][3].set_title('polycoder-base',fontsize=25, fontweight='bold')
axes[1][3].set_yscale('log')
axes[1][3].tick_params(axis='x', labelsize=15)   
axes[1][3].tick_params(axis='y', labelsize=15)   
#axes[1][3].set_xlim(-60,60)

axes[1][4].hist(data_vdcwe_polycoder_large_F, bins=30, alpha=0.5, color='red')
axes[1][4].set_title('polycoder-large',fontsize=25, fontweight='bold')
axes[1][4].set_yscale('log')
axes[1][4].tick_params(axis='x', labelsize=15)   
axes[1][4].tick_params(axis='y', labelsize=15)   
#axes[1][4].set_xlim(-60,60)

#  
for ax in axes.flat:
    ax.yaxis.grid(True, linestyle='dashed')
    
#  
plt.tight_layout()

#  
plt.savefig('rq2-2-test.png', dpi=350,bbox_inches = 'tight')
plt.show()
