# %%
import numpy as np
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from scipy.stats import kendalltau
import statistics 
import pandas as pd

# %%
def readfile(filepath):
    with open(filepath, 'r') as f:
        data = f.readlines()
        data = [float(i.strip()) for i in data[0].split(',')[:-1]]
        #data = data[0]
        #data = [i for i in data.split(',')]
        #data = [float(i) for i in data[0].split(',')]
    return data

# %%
codebert4vdcwe_small = 'codebert4vdcwe-small/'
codebert4vdcwe_base = 'codebert4vdcwe-base/'
codegen4vdcwe_small = 'codegen4vdcwe-small/'
codegen4vdcwe_base = 'codegen4vdcwe-base/'
codet54vdcwe_small = 'codet54vdcwe-small/'
codet54vdcwe_base = 'codet54vdcwe-base/'
codet54vdcwe_large = 'codet54vdcwe-large/'
polycoder4vdcwe_small = 'polycoder4vdcwe-small/'
polycoder4vdcwe_base = 'polycoder4vdcwe-base/'
polycoder4vdcwe_large = 'polycoder4vdcwe-large/'


'''
trained_codexglue_path = 'DAP/trained_codexglue/'
trained_reveal_path = 'DAP/trained_reveal/'
trained_cwe119_path = 'DAP/trained_cwe119/'
trained_cwe399_path = 'DAP/trained_cwe399/'
'''
# Out:
# "\ntrained_codexglue_path = 'DAP/trained_codexglue/'\ntrained_reveal_path = 'DAP/trained_reveal/'\ntrained_cwe119_path = 'DAP/trained_cwe119/'\ntrained_cwe399_path = 'DAP/trained_cwe399/'\n"

# %%
trained_codexglue_path = {}
trained_reveal_path = {}
trained_cwe119_path = {}
trained_cwe399_path = {}
for i in range(200):  
    trained_codexglue_path[i] = 'DAP/trained_codexglue/{}/'.format(i)
    trained_reveal_path[i] = 'DAP/trained_reveal/{}/'.format(i)
    trained_cwe119_path[i] = 'DAP/trained_cwe119/{}/'.format(i)
    trained_cwe399_path[i] = 'DAP/trained_cwe399/{}/'.format(i)
print(trained_codexglue_path[0])
# Out:
# DAP/trained_codexglue/0/

# %%
codebert4vdcwe_small_codexglue_acc = {}
codebert4vdcwe_small_codexglue_pre = {}
codebert4vdcwe_small_codexglue_rec = {}
codebert4vdcwe_small_codexglue_f1 = {}
codebert4vdcwe_small_codexglue_auc = {}
codebert4vdcwe_small_codexglue_mcc = {}
codebert4vdcwe_small_codexglue_auc_pr = {}

for i in range(200):  
    codebert4vdcwe_small_codexglue_acc[i] = readfile(codebert4vdcwe_small+trained_codexglue_path[i]+'model_auc-acc-performance.txt')
    codebert4vdcwe_small_codexglue_pre[i] = readfile(codebert4vdcwe_small+trained_codexglue_path[i]+'model_auc-pre-performance.txt')
    codebert4vdcwe_small_codexglue_rec[i] = readfile(codebert4vdcwe_small+trained_codexglue_path[i]+'model_auc-rec-performance.txt')
    codebert4vdcwe_small_codexglue_f1[i] = readfile(codebert4vdcwe_small+trained_codexglue_path[i]+'model_auc-f1-performance.txt')
    codebert4vdcwe_small_codexglue_auc[i] = readfile(codebert4vdcwe_small+trained_codexglue_path[i]+'model_auc-auc-performance.txt')
    codebert4vdcwe_small_codexglue_mcc[i] = readfile(codebert4vdcwe_small+trained_codexglue_path[i]+'model_auc-mcc-performance.txt')
    codebert4vdcwe_small_codexglue_auc_pr[i] = readfile(codebert4vdcwe_small+trained_codexglue_path[i]+'model_auc-auc_pr-performance.txt')


codebert4vdcwe_base_codexglue_acc = {}
codebert4vdcwe_base_codexglue_pre = {}
codebert4vdcwe_base_codexglue_rec = {}
codebert4vdcwe_base_codexglue_f1 = {}
codebert4vdcwe_base_codexglue_auc = {}
codebert4vdcwe_base_codexglue_mcc = {}
codebert4vdcwe_base_codexglue_auc_pr = {}

for i in range(200):  
    codebert4vdcwe_base_codexglue_acc[i] = readfile(codebert4vdcwe_base+trained_codexglue_path[i]+'model_auc-acc-performance.txt')
    codebert4vdcwe_base_codexglue_pre[i] = readfile(codebert4vdcwe_base+trained_codexglue_path[i]+'model_auc-pre-performance.txt')
    codebert4vdcwe_base_codexglue_rec[i] = readfile(codebert4vdcwe_base+trained_codexglue_path[i]+'model_auc-rec-performance.txt')
    codebert4vdcwe_base_codexglue_f1[i] = readfile(codebert4vdcwe_base+trained_codexglue_path[i]+'model_auc-f1-performance.txt')
    codebert4vdcwe_base_codexglue_auc[i] = readfile(codebert4vdcwe_base+trained_codexglue_path[i]+'model_auc-auc-performance.txt')
    codebert4vdcwe_base_codexglue_mcc[i] = readfile(codebert4vdcwe_base+trained_codexglue_path[i]+'model_auc-mcc-performance.txt')
    codebert4vdcwe_base_codexglue_auc_pr[i] = readfile(codebert4vdcwe_base+trained_codexglue_path[i]+'model_auc-auc_pr-performance.txt')


codegen4vdcwe_small_codexglue_acc = {}
codegen4vdcwe_small_codexglue_pre = {}
codegen4vdcwe_small_codexglue_rec = {}
codegen4vdcwe_small_codexglue_f1 = {}
codegen4vdcwe_small_codexglue_auc = {}
codegen4vdcwe_small_codexglue_mcc = {}
codegen4vdcwe_small_codexglue_auc_pr = {}

for i in range(200):  
    codegen4vdcwe_small_codexglue_acc[i] = readfile(codegen4vdcwe_small+trained_codexglue_path[i]+'model_auc-acc-performance.txt')
    codegen4vdcwe_small_codexglue_pre[i] = readfile(codegen4vdcwe_small+trained_codexglue_path[i]+'model_auc-pre-performance.txt')
    codegen4vdcwe_small_codexglue_rec[i] = readfile(codegen4vdcwe_small+trained_codexglue_path[i]+'model_auc-rec-performance.txt')
    codegen4vdcwe_small_codexglue_f1[i] = readfile(codegen4vdcwe_small+trained_codexglue_path[i]+'model_auc-f1-performance.txt')
    codegen4vdcwe_small_codexglue_auc[i] = readfile(codegen4vdcwe_small+trained_codexglue_path[i]+'model_auc-auc-performance.txt')
    codegen4vdcwe_small_codexglue_mcc[i] = readfile(codegen4vdcwe_small+trained_codexglue_path[i]+'model_auc-mcc-performance.txt')
    codegen4vdcwe_small_codexglue_auc_pr[i] = readfile(codegen4vdcwe_small+trained_codexglue_path[i]+'model_auc-auc_pr-performance.txt')

codegen4vdcwe_base_codexglue_acc = {}
codegen4vdcwe_base_codexglue_pre = {}
codegen4vdcwe_base_codexglue_rec = {}
codegen4vdcwe_base_codexglue_f1 = {}
codegen4vdcwe_base_codexglue_auc = {}
codegen4vdcwe_base_codexglue_mcc = {}
codegen4vdcwe_base_codexglue_auc_pr = {}

for i in range(200):  

    codegen4vdcwe_base_codexglue_acc[i] = readfile(codegen4vdcwe_base+trained_codexglue_path[i]+'model_auc-acc-performance.txt')
    codegen4vdcwe_base_codexglue_pre[i] = readfile(codegen4vdcwe_base+trained_codexglue_path[i]+'model_auc-pre-performance.txt')
    codegen4vdcwe_base_codexglue_rec[i] = readfile(codegen4vdcwe_base+trained_codexglue_path[i]+'model_auc-rec-performance.txt')
    codegen4vdcwe_base_codexglue_f1[i] = readfile(codegen4vdcwe_base+trained_codexglue_path[i]+'model_auc-f1-performance.txt')
    codegen4vdcwe_base_codexglue_auc[i] = readfile(codegen4vdcwe_base+trained_codexglue_path[i]+'model_auc-auc-performance.txt')
    codegen4vdcwe_base_codexglue_mcc[i] = readfile(codegen4vdcwe_base+trained_codexglue_path[i]+'model_auc-mcc-performance.txt')
    codegen4vdcwe_base_codexglue_auc_pr[i] = readfile(codegen4vdcwe_base+trained_codexglue_path[i]+'model_auc-auc_pr-performance.txt')

codet54vdcwe_small_codexglue_acc = {}
codet54vdcwe_small_codexglue_pre = {}
codet54vdcwe_small_codexglue_rec = {}
codet54vdcwe_small_codexglue_f1 = {}
codet54vdcwe_small_codexglue_auc = {}
codet54vdcwe_small_codexglue_mcc = {}
codet54vdcwe_small_codexglue_auc_pr = {}

for i in range(200):  
    codet54vdcwe_small_codexglue_acc[i] = readfile(codet54vdcwe_small+trained_codexglue_path[i]+'model_auc-acc-performance.txt')
    codet54vdcwe_small_codexglue_pre[i] = readfile(codet54vdcwe_small+trained_codexglue_path[i]+'model_auc-pre-performance.txt')
    codet54vdcwe_small_codexglue_rec[i] = readfile(codet54vdcwe_small+trained_codexglue_path[i]+'model_auc-rec-performance.txt')
    codet54vdcwe_small_codexglue_f1[i] = readfile(codet54vdcwe_small+trained_codexglue_path[i]+'model_auc-f1-performance.txt')
    codet54vdcwe_small_codexglue_auc[i] = readfile(codet54vdcwe_small+trained_codexglue_path[i]+'model_auc-auc-performance.txt')
    codet54vdcwe_small_codexglue_mcc[i] = readfile(codet54vdcwe_small+trained_codexglue_path[i]+'model_auc-mcc-performance.txt')
    codet54vdcwe_small_codexglue_auc_pr[i] = readfile(codet54vdcwe_small+trained_codexglue_path[i]+'model_auc-auc_pr-performance.txt')

    
codet54vdcwe_base_codexglue_acc = {}
codet54vdcwe_base_codexglue_pre = {}
codet54vdcwe_base_codexglue_rec = {}
codet54vdcwe_base_codexglue_f1 = {}
codet54vdcwe_base_codexglue_auc = {}
codet54vdcwe_base_codexglue_mcc = {}
codet54vdcwe_base_codexglue_auc_pr = {}

for i in range(200):  
    codet54vdcwe_base_codexglue_acc[i] = readfile(codet54vdcwe_base+trained_codexglue_path[i]+'model_auc-acc-performance.txt')
    codet54vdcwe_base_codexglue_pre[i] = readfile(codet54vdcwe_base+trained_codexglue_path[i]+'model_auc-pre-performance.txt')
    codet54vdcwe_base_codexglue_rec[i] = readfile(codet54vdcwe_base+trained_codexglue_path[i]+'model_auc-rec-performance.txt')
    codet54vdcwe_base_codexglue_f1[i] = readfile(codet54vdcwe_base+trained_codexglue_path[i]+'model_auc-f1-performance.txt')
    codet54vdcwe_base_codexglue_auc[i] = readfile(codet54vdcwe_base+trained_codexglue_path[i]+'model_auc-auc-performance.txt')
    codet54vdcwe_base_codexglue_mcc[i] = readfile(codet54vdcwe_base+trained_codexglue_path[i]+'model_auc-mcc-performance.txt')
    codet54vdcwe_base_codexglue_auc_pr[i] = readfile(codet54vdcwe_base+trained_codexglue_path[i]+'model_auc-auc_pr-performance.txt')

    
codet54vdcwe_large_codexglue_acc = {}
codet54vdcwe_large_codexglue_pre = {}
codet54vdcwe_large_codexglue_rec = {}
codet54vdcwe_large_codexglue_f1 = {}
codet54vdcwe_large_codexglue_auc = {}
codet54vdcwe_large_codexglue_mcc = {}
codet54vdcwe_large_codexglue_auc_pr = {}

for i in range(200):  
    codet54vdcwe_large_codexglue_acc[i] = readfile(codet54vdcwe_large+trained_codexglue_path[i]+'model_auc-acc-performance.txt')
    codet54vdcwe_large_codexglue_pre[i] = readfile(codet54vdcwe_large+trained_codexglue_path[i]+'model_auc-pre-performance.txt')
    codet54vdcwe_large_codexglue_rec[i] = readfile(codet54vdcwe_large+trained_codexglue_path[i]+'model_auc-rec-performance.txt')
    codet54vdcwe_large_codexglue_f1[i] = readfile(codet54vdcwe_large+trained_codexglue_path[i]+'model_auc-f1-performance.txt')
    codet54vdcwe_large_codexglue_auc[i] = readfile(codet54vdcwe_large+trained_codexglue_path[i]+'model_auc-auc-performance.txt')
    codet54vdcwe_large_codexglue_mcc[i] = readfile(codet54vdcwe_large+trained_codexglue_path[i]+'model_auc-mcc-performance.txt')
    codet54vdcwe_large_codexglue_auc_pr[i] = readfile(codet54vdcwe_large+trained_codexglue_path[i]+'model_auc-auc_pr-performance.txt')


polycoder4vdcwe_small_codexglue_acc = {}
polycoder4vdcwe_small_codexglue_pre = {}
polycoder4vdcwe_small_codexglue_rec = {}
polycoder4vdcwe_small_codexglue_f1 = {}
polycoder4vdcwe_small_codexglue_auc = {}
polycoder4vdcwe_small_codexglue_mcc = {}
polycoder4vdcwe_small_codexglue_auc_pr = {}

for i in range(200):  
    polycoder4vdcwe_small_codexglue_acc[i] = readfile(polycoder4vdcwe_small+trained_codexglue_path[i]+'model_auc-acc-performance.txt')
    polycoder4vdcwe_small_codexglue_pre[i] = readfile(polycoder4vdcwe_small+trained_codexglue_path[i]+'model_auc-pre-performance.txt')
    polycoder4vdcwe_small_codexglue_rec[i] = readfile(polycoder4vdcwe_small+trained_codexglue_path[i]+'model_auc-rec-performance.txt')
    polycoder4vdcwe_small_codexglue_f1[i] = readfile(polycoder4vdcwe_small+trained_codexglue_path[i]+'model_auc-f1-performance.txt')
    polycoder4vdcwe_small_codexglue_auc[i] = readfile(polycoder4vdcwe_small+trained_codexglue_path[i]+'model_auc-auc-performance.txt')
    polycoder4vdcwe_small_codexglue_mcc[i] = readfile(polycoder4vdcwe_small+trained_codexglue_path[i]+'model_auc-mcc-performance.txt')
    polycoder4vdcwe_small_codexglue_auc_pr[i] = readfile(polycoder4vdcwe_small+trained_codexglue_path[i]+'model_auc-auc_pr-performance.txt')
    
    
    
    
polycoder4vdcwe_base_codexglue_acc = {}
polycoder4vdcwe_base_codexglue_pre = {}
polycoder4vdcwe_base_codexglue_rec = {}
polycoder4vdcwe_base_codexglue_f1 = {}
polycoder4vdcwe_base_codexglue_auc = {}
polycoder4vdcwe_base_codexglue_mcc = {}
polycoder4vdcwe_base_codexglue_auc_pr = {}

for i in range(200):  
    polycoder4vdcwe_base_codexglue_acc[i] = readfile(polycoder4vdcwe_base+trained_codexglue_path[i]+'model_auc-acc-performance.txt')
    polycoder4vdcwe_base_codexglue_pre[i] = readfile(polycoder4vdcwe_base+trained_codexglue_path[i]+'model_auc-pre-performance.txt')
    polycoder4vdcwe_base_codexglue_rec[i] = readfile(polycoder4vdcwe_base+trained_codexglue_path[i]+'model_auc-rec-performance.txt')
    polycoder4vdcwe_base_codexglue_f1[i] = readfile(polycoder4vdcwe_base+trained_codexglue_path[i]+'model_auc-f1-performance.txt')
    polycoder4vdcwe_base_codexglue_auc[i] = readfile(polycoder4vdcwe_base+trained_codexglue_path[i]+'model_auc-auc-performance.txt')
    polycoder4vdcwe_base_codexglue_mcc[i] = readfile(polycoder4vdcwe_base+trained_codexglue_path[i]+'model_auc-mcc-performance.txt')
    polycoder4vdcwe_base_codexglue_auc_pr[i] = readfile(polycoder4vdcwe_base+trained_codexglue_path[i]+'model_auc-auc_pr-performance.txt')
    
    
polycoder4vdcwe_large_codexglue_acc = {}
polycoder4vdcwe_large_codexglue_pre = {}
polycoder4vdcwe_large_codexglue_rec = {}
polycoder4vdcwe_large_codexglue_f1 = {}
polycoder4vdcwe_large_codexglue_auc = {}
polycoder4vdcwe_large_codexglue_mcc = {}
polycoder4vdcwe_large_codexglue_auc_pr = {}

for i in range(200):  
    polycoder4vdcwe_large_codexglue_acc[i] = readfile(polycoder4vdcwe_large+trained_codexglue_path[i]+'model_auc-acc-performance.txt')
    polycoder4vdcwe_large_codexglue_pre[i] = readfile(polycoder4vdcwe_large+trained_codexglue_path[i]+'model_auc-pre-performance.txt')
    polycoder4vdcwe_large_codexglue_rec[i] = readfile(polycoder4vdcwe_large+trained_codexglue_path[i]+'model_auc-rec-performance.txt')
    polycoder4vdcwe_large_codexglue_f1[i] = readfile(polycoder4vdcwe_large+trained_codexglue_path[i]+'model_auc-f1-performance.txt')
    polycoder4vdcwe_large_codexglue_auc[i] = readfile(polycoder4vdcwe_large+trained_codexglue_path[i]+'model_auc-auc-performance.txt')
    polycoder4vdcwe_large_codexglue_mcc[i] = readfile(polycoder4vdcwe_large+trained_codexglue_path[i]+'model_auc-mcc-performance.txt')
    polycoder4vdcwe_large_codexglue_auc_pr[i] = readfile(polycoder4vdcwe_large+trained_codexglue_path[i]+'model_auc-auc_pr-performance.txt')

# %%
codebert4vdcwe_small_reveal_acc = {}
codebert4vdcwe_small_reveal_pre = {}
codebert4vdcwe_small_reveal_rec = {}
codebert4vdcwe_small_reveal_f1 = {}
codebert4vdcwe_small_reveal_auc = {}
codebert4vdcwe_small_reveal_mcc = {}
codebert4vdcwe_small_reveal_auc_pr = {}

for i in range(200):  
    codebert4vdcwe_small_reveal_acc[i] = readfile(codebert4vdcwe_small+trained_reveal_path[i]+'model_auc-acc-performance.txt')
    codebert4vdcwe_small_reveal_pre[i] = readfile(codebert4vdcwe_small+trained_reveal_path[i]+'model_auc-pre-performance.txt')
    codebert4vdcwe_small_reveal_rec[i] = readfile(codebert4vdcwe_small+trained_reveal_path[i]+'model_auc-rec-performance.txt')
    codebert4vdcwe_small_reveal_f1[i] = readfile(codebert4vdcwe_small+trained_reveal_path[i]+'model_auc-f1-performance.txt')
    codebert4vdcwe_small_reveal_auc[i] = readfile(codebert4vdcwe_small+trained_reveal_path[i]+'model_auc-auc-performance.txt')
    codebert4vdcwe_small_reveal_mcc[i] = readfile(codebert4vdcwe_small+trained_reveal_path[i]+'model_auc-mcc-performance.txt')
    codebert4vdcwe_small_reveal_auc_pr[i] = readfile(codebert4vdcwe_small+trained_reveal_path[i]+'model_auc-auc_pr-performance.txt')


codebert4vdcwe_base_reveal_acc = {}
codebert4vdcwe_base_reveal_pre = {}
codebert4vdcwe_base_reveal_rec = {}
codebert4vdcwe_base_reveal_f1 = {}
codebert4vdcwe_base_reveal_auc = {}
codebert4vdcwe_base_reveal_mcc = {}
codebert4vdcwe_base_reveal_auc_pr = {}

for i in range(200):  
    codebert4vdcwe_base_reveal_acc[i] = readfile(codebert4vdcwe_base+trained_reveal_path[i]+'model_auc-acc-performance.txt')
    codebert4vdcwe_base_reveal_pre[i] = readfile(codebert4vdcwe_base+trained_reveal_path[i]+'model_auc-pre-performance.txt')
    codebert4vdcwe_base_reveal_rec[i] = readfile(codebert4vdcwe_base+trained_reveal_path[i]+'model_auc-rec-performance.txt')
    codebert4vdcwe_base_reveal_f1[i] = readfile(codebert4vdcwe_base+trained_reveal_path[i]+'model_auc-f1-performance.txt')
    codebert4vdcwe_base_reveal_auc[i] = readfile(codebert4vdcwe_base+trained_reveal_path[i]+'model_auc-auc-performance.txt')
    codebert4vdcwe_base_reveal_mcc[i] = readfile(codebert4vdcwe_base+trained_reveal_path[i]+'model_auc-mcc-performance.txt')
    codebert4vdcwe_base_reveal_auc_pr[i] = readfile(codebert4vdcwe_base+trained_reveal_path[i]+'model_auc-auc_pr-performance.txt')


codegen4vdcwe_small_reveal_acc = {}
codegen4vdcwe_small_reveal_pre = {}
codegen4vdcwe_small_reveal_rec = {}
codegen4vdcwe_small_reveal_f1 = {}
codegen4vdcwe_small_reveal_auc = {}
codegen4vdcwe_small_reveal_mcc = {}
codegen4vdcwe_small_reveal_auc_pr = {}

for i in range(200):  
    codegen4vdcwe_small_reveal_acc[i] = readfile(codegen4vdcwe_small+trained_reveal_path[i]+'model_auc-acc-performance.txt')
    codegen4vdcwe_small_reveal_pre[i] = readfile(codegen4vdcwe_small+trained_reveal_path[i]+'model_auc-pre-performance.txt')
    codegen4vdcwe_small_reveal_rec[i] = readfile(codegen4vdcwe_small+trained_reveal_path[i]+'model_auc-rec-performance.txt')
    codegen4vdcwe_small_reveal_f1[i] = readfile(codegen4vdcwe_small+trained_reveal_path[i]+'model_auc-f1-performance.txt')
    codegen4vdcwe_small_reveal_auc[i] = readfile(codegen4vdcwe_small+trained_reveal_path[i]+'model_auc-auc-performance.txt')
    codegen4vdcwe_small_reveal_mcc[i] = readfile(codegen4vdcwe_small+trained_reveal_path[i]+'model_auc-mcc-performance.txt')
    codegen4vdcwe_small_reveal_auc_pr[i] = readfile(codegen4vdcwe_small+trained_reveal_path[i]+'model_auc-auc_pr-performance.txt')

codegen4vdcwe_base_reveal_acc = {}
codegen4vdcwe_base_reveal_pre = {}
codegen4vdcwe_base_reveal_rec = {}
codegen4vdcwe_base_reveal_f1 = {}
codegen4vdcwe_base_reveal_auc = {}
codegen4vdcwe_base_reveal_mcc = {}
codegen4vdcwe_base_reveal_auc_pr = {}

for i in range(200):  

    codegen4vdcwe_base_reveal_acc[i] = readfile(codegen4vdcwe_base+trained_reveal_path[i]+'model_auc-acc-performance.txt')
    codegen4vdcwe_base_reveal_pre[i] = readfile(codegen4vdcwe_base+trained_reveal_path[i]+'model_auc-pre-performance.txt')
    codegen4vdcwe_base_reveal_rec[i] = readfile(codegen4vdcwe_base+trained_reveal_path[i]+'model_auc-rec-performance.txt')
    codegen4vdcwe_base_reveal_f1[i] = readfile(codegen4vdcwe_base+trained_reveal_path[i]+'model_auc-f1-performance.txt')
    codegen4vdcwe_base_reveal_auc[i] = readfile(codegen4vdcwe_base+trained_reveal_path[i]+'model_auc-auc-performance.txt')
    codegen4vdcwe_base_reveal_mcc[i] = readfile(codegen4vdcwe_base+trained_reveal_path[i]+'model_auc-mcc-performance.txt')
    codegen4vdcwe_base_reveal_auc_pr[i] = readfile(codegen4vdcwe_base+trained_reveal_path[i]+'model_auc-auc_pr-performance.txt')

    
    
codet54vdcwe_small_reveal_acc = {}
codet54vdcwe_small_reveal_pre = {}
codet54vdcwe_small_reveal_rec = {}
codet54vdcwe_small_reveal_f1 = {}
codet54vdcwe_small_reveal_auc = {}
codet54vdcwe_small_reveal_mcc = {}
codet54vdcwe_small_reveal_auc_pr = {}

for i in range(200):  
    codet54vdcwe_small_reveal_acc[i] = readfile(codet54vdcwe_small+trained_reveal_path[i]+'model_auc-acc-performance.txt')
    codet54vdcwe_small_reveal_pre[i] = readfile(codet54vdcwe_small+trained_reveal_path[i]+'model_auc-pre-performance.txt')
    codet54vdcwe_small_reveal_rec[i] = readfile(codet54vdcwe_small+trained_reveal_path[i]+'model_auc-rec-performance.txt')
    codet54vdcwe_small_reveal_f1[i] = readfile(codet54vdcwe_small+trained_reveal_path[i]+'model_auc-f1-performance.txt')
    codet54vdcwe_small_reveal_auc[i] = readfile(codet54vdcwe_small+trained_reveal_path[i]+'model_auc-auc-performance.txt')
    codet54vdcwe_small_reveal_mcc[i] = readfile(codet54vdcwe_small+trained_reveal_path[i]+'model_auc-mcc-performance.txt')
    codet54vdcwe_small_reveal_auc_pr[i] = readfile(codet54vdcwe_small+trained_reveal_path[i]+'model_auc-auc_pr-performance.txt')

    
codet54vdcwe_base_reveal_acc = {}
codet54vdcwe_base_reveal_pre = {}
codet54vdcwe_base_reveal_rec = {}
codet54vdcwe_base_reveal_f1 = {}
codet54vdcwe_base_reveal_auc = {}
codet54vdcwe_base_reveal_mcc = {}
codet54vdcwe_base_reveal_auc_pr = {}

for i in range(200):  
    codet54vdcwe_base_reveal_acc[i] = readfile(codet54vdcwe_base+trained_reveal_path[i]+'model_auc-acc-performance.txt')
    codet54vdcwe_base_reveal_pre[i] = readfile(codet54vdcwe_base+trained_reveal_path[i]+'model_auc-pre-performance.txt')
    codet54vdcwe_base_reveal_rec[i] = readfile(codet54vdcwe_base+trained_reveal_path[i]+'model_auc-rec-performance.txt')
    codet54vdcwe_base_reveal_f1[i] = readfile(codet54vdcwe_base+trained_reveal_path[i]+'model_auc-f1-performance.txt')
    codet54vdcwe_base_reveal_auc[i] = readfile(codet54vdcwe_base+trained_reveal_path[i]+'model_auc-auc-performance.txt')
    codet54vdcwe_base_reveal_mcc[i] = readfile(codet54vdcwe_base+trained_reveal_path[i]+'model_auc-mcc-performance.txt')
    codet54vdcwe_base_reveal_auc_pr[i] = readfile(codet54vdcwe_base+trained_reveal_path[i]+'model_auc-auc_pr-performance.txt')

    
codet54vdcwe_large_reveal_acc = {}
codet54vdcwe_large_reveal_pre = {}
codet54vdcwe_large_reveal_rec = {}
codet54vdcwe_large_reveal_f1 = {}
codet54vdcwe_large_reveal_auc = {}
codet54vdcwe_large_reveal_mcc = {}
codet54vdcwe_large_reveal_auc_pr = {}

for i in range(200):  
    codet54vdcwe_large_reveal_acc[i] = readfile(codet54vdcwe_large+trained_reveal_path[i]+'model_auc-acc-performance.txt')
    codet54vdcwe_large_reveal_pre[i] = readfile(codet54vdcwe_large+trained_reveal_path[i]+'model_auc-pre-performance.txt')
    codet54vdcwe_large_reveal_rec[i] = readfile(codet54vdcwe_large+trained_reveal_path[i]+'model_auc-rec-performance.txt')
    codet54vdcwe_large_reveal_f1[i] = readfile(codet54vdcwe_large+trained_reveal_path[i]+'model_auc-f1-performance.txt')
    codet54vdcwe_large_reveal_auc[i] = readfile(codet54vdcwe_large+trained_reveal_path[i]+'model_auc-auc-performance.txt')
    codet54vdcwe_large_reveal_mcc[i] = readfile(codet54vdcwe_large+trained_reveal_path[i]+'model_auc-mcc-performance.txt')
    codet54vdcwe_large_reveal_auc_pr[i] = readfile(codet54vdcwe_large+trained_reveal_path[i]+'model_auc-auc_pr-performance.txt')


polycoder4vdcwe_small_reveal_acc = {}
polycoder4vdcwe_small_reveal_pre = {}
polycoder4vdcwe_small_reveal_rec = {}
polycoder4vdcwe_small_reveal_f1 = {}
polycoder4vdcwe_small_reveal_auc = {}
polycoder4vdcwe_small_reveal_mcc = {}
polycoder4vdcwe_small_reveal_auc_pr = {}

for i in range(200):  
    polycoder4vdcwe_small_reveal_acc[i] = readfile(polycoder4vdcwe_small+trained_reveal_path[i]+'model_auc-acc-performance.txt')
    polycoder4vdcwe_small_reveal_pre[i] = readfile(polycoder4vdcwe_small+trained_reveal_path[i]+'model_auc-pre-performance.txt')
    polycoder4vdcwe_small_reveal_rec[i] = readfile(polycoder4vdcwe_small+trained_reveal_path[i]+'model_auc-rec-performance.txt')
    polycoder4vdcwe_small_reveal_f1[i] = readfile(polycoder4vdcwe_small+trained_reveal_path[i]+'model_auc-f1-performance.txt')
    polycoder4vdcwe_small_reveal_auc[i] = readfile(polycoder4vdcwe_small+trained_reveal_path[i]+'model_auc-auc-performance.txt')
    polycoder4vdcwe_small_reveal_mcc[i] = readfile(polycoder4vdcwe_small+trained_reveal_path[i]+'model_auc-mcc-performance.txt')
    polycoder4vdcwe_small_reveal_auc_pr[i] = readfile(polycoder4vdcwe_small+trained_reveal_path[i]+'model_auc-auc_pr-performance.txt')
    
    
    
    
polycoder4vdcwe_base_reveal_acc = {}
polycoder4vdcwe_base_reveal_pre = {}
polycoder4vdcwe_base_reveal_rec = {}
polycoder4vdcwe_base_reveal_f1 = {}
polycoder4vdcwe_base_reveal_auc = {}
polycoder4vdcwe_base_reveal_mcc = {}
polycoder4vdcwe_base_reveal_auc_pr = {}

for i in range(200):  
    polycoder4vdcwe_base_reveal_acc[i] = readfile(polycoder4vdcwe_base+trained_reveal_path[i]+'model_auc-acc-performance.txt')
    polycoder4vdcwe_base_reveal_pre[i] = readfile(polycoder4vdcwe_base+trained_reveal_path[i]+'model_auc-pre-performance.txt')
    polycoder4vdcwe_base_reveal_rec[i] = readfile(polycoder4vdcwe_base+trained_reveal_path[i]+'model_auc-rec-performance.txt')
    polycoder4vdcwe_base_reveal_f1[i] = readfile(polycoder4vdcwe_base+trained_reveal_path[i]+'model_auc-f1-performance.txt')
    polycoder4vdcwe_base_reveal_auc[i] = readfile(polycoder4vdcwe_base+trained_reveal_path[i]+'model_auc-auc-performance.txt')
    polycoder4vdcwe_base_reveal_mcc[i] = readfile(polycoder4vdcwe_base+trained_reveal_path[i]+'model_auc-mcc-performance.txt')
    polycoder4vdcwe_base_reveal_auc_pr[i] = readfile(polycoder4vdcwe_base+trained_reveal_path[i]+'model_auc-auc_pr-performance.txt')
    
    
polycoder4vdcwe_large_reveal_acc = {}
polycoder4vdcwe_large_reveal_pre = {}
polycoder4vdcwe_large_reveal_rec = {}
polycoder4vdcwe_large_reveal_f1 = {}
polycoder4vdcwe_large_reveal_auc = {}
polycoder4vdcwe_large_reveal_mcc = {}
polycoder4vdcwe_large_reveal_auc_pr = {}

for i in range(200):  
    polycoder4vdcwe_large_reveal_acc[i] = readfile(polycoder4vdcwe_large+trained_reveal_path[i]+'model_auc-acc-performance.txt')
    polycoder4vdcwe_large_reveal_pre[i] = readfile(polycoder4vdcwe_large+trained_reveal_path[i]+'model_auc-pre-performance.txt')
    polycoder4vdcwe_large_reveal_rec[i] = readfile(polycoder4vdcwe_large+trained_reveal_path[i]+'model_auc-rec-performance.txt')
    polycoder4vdcwe_large_reveal_f1[i] = readfile(polycoder4vdcwe_large+trained_reveal_path[i]+'model_auc-f1-performance.txt')
    polycoder4vdcwe_large_reveal_auc[i] = readfile(polycoder4vdcwe_large+trained_reveal_path[i]+'model_auc-auc-performance.txt')
    polycoder4vdcwe_large_reveal_mcc[i] = readfile(polycoder4vdcwe_large+trained_reveal_path[i]+'model_auc-mcc-performance.txt')
    polycoder4vdcwe_large_reveal_auc_pr[i] = readfile(polycoder4vdcwe_large+trained_reveal_path[i]+'model_auc-auc_pr-performance.txt')

# %%
codebert4vdcwe_small_cwe119_acc = {}
codebert4vdcwe_small_cwe119_pre = {}
codebert4vdcwe_small_cwe119_rec = {}
codebert4vdcwe_small_cwe119_f1 = {}
codebert4vdcwe_small_cwe119_auc = {}
codebert4vdcwe_small_cwe119_mcc = {}
codebert4vdcwe_small_cwe119_auc_pr = {}

for i in range(200):  
    codebert4vdcwe_small_cwe119_acc[i] = readfile(codebert4vdcwe_small+trained_cwe119_path[i]+'model_auc-acc-performance.txt')
    codebert4vdcwe_small_cwe119_pre[i] = readfile(codebert4vdcwe_small+trained_cwe119_path[i]+'model_auc-pre-performance.txt')
    codebert4vdcwe_small_cwe119_rec[i] = readfile(codebert4vdcwe_small+trained_cwe119_path[i]+'model_auc-rec-performance.txt')
    codebert4vdcwe_small_cwe119_f1[i] = readfile(codebert4vdcwe_small+trained_cwe119_path[i]+'model_auc-f1-performance.txt')
    codebert4vdcwe_small_cwe119_auc[i] = readfile(codebert4vdcwe_small+trained_cwe119_path[i]+'model_auc-auc-performance.txt')
    codebert4vdcwe_small_cwe119_mcc[i] = readfile(codebert4vdcwe_small+trained_cwe119_path[i]+'model_auc-mcc-performance.txt')
    codebert4vdcwe_small_cwe119_auc_pr[i] = readfile(codebert4vdcwe_small+trained_cwe119_path[i]+'model_auc-auc_pr-performance.txt')


codebert4vdcwe_base_cwe119_acc = {}
codebert4vdcwe_base_cwe119_pre = {}
codebert4vdcwe_base_cwe119_rec = {}
codebert4vdcwe_base_cwe119_f1 = {}
codebert4vdcwe_base_cwe119_auc = {}
codebert4vdcwe_base_cwe119_mcc = {}
codebert4vdcwe_base_cwe119_auc_pr = {}

for i in range(200):  
    codebert4vdcwe_base_cwe119_acc[i] = readfile(codebert4vdcwe_base+trained_cwe119_path[i]+'model_auc-acc-performance.txt')
    codebert4vdcwe_base_cwe119_pre[i] = readfile(codebert4vdcwe_base+trained_cwe119_path[i]+'model_auc-pre-performance.txt')
    codebert4vdcwe_base_cwe119_rec[i] = readfile(codebert4vdcwe_base+trained_cwe119_path[i]+'model_auc-rec-performance.txt')
    codebert4vdcwe_base_cwe119_f1[i] = readfile(codebert4vdcwe_base+trained_cwe119_path[i]+'model_auc-f1-performance.txt')
    codebert4vdcwe_base_cwe119_auc[i] = readfile(codebert4vdcwe_base+trained_cwe119_path[i]+'model_auc-auc-performance.txt')
    codebert4vdcwe_base_cwe119_mcc[i] = readfile(codebert4vdcwe_base+trained_cwe119_path[i]+'model_auc-mcc-performance.txt')
    codebert4vdcwe_base_cwe119_auc_pr[i] = readfile(codebert4vdcwe_base+trained_cwe119_path[i]+'model_auc-auc_pr-performance.txt')


codegen4vdcwe_small_cwe119_acc = {}
codegen4vdcwe_small_cwe119_pre = {}
codegen4vdcwe_small_cwe119_rec = {}
codegen4vdcwe_small_cwe119_f1 = {}
codegen4vdcwe_small_cwe119_auc = {}
codegen4vdcwe_small_cwe119_mcc = {}
codegen4vdcwe_small_cwe119_auc_pr = {}

for i in range(200):  
    codegen4vdcwe_small_cwe119_acc[i] = readfile(codegen4vdcwe_small+trained_cwe119_path[i]+'model_auc-acc-performance.txt')
    codegen4vdcwe_small_cwe119_pre[i] = readfile(codegen4vdcwe_small+trained_cwe119_path[i]+'model_auc-pre-performance.txt')
    codegen4vdcwe_small_cwe119_rec[i] = readfile(codegen4vdcwe_small+trained_cwe119_path[i]+'model_auc-rec-performance.txt')
    codegen4vdcwe_small_cwe119_f1[i] = readfile(codegen4vdcwe_small+trained_cwe119_path[i]+'model_auc-f1-performance.txt')
    codegen4vdcwe_small_cwe119_auc[i] = readfile(codegen4vdcwe_small+trained_cwe119_path[i]+'model_auc-auc-performance.txt')
    codegen4vdcwe_small_cwe119_mcc[i] = readfile(codegen4vdcwe_small+trained_cwe119_path[i]+'model_auc-mcc-performance.txt')
    codegen4vdcwe_small_cwe119_auc_pr[i] = readfile(codegen4vdcwe_small+trained_cwe119_path[i]+'model_auc-auc_pr-performance.txt')

codegen4vdcwe_base_cwe119_acc = {}
codegen4vdcwe_base_cwe119_pre = {}
codegen4vdcwe_base_cwe119_rec = {}
codegen4vdcwe_base_cwe119_f1 = {}
codegen4vdcwe_base_cwe119_auc = {}
codegen4vdcwe_base_cwe119_mcc = {}
codegen4vdcwe_base_cwe119_auc_pr = {}

for i in range(200):  

    codegen4vdcwe_base_cwe119_acc[i] = readfile(codegen4vdcwe_base+trained_cwe119_path[i]+'model_auc-acc-performance.txt')
    codegen4vdcwe_base_cwe119_pre[i] = readfile(codegen4vdcwe_base+trained_cwe119_path[i]+'model_auc-pre-performance.txt')
    codegen4vdcwe_base_cwe119_rec[i] = readfile(codegen4vdcwe_base+trained_cwe119_path[i]+'model_auc-rec-performance.txt')
    codegen4vdcwe_base_cwe119_f1[i] = readfile(codegen4vdcwe_base+trained_cwe119_path[i]+'model_auc-f1-performance.txt')
    codegen4vdcwe_base_cwe119_auc[i] = readfile(codegen4vdcwe_base+trained_cwe119_path[i]+'model_auc-auc-performance.txt')
    codegen4vdcwe_base_cwe119_mcc[i] = readfile(codegen4vdcwe_base+trained_cwe119_path[i]+'model_auc-mcc-performance.txt')
    codegen4vdcwe_base_cwe119_auc_pr[i] = readfile(codegen4vdcwe_base+trained_cwe119_path[i]+'model_auc-auc_pr-performance.txt')

codet54vdcwe_small_cwe119_acc = {}
codet54vdcwe_small_cwe119_pre = {}
codet54vdcwe_small_cwe119_rec = {}
codet54vdcwe_small_cwe119_f1 = {}
codet54vdcwe_small_cwe119_auc = {}
codet54vdcwe_small_cwe119_mcc = {}
codet54vdcwe_small_cwe119_auc_pr = {}

for i in range(200):  
    codet54vdcwe_small_cwe119_acc[i] = readfile(codet54vdcwe_small+trained_cwe119_path[i]+'model_auc-acc-performance.txt')
    codet54vdcwe_small_cwe119_pre[i] = readfile(codet54vdcwe_small+trained_cwe119_path[i]+'model_auc-pre-performance.txt')
    codet54vdcwe_small_cwe119_rec[i] = readfile(codet54vdcwe_small+trained_cwe119_path[i]+'model_auc-rec-performance.txt')
    codet54vdcwe_small_cwe119_f1[i] = readfile(codet54vdcwe_small+trained_cwe119_path[i]+'model_auc-f1-performance.txt')
    codet54vdcwe_small_cwe119_auc[i] = readfile(codet54vdcwe_small+trained_cwe119_path[i]+'model_auc-auc-performance.txt')
    codet54vdcwe_small_cwe119_mcc[i] = readfile(codet54vdcwe_small+trained_cwe119_path[i]+'model_auc-mcc-performance.txt')
    codet54vdcwe_small_cwe119_auc_pr[i] = readfile(codet54vdcwe_small+trained_cwe119_path[i]+'model_auc-auc_pr-performance.txt')

    
codet54vdcwe_base_cwe119_acc = {}
codet54vdcwe_base_cwe119_pre = {}
codet54vdcwe_base_cwe119_rec = {}
codet54vdcwe_base_cwe119_f1 = {}
codet54vdcwe_base_cwe119_auc = {}
codet54vdcwe_base_cwe119_mcc = {}
codet54vdcwe_base_cwe119_auc_pr = {}

for i in range(200):  
    codet54vdcwe_base_cwe119_acc[i] = readfile(codet54vdcwe_base+trained_cwe119_path[i]+'model_auc-acc-performance.txt')
    codet54vdcwe_base_cwe119_pre[i] = readfile(codet54vdcwe_base+trained_cwe119_path[i]+'model_auc-pre-performance.txt')
    codet54vdcwe_base_cwe119_rec[i] = readfile(codet54vdcwe_base+trained_cwe119_path[i]+'model_auc-rec-performance.txt')
    codet54vdcwe_base_cwe119_f1[i] = readfile(codet54vdcwe_base+trained_cwe119_path[i]+'model_auc-f1-performance.txt')
    codet54vdcwe_base_cwe119_auc[i] = readfile(codet54vdcwe_base+trained_cwe119_path[i]+'model_auc-auc-performance.txt')
    codet54vdcwe_base_cwe119_mcc[i] = readfile(codet54vdcwe_base+trained_cwe119_path[i]+'model_auc-mcc-performance.txt')
    codet54vdcwe_base_cwe119_auc_pr[i] = readfile(codet54vdcwe_base+trained_cwe119_path[i]+'model_auc-auc_pr-performance.txt')

    
codet54vdcwe_large_cwe119_acc = {}
codet54vdcwe_large_cwe119_pre = {}
codet54vdcwe_large_cwe119_rec = {}
codet54vdcwe_large_cwe119_f1 = {}
codet54vdcwe_large_cwe119_auc = {}
codet54vdcwe_large_cwe119_mcc = {}
codet54vdcwe_large_cwe119_auc_pr = {}

for i in range(200):  
    codet54vdcwe_large_cwe119_acc[i] = readfile(codet54vdcwe_large+trained_cwe119_path[i]+'model_auc-acc-performance.txt')
    codet54vdcwe_large_cwe119_pre[i] = readfile(codet54vdcwe_large+trained_cwe119_path[i]+'model_auc-pre-performance.txt')
    codet54vdcwe_large_cwe119_rec[i] = readfile(codet54vdcwe_large+trained_cwe119_path[i]+'model_auc-rec-performance.txt')
    codet54vdcwe_large_cwe119_f1[i] = readfile(codet54vdcwe_large+trained_cwe119_path[i]+'model_auc-f1-performance.txt')
    codet54vdcwe_large_cwe119_auc[i] = readfile(codet54vdcwe_large+trained_cwe119_path[i]+'model_auc-auc-performance.txt')
    codet54vdcwe_large_cwe119_mcc[i] = readfile(codet54vdcwe_large+trained_cwe119_path[i]+'model_auc-mcc-performance.txt')
    codet54vdcwe_large_cwe119_auc_pr[i] = readfile(codet54vdcwe_large+trained_cwe119_path[i]+'model_auc-auc_pr-performance.txt')


polycoder4vdcwe_small_cwe119_acc = {}
polycoder4vdcwe_small_cwe119_pre = {}
polycoder4vdcwe_small_cwe119_rec = {}
polycoder4vdcwe_small_cwe119_f1 = {}
polycoder4vdcwe_small_cwe119_auc = {}
polycoder4vdcwe_small_cwe119_mcc = {}
polycoder4vdcwe_small_cwe119_auc_pr = {}

for i in range(200):  
    polycoder4vdcwe_small_cwe119_acc[i] = readfile(polycoder4vdcwe_small+trained_cwe119_path[i]+'model_auc-acc-performance.txt')
    polycoder4vdcwe_small_cwe119_pre[i] = readfile(polycoder4vdcwe_small+trained_cwe119_path[i]+'model_auc-pre-performance.txt')
    polycoder4vdcwe_small_cwe119_rec[i] = readfile(polycoder4vdcwe_small+trained_cwe119_path[i]+'model_auc-rec-performance.txt')
    polycoder4vdcwe_small_cwe119_f1[i] = readfile(polycoder4vdcwe_small+trained_cwe119_path[i]+'model_auc-f1-performance.txt')
    polycoder4vdcwe_small_cwe119_auc[i] = readfile(polycoder4vdcwe_small+trained_cwe119_path[i]+'model_auc-auc-performance.txt')
    polycoder4vdcwe_small_cwe119_mcc[i] = readfile(polycoder4vdcwe_small+trained_cwe119_path[i]+'model_auc-mcc-performance.txt')
    polycoder4vdcwe_small_cwe119_auc_pr[i] = readfile(polycoder4vdcwe_small+trained_cwe119_path[i]+'model_auc-auc_pr-performance.txt')
    
    
    
    
polycoder4vdcwe_base_cwe119_acc = {}
polycoder4vdcwe_base_cwe119_pre = {}
polycoder4vdcwe_base_cwe119_rec = {}
polycoder4vdcwe_base_cwe119_f1 = {}
polycoder4vdcwe_base_cwe119_auc = {}
polycoder4vdcwe_base_cwe119_mcc = {}
polycoder4vdcwe_base_cwe119_auc_pr = {}

for i in range(200):  
    polycoder4vdcwe_base_cwe119_acc[i] = readfile(polycoder4vdcwe_base+trained_cwe119_path[i]+'model_auc-acc-performance.txt')
    polycoder4vdcwe_base_cwe119_pre[i] = readfile(polycoder4vdcwe_base+trained_cwe119_path[i]+'model_auc-pre-performance.txt')
    polycoder4vdcwe_base_cwe119_rec[i] = readfile(polycoder4vdcwe_base+trained_cwe119_path[i]+'model_auc-rec-performance.txt')
    polycoder4vdcwe_base_cwe119_f1[i] = readfile(polycoder4vdcwe_base+trained_cwe119_path[i]+'model_auc-f1-performance.txt')
    polycoder4vdcwe_base_cwe119_auc[i] = readfile(polycoder4vdcwe_base+trained_cwe119_path[i]+'model_auc-auc-performance.txt')
    polycoder4vdcwe_base_cwe119_mcc[i] = readfile(polycoder4vdcwe_base+trained_cwe119_path[i]+'model_auc-mcc-performance.txt')
    polycoder4vdcwe_base_cwe119_auc_pr[i] = readfile(polycoder4vdcwe_base+trained_cwe119_path[i]+'model_auc-auc_pr-performance.txt')
    
    
polycoder4vdcwe_large_cwe119_acc = {}
polycoder4vdcwe_large_cwe119_pre = {}
polycoder4vdcwe_large_cwe119_rec = {}
polycoder4vdcwe_large_cwe119_f1 = {}
polycoder4vdcwe_large_cwe119_auc = {}
polycoder4vdcwe_large_cwe119_mcc = {}
polycoder4vdcwe_large_cwe119_auc_pr = {}

for i in range(200):  
    polycoder4vdcwe_large_cwe119_acc[i] = readfile(polycoder4vdcwe_large+trained_cwe119_path[i]+'model_auc-acc-performance.txt')
    polycoder4vdcwe_large_cwe119_pre[i] = readfile(polycoder4vdcwe_large+trained_cwe119_path[i]+'model_auc-pre-performance.txt')
    polycoder4vdcwe_large_cwe119_rec[i] = readfile(polycoder4vdcwe_large+trained_cwe119_path[i]+'model_auc-rec-performance.txt')
    polycoder4vdcwe_large_cwe119_f1[i] = readfile(polycoder4vdcwe_large+trained_cwe119_path[i]+'model_auc-f1-performance.txt')
    polycoder4vdcwe_large_cwe119_auc[i] = readfile(polycoder4vdcwe_large+trained_cwe119_path[i]+'model_auc-auc-performance.txt')
    polycoder4vdcwe_large_cwe119_mcc[i] = readfile(polycoder4vdcwe_large+trained_cwe119_path[i]+'model_auc-mcc-performance.txt')
    polycoder4vdcwe_large_cwe119_auc_pr[i] = readfile(polycoder4vdcwe_large+trained_cwe119_path[i]+'model_auc-auc_pr-performance.txt')

# %%
codebert4vdcwe_small_cwe399_acc = {}
codebert4vdcwe_small_cwe399_pre = {}
codebert4vdcwe_small_cwe399_rec = {}
codebert4vdcwe_small_cwe399_f1 = {}
codebert4vdcwe_small_cwe399_auc = {}
codebert4vdcwe_small_cwe399_mcc = {}
codebert4vdcwe_small_cwe399_auc_pr = {}

for i in range(200):  
    codebert4vdcwe_small_cwe399_acc[i] = readfile(codebert4vdcwe_small+trained_cwe399_path[i]+'model_auc-acc-performance.txt')
    codebert4vdcwe_small_cwe399_pre[i] = readfile(codebert4vdcwe_small+trained_cwe399_path[i]+'model_auc-pre-performance.txt')
    codebert4vdcwe_small_cwe399_rec[i] = readfile(codebert4vdcwe_small+trained_cwe399_path[i]+'model_auc-rec-performance.txt')
    codebert4vdcwe_small_cwe399_f1[i] = readfile(codebert4vdcwe_small+trained_cwe399_path[i]+'model_auc-f1-performance.txt')
    codebert4vdcwe_small_cwe399_auc[i] = readfile(codebert4vdcwe_small+trained_cwe399_path[i]+'model_auc-auc-performance.txt')
    codebert4vdcwe_small_cwe399_mcc[i] = readfile(codebert4vdcwe_small+trained_cwe399_path[i]+'model_auc-mcc-performance.txt')
    codebert4vdcwe_small_cwe399_auc_pr[i] = readfile(codebert4vdcwe_small+trained_cwe399_path[i]+'model_auc-auc_pr-performance.txt')


codebert4vdcwe_base_cwe399_acc = {}
codebert4vdcwe_base_cwe399_pre = {}
codebert4vdcwe_base_cwe399_rec = {}
codebert4vdcwe_base_cwe399_f1 = {}
codebert4vdcwe_base_cwe399_auc = {}
codebert4vdcwe_base_cwe399_mcc = {}
codebert4vdcwe_base_cwe399_auc_pr = {}

for i in range(200):  
    codebert4vdcwe_base_cwe399_acc[i] = readfile(codebert4vdcwe_base+trained_cwe399_path[i]+'model_auc-acc-performance.txt')
    codebert4vdcwe_base_cwe399_pre[i] = readfile(codebert4vdcwe_base+trained_cwe399_path[i]+'model_auc-pre-performance.txt')
    codebert4vdcwe_base_cwe399_rec[i] = readfile(codebert4vdcwe_base+trained_cwe399_path[i]+'model_auc-rec-performance.txt')
    codebert4vdcwe_base_cwe399_f1[i] = readfile(codebert4vdcwe_base+trained_cwe399_path[i]+'model_auc-f1-performance.txt')
    codebert4vdcwe_base_cwe399_auc[i] = readfile(codebert4vdcwe_base+trained_cwe399_path[i]+'model_auc-auc-performance.txt')
    codebert4vdcwe_base_cwe399_mcc[i] = readfile(codebert4vdcwe_base+trained_cwe399_path[i]+'model_auc-mcc-performance.txt')
    codebert4vdcwe_base_cwe399_auc_pr[i] = readfile(codebert4vdcwe_base+trained_cwe399_path[i]+'model_auc-auc_pr-performance.txt')


codegen4vdcwe_small_cwe399_acc = {}
codegen4vdcwe_small_cwe399_pre = {}
codegen4vdcwe_small_cwe399_rec = {}
codegen4vdcwe_small_cwe399_f1 = {}
codegen4vdcwe_small_cwe399_auc = {}
codegen4vdcwe_small_cwe399_mcc = {}
codegen4vdcwe_small_cwe399_auc_pr = {}

for i in range(200):  
    codegen4vdcwe_small_cwe399_acc[i] = readfile(codegen4vdcwe_small+trained_cwe399_path[i]+'model_auc-acc-performance.txt')
    codegen4vdcwe_small_cwe399_pre[i] = readfile(codegen4vdcwe_small+trained_cwe399_path[i]+'model_auc-pre-performance.txt')
    codegen4vdcwe_small_cwe399_rec[i] = readfile(codegen4vdcwe_small+trained_cwe399_path[i]+'model_auc-rec-performance.txt')
    codegen4vdcwe_small_cwe399_f1[i] = readfile(codegen4vdcwe_small+trained_cwe399_path[i]+'model_auc-f1-performance.txt')
    codegen4vdcwe_small_cwe399_auc[i] = readfile(codegen4vdcwe_small+trained_cwe399_path[i]+'model_auc-auc-performance.txt')
    codegen4vdcwe_small_cwe399_mcc[i] = readfile(codegen4vdcwe_small+trained_cwe399_path[i]+'model_auc-mcc-performance.txt')
    codegen4vdcwe_small_cwe399_auc_pr[i] = readfile(codegen4vdcwe_small+trained_cwe399_path[i]+'model_auc-auc_pr-performance.txt')

codegen4vdcwe_base_cwe399_acc = {}
codegen4vdcwe_base_cwe399_pre = {}
codegen4vdcwe_base_cwe399_rec = {}
codegen4vdcwe_base_cwe399_f1 = {}
codegen4vdcwe_base_cwe399_auc = {}
codegen4vdcwe_base_cwe399_mcc = {}
codegen4vdcwe_base_cwe399_auc_pr = {}

for i in range(200):  

    codegen4vdcwe_base_cwe399_acc[i] = readfile(codegen4vdcwe_base+trained_cwe399_path[i]+'model_auc-acc-performance.txt')
    codegen4vdcwe_base_cwe399_pre[i] = readfile(codegen4vdcwe_base+trained_cwe399_path[i]+'model_auc-pre-performance.txt')
    codegen4vdcwe_base_cwe399_rec[i] = readfile(codegen4vdcwe_base+trained_cwe399_path[i]+'model_auc-rec-performance.txt')
    codegen4vdcwe_base_cwe399_f1[i] = readfile(codegen4vdcwe_base+trained_cwe399_path[i]+'model_auc-f1-performance.txt')
    codegen4vdcwe_base_cwe399_auc[i] = readfile(codegen4vdcwe_base+trained_cwe399_path[i]+'model_auc-auc-performance.txt')
    codegen4vdcwe_base_cwe399_mcc[i] = readfile(codegen4vdcwe_base+trained_cwe399_path[i]+'model_auc-mcc-performance.txt')
    codegen4vdcwe_base_cwe399_auc_pr[i] = readfile(codegen4vdcwe_base+trained_cwe399_path[i]+'model_auc-auc_pr-performance.txt')

codet54vdcwe_small_cwe399_acc = {}
codet54vdcwe_small_cwe399_pre = {}
codet54vdcwe_small_cwe399_rec = {}
codet54vdcwe_small_cwe399_f1 = {}
codet54vdcwe_small_cwe399_auc = {}
codet54vdcwe_small_cwe399_mcc = {}
codet54vdcwe_small_cwe399_auc_pr = {}

for i in range(200):  
    codet54vdcwe_small_cwe399_acc[i] = readfile(codet54vdcwe_small+trained_cwe399_path[i]+'model_auc-acc-performance.txt')
    codet54vdcwe_small_cwe399_pre[i] = readfile(codet54vdcwe_small+trained_cwe399_path[i]+'model_auc-pre-performance.txt')
    codet54vdcwe_small_cwe399_rec[i] = readfile(codet54vdcwe_small+trained_cwe399_path[i]+'model_auc-rec-performance.txt')
    codet54vdcwe_small_cwe399_f1[i] = readfile(codet54vdcwe_small+trained_cwe399_path[i]+'model_auc-f1-performance.txt')
    codet54vdcwe_small_cwe399_auc[i] = readfile(codet54vdcwe_small+trained_cwe399_path[i]+'model_auc-auc-performance.txt')
    codet54vdcwe_small_cwe399_mcc[i] = readfile(codet54vdcwe_small+trained_cwe399_path[i]+'model_auc-mcc-performance.txt')
    codet54vdcwe_small_cwe399_auc_pr[i] = readfile(codet54vdcwe_small+trained_cwe399_path[i]+'model_auc-auc_pr-performance.txt')

    
codet54vdcwe_base_cwe399_acc = {}
codet54vdcwe_base_cwe399_pre = {}
codet54vdcwe_base_cwe399_rec = {}
codet54vdcwe_base_cwe399_f1 = {}
codet54vdcwe_base_cwe399_auc = {}
codet54vdcwe_base_cwe399_mcc = {}
codet54vdcwe_base_cwe399_auc_pr = {}

for i in range(200):  
    codet54vdcwe_base_cwe399_acc[i] = readfile(codet54vdcwe_base+trained_cwe399_path[i]+'model_auc-acc-performance.txt')
    codet54vdcwe_base_cwe399_pre[i] = readfile(codet54vdcwe_base+trained_cwe399_path[i]+'model_auc-pre-performance.txt')
    codet54vdcwe_base_cwe399_rec[i] = readfile(codet54vdcwe_base+trained_cwe399_path[i]+'model_auc-rec-performance.txt')
    codet54vdcwe_base_cwe399_f1[i] = readfile(codet54vdcwe_base+trained_cwe399_path[i]+'model_auc-f1-performance.txt')
    codet54vdcwe_base_cwe399_auc[i] = readfile(codet54vdcwe_base+trained_cwe399_path[i]+'model_auc-auc-performance.txt')
    codet54vdcwe_base_cwe399_mcc[i] = readfile(codet54vdcwe_base+trained_cwe399_path[i]+'model_auc-mcc-performance.txt')
    codet54vdcwe_base_cwe399_auc_pr[i] = readfile(codet54vdcwe_base+trained_cwe399_path[i]+'model_auc-auc_pr-performance.txt')

    
codet54vdcwe_large_cwe399_acc = {}
codet54vdcwe_large_cwe399_pre = {}
codet54vdcwe_large_cwe399_rec = {}
codet54vdcwe_large_cwe399_f1 = {}
codet54vdcwe_large_cwe399_auc = {}
codet54vdcwe_large_cwe399_mcc = {}
codet54vdcwe_large_cwe399_auc_pr = {}

for i in range(200):  
    codet54vdcwe_large_cwe399_acc[i] = readfile(codet54vdcwe_large+trained_cwe399_path[i]+'model_auc-acc-performance.txt')
    codet54vdcwe_large_cwe399_pre[i] = readfile(codet54vdcwe_large+trained_cwe399_path[i]+'model_auc-pre-performance.txt')
    codet54vdcwe_large_cwe399_rec[i] = readfile(codet54vdcwe_large+trained_cwe399_path[i]+'model_auc-rec-performance.txt')
    codet54vdcwe_large_cwe399_f1[i] = readfile(codet54vdcwe_large+trained_cwe399_path[i]+'model_auc-f1-performance.txt')
    codet54vdcwe_large_cwe399_auc[i] = readfile(codet54vdcwe_large+trained_cwe399_path[i]+'model_auc-auc-performance.txt')
    codet54vdcwe_large_cwe399_mcc[i] = readfile(codet54vdcwe_large+trained_cwe399_path[i]+'model_auc-mcc-performance.txt')
    codet54vdcwe_large_cwe399_auc_pr[i] = readfile(codet54vdcwe_large+trained_cwe399_path[i]+'model_auc-auc_pr-performance.txt')


polycoder4vdcwe_small_cwe399_acc = {}
polycoder4vdcwe_small_cwe399_pre = {}
polycoder4vdcwe_small_cwe399_rec = {}
polycoder4vdcwe_small_cwe399_f1 = {}
polycoder4vdcwe_small_cwe399_auc = {}
polycoder4vdcwe_small_cwe399_mcc = {}
polycoder4vdcwe_small_cwe399_auc_pr = {}

for i in range(200):  
    polycoder4vdcwe_small_cwe399_acc[i] = readfile(polycoder4vdcwe_small+trained_cwe399_path[i]+'model_auc-acc-performance.txt')
    polycoder4vdcwe_small_cwe399_pre[i] = readfile(polycoder4vdcwe_small+trained_cwe399_path[i]+'model_auc-pre-performance.txt')
    polycoder4vdcwe_small_cwe399_rec[i] = readfile(polycoder4vdcwe_small+trained_cwe399_path[i]+'model_auc-rec-performance.txt')
    polycoder4vdcwe_small_cwe399_f1[i] = readfile(polycoder4vdcwe_small+trained_cwe399_path[i]+'model_auc-f1-performance.txt')
    polycoder4vdcwe_small_cwe399_auc[i] = readfile(polycoder4vdcwe_small+trained_cwe399_path[i]+'model_auc-auc-performance.txt')
    polycoder4vdcwe_small_cwe399_mcc[i] = readfile(polycoder4vdcwe_small+trained_cwe399_path[i]+'model_auc-mcc-performance.txt')
    polycoder4vdcwe_small_cwe399_auc_pr[i] = readfile(polycoder4vdcwe_small+trained_cwe399_path[i]+'model_auc-auc_pr-performance.txt')
    
    
    
    
polycoder4vdcwe_base_cwe399_acc = {}
polycoder4vdcwe_base_cwe399_pre = {}
polycoder4vdcwe_base_cwe399_rec = {}
polycoder4vdcwe_base_cwe399_f1 = {}
polycoder4vdcwe_base_cwe399_auc = {}
polycoder4vdcwe_base_cwe399_mcc = {}
polycoder4vdcwe_base_cwe399_auc_pr = {}

for i in range(200):  
    polycoder4vdcwe_base_cwe399_acc[i] = readfile(polycoder4vdcwe_base+trained_cwe399_path[i]+'model_auc-acc-performance.txt')
    polycoder4vdcwe_base_cwe399_pre[i] = readfile(polycoder4vdcwe_base+trained_cwe399_path[i]+'model_auc-pre-performance.txt')
    polycoder4vdcwe_base_cwe399_rec[i] = readfile(polycoder4vdcwe_base+trained_cwe399_path[i]+'model_auc-rec-performance.txt')
    polycoder4vdcwe_base_cwe399_f1[i] = readfile(polycoder4vdcwe_base+trained_cwe399_path[i]+'model_auc-f1-performance.txt')
    polycoder4vdcwe_base_cwe399_auc[i] = readfile(polycoder4vdcwe_base+trained_cwe399_path[i]+'model_auc-auc-performance.txt')
    polycoder4vdcwe_base_cwe399_mcc[i] = readfile(polycoder4vdcwe_base+trained_cwe399_path[i]+'model_auc-mcc-performance.txt')
    polycoder4vdcwe_base_cwe399_auc_pr[i] = readfile(polycoder4vdcwe_base+trained_cwe399_path[i]+'model_auc-auc_pr-performance.txt')
    
    
polycoder4vdcwe_large_cwe399_acc = {}
polycoder4vdcwe_large_cwe399_pre = {}
polycoder4vdcwe_large_cwe399_rec = {}
polycoder4vdcwe_large_cwe399_f1 = {}
polycoder4vdcwe_large_cwe399_auc = {}
polycoder4vdcwe_large_cwe399_mcc = {}
polycoder4vdcwe_large_cwe399_auc_pr = {}

for i in range(200):  
    polycoder4vdcwe_large_cwe399_acc[i] = readfile(polycoder4vdcwe_large+trained_cwe399_path[i]+'model_auc-acc-performance.txt')
    polycoder4vdcwe_large_cwe399_pre[i] = readfile(polycoder4vdcwe_large+trained_cwe399_path[i]+'model_auc-pre-performance.txt')
    polycoder4vdcwe_large_cwe399_rec[i] = readfile(polycoder4vdcwe_large+trained_cwe399_path[i]+'model_auc-rec-performance.txt')
    polycoder4vdcwe_large_cwe399_f1[i] = readfile(polycoder4vdcwe_large+trained_cwe399_path[i]+'model_auc-f1-performance.txt')
    polycoder4vdcwe_large_cwe399_auc[i] = readfile(polycoder4vdcwe_large+trained_cwe399_path[i]+'model_auc-auc-performance.txt')
    polycoder4vdcwe_large_cwe399_mcc[i] = readfile(polycoder4vdcwe_large+trained_cwe399_path[i]+'model_auc-mcc-performance.txt')
    polycoder4vdcwe_large_cwe399_auc_pr[i] = readfile(polycoder4vdcwe_large+trained_cwe399_path[i]+'model_auc-auc_pr-performance.txt')

# %%
print(np.array(codegen4vdcwe_base_codexglue_acc[20]).mean())


print(np.array(polycoder4vdcwe_large_cwe399_acc[20]).mean())
# Out:
# 0.5921569279914813
# 0.936714644733836

# %%
codexglue_data_acc = {}
codexglue_data_pre = {}
codexglue_data_rec = {}
codexglue_data_f1 = {}
codexglue_data_auc = {}
codexglue_data_mcc = {}
codexglue_data_auc_pr = {}

for i in range(200): 
    codexglue_data_acc[i] = [np.array(codebert4vdcwe_small_codexglue_acc[i]).mean(),np.array(codebert4vdcwe_base_codexglue_acc[i]).mean(),np.array(codegen4vdcwe_small_codexglue_acc[i]).mean(),np.array(codegen4vdcwe_base_codexglue_acc[i]).mean(),np.array(codet54vdcwe_small_codexglue_acc[i]).mean(),np.array(codet54vdcwe_base_codexglue_acc[i]).mean(),np.array(codet54vdcwe_large_codexglue_acc[i]).mean(),np.array(polycoder4vdcwe_small_codexglue_acc[i]).mean(),np.array(polycoder4vdcwe_base_codexglue_acc[i]).mean(),np.array(polycoder4vdcwe_large_codexglue_acc[i]).mean()]
    codexglue_data_pre[i] = [np.array(codebert4vdcwe_small_codexglue_pre[i]).mean(),np.array(codebert4vdcwe_base_codexglue_pre[i]).mean(),np.array(codegen4vdcwe_small_codexglue_pre[i]).mean(),np.array(codegen4vdcwe_base_codexglue_pre[i]).mean(),np.array(codet54vdcwe_small_codexglue_pre[i]).mean(),np.array(codet54vdcwe_base_codexglue_pre[i]).mean(),np.array(codet54vdcwe_large_codexglue_pre[i]).mean(),np.array(polycoder4vdcwe_small_codexglue_pre[i]).mean(),np.array(polycoder4vdcwe_base_codexglue_pre[i]).mean(),np.array(polycoder4vdcwe_large_codexglue_pre[i]).mean()]
    codexglue_data_rec[i] = [np.array(codebert4vdcwe_small_codexglue_rec[i]).mean(),np.array(codebert4vdcwe_base_codexglue_rec[i]).mean(),np.array(codegen4vdcwe_small_codexglue_rec[i]).mean(),np.array(codegen4vdcwe_base_codexglue_rec[i]).mean(),np.array(codet54vdcwe_small_codexglue_rec[i]).mean(),np.array(codet54vdcwe_base_codexglue_rec[i]).mean(),np.array(codet54vdcwe_large_codexglue_rec[i]).mean(),np.array(polycoder4vdcwe_small_codexglue_rec[i]).mean(),np.array(polycoder4vdcwe_base_codexglue_rec[i]).mean(),np.array(polycoder4vdcwe_large_codexglue_rec[i]).mean()]
    codexglue_data_f1[i] = [np.array(codebert4vdcwe_small_codexglue_f1[i]).mean(),np.array(codebert4vdcwe_base_codexglue_f1[i]).mean(),np.array(codegen4vdcwe_small_codexglue_f1[i]).mean(),np.array(codegen4vdcwe_base_codexglue_f1[i]).mean(),np.array(codet54vdcwe_small_codexglue_f1[i]).mean(),np.array(codet54vdcwe_base_codexglue_f1[i]).mean(),np.array(codet54vdcwe_large_codexglue_f1[i]).mean(),np.array(polycoder4vdcwe_small_codexglue_f1[i]).mean(),np.array(polycoder4vdcwe_base_codexglue_f1[i]).mean(),np.array(polycoder4vdcwe_large_codexglue_f1[i]).mean()]
    codexglue_data_auc[i] = [np.array(codebert4vdcwe_small_codexglue_auc[i]).mean(),np.array(codebert4vdcwe_base_codexglue_auc[i]).mean(),np.array(codegen4vdcwe_small_codexglue_auc[i]).mean(),np.array(codegen4vdcwe_base_codexglue_auc[i]).mean(),np.array(codet54vdcwe_small_codexglue_auc[i]).mean(),np.array(codet54vdcwe_base_codexglue_auc[i]).mean(),np.array(codet54vdcwe_large_codexglue_auc[i]).mean(),np.array(polycoder4vdcwe_small_codexglue_auc[i]).mean(),np.array(polycoder4vdcwe_base_codexglue_auc[i]).mean(),np.array(polycoder4vdcwe_large_codexglue_auc[i]).mean()]
    codexglue_data_mcc[i] = [np.array(codebert4vdcwe_small_codexglue_mcc[i]).mean(),np.array(codebert4vdcwe_base_codexglue_mcc[i]).mean(),np.array(codegen4vdcwe_small_codexglue_mcc[i]).mean(),np.array(codegen4vdcwe_base_codexglue_mcc[i]).mean(),np.array(codet54vdcwe_small_codexglue_mcc[i]).mean(),np.array(codet54vdcwe_base_codexglue_mcc[i]).mean(),np.array(codet54vdcwe_large_codexglue_mcc[i]).mean(),np.array(polycoder4vdcwe_small_codexglue_mcc[i]).mean(),np.array(polycoder4vdcwe_base_codexglue_mcc[i]).mean(),np.array(polycoder4vdcwe_large_codexglue_mcc[i]).mean()]
    codexglue_data_auc_pr[i] = [np.array(codebert4vdcwe_small_codexglue_auc_pr[i]).mean(),np.array(codebert4vdcwe_base_codexglue_auc_pr[i]).mean(),np.array(codegen4vdcwe_small_codexglue_auc_pr[i]).mean(),np.array(codegen4vdcwe_base_codexglue_auc_pr[i]).mean(),np.array(codet54vdcwe_small_codexglue_auc_pr[i]).mean(),np.array(codet54vdcwe_base_codexglue_auc_pr[i]).mean(),np.array(codet54vdcwe_large_codexglue_auc_pr[i]).mean(),np.array(polycoder4vdcwe_small_codexglue_auc_pr[i]).mean(),np.array(polycoder4vdcwe_base_codexglue_auc_pr[i]).mean(),np.array(polycoder4vdcwe_large_codexglue_auc_pr[i]).mean()]

reveal_data_acc = {}
reveal_data_pre = {}
reveal_data_rec = {}
reveal_data_f1 = {}
reveal_data_auc = {}
reveal_data_mcc = {}
reveal_data_auc_pr = {}

for i in range(200): 
    reveal_data_acc[i] = [np.array(codebert4vdcwe_small_reveal_acc[i]).mean(),np.array(codebert4vdcwe_base_reveal_acc[i]).mean(),np.array(codegen4vdcwe_small_reveal_acc[i]).mean(),np.array(codegen4vdcwe_base_reveal_acc[i]).mean(),np.array(codet54vdcwe_small_reveal_acc[i]).mean(),np.array(codet54vdcwe_base_reveal_acc[i]).mean(),np.array(codet54vdcwe_large_reveal_acc[i]).mean(),np.array(polycoder4vdcwe_small_reveal_acc[i]).mean(),np.array(polycoder4vdcwe_base_reveal_acc[i]).mean(),np.array(polycoder4vdcwe_large_reveal_acc[i]).mean()]
    reveal_data_pre[i] = [np.array(codebert4vdcwe_small_reveal_pre[i]).mean(),np.array(codebert4vdcwe_base_reveal_pre[i]).mean(),np.array(codegen4vdcwe_small_reveal_pre[i]).mean(),np.array(codegen4vdcwe_base_reveal_pre[i]).mean(),np.array(codet54vdcwe_small_reveal_pre[i]).mean(),np.array(codet54vdcwe_base_reveal_pre[i]).mean(),np.array(codet54vdcwe_large_reveal_pre[i]).mean(),np.array(polycoder4vdcwe_small_reveal_pre[i]).mean(),np.array(polycoder4vdcwe_base_reveal_pre[i]).mean(),np.array(polycoder4vdcwe_large_reveal_pre[i]).mean()]
    reveal_data_rec[i] = [np.array(codebert4vdcwe_small_reveal_rec[i]).mean(),np.array(codebert4vdcwe_base_reveal_rec[i]).mean(),np.array(codegen4vdcwe_small_reveal_rec[i]).mean(),np.array(codegen4vdcwe_base_reveal_rec[i]).mean(),np.array(codet54vdcwe_small_reveal_rec[i]).mean(),np.array(codet54vdcwe_base_reveal_rec[i]).mean(),np.array(codet54vdcwe_large_reveal_rec[i]).mean(),np.array(polycoder4vdcwe_small_reveal_rec[i]).mean(),np.array(polycoder4vdcwe_base_reveal_rec[i]).mean(),np.array(polycoder4vdcwe_large_reveal_rec[i]).mean()]
    reveal_data_f1[i] = [np.array(codebert4vdcwe_small_reveal_f1[i]).mean(),np.array(codebert4vdcwe_base_reveal_f1[i]).mean(),np.array(codegen4vdcwe_small_reveal_f1[i]).mean(),np.array(codegen4vdcwe_base_reveal_f1[i]).mean(),np.array(codet54vdcwe_small_reveal_f1[i]).mean(),np.array(codet54vdcwe_base_reveal_f1[i]).mean(),np.array(codet54vdcwe_large_reveal_f1[i]).mean(),np.array(polycoder4vdcwe_small_reveal_f1[i]).mean(),np.array(polycoder4vdcwe_base_reveal_f1[i]).mean(),np.array(polycoder4vdcwe_large_reveal_f1[i]).mean()]
    reveal_data_auc[i] = [np.array(codebert4vdcwe_small_reveal_auc[i]).mean(),np.array(codebert4vdcwe_base_reveal_auc[i]).mean(),np.array(codegen4vdcwe_small_reveal_auc[i]).mean(),np.array(codegen4vdcwe_base_reveal_auc[i]).mean(),np.array(codet54vdcwe_small_reveal_auc[i]).mean(),np.array(codet54vdcwe_base_reveal_auc[i]).mean(),np.array(codet54vdcwe_large_reveal_auc[i]).mean(),np.array(polycoder4vdcwe_small_reveal_auc[i]).mean(),np.array(polycoder4vdcwe_base_reveal_auc[i]).mean(),np.array(polycoder4vdcwe_large_reveal_auc[i]).mean()]
    reveal_data_mcc[i] = [np.array(codebert4vdcwe_small_reveal_mcc[i]).mean(),np.array(codebert4vdcwe_base_reveal_mcc[i]).mean(),np.array(codegen4vdcwe_small_reveal_mcc[i]).mean(),np.array(codegen4vdcwe_base_reveal_mcc[i]).mean(),np.array(codet54vdcwe_small_reveal_mcc[i]).mean(),np.array(codet54vdcwe_base_reveal_mcc[i]).mean(),np.array(codet54vdcwe_large_reveal_mcc[i]).mean(),np.array(polycoder4vdcwe_small_reveal_mcc[i]).mean(),np.array(polycoder4vdcwe_base_reveal_mcc[i]).mean(),np.array(polycoder4vdcwe_large_reveal_mcc[i]).mean()]
    reveal_data_auc_pr[i] = [np.array(codebert4vdcwe_small_reveal_auc_pr[i]).mean(),np.array(codebert4vdcwe_base_reveal_auc_pr[i]).mean(),np.array(codegen4vdcwe_small_reveal_auc_pr[i]).mean(),np.array(codegen4vdcwe_base_reveal_auc_pr[i]).mean(),np.array(codet54vdcwe_small_reveal_auc_pr[i]).mean(),np.array(codet54vdcwe_base_reveal_auc_pr[i]).mean(),np.array(codet54vdcwe_large_reveal_auc_pr[i]).mean(),np.array(polycoder4vdcwe_small_reveal_auc_pr[i]).mean(),np.array(polycoder4vdcwe_base_reveal_auc_pr[i]).mean(),np.array(polycoder4vdcwe_large_reveal_auc_pr[i]).mean()]

    
cwe119_data_acc = {}
cwe119_data_pre = {}
cwe119_data_rec = {}
cwe119_data_f1 = {}
cwe119_data_auc = {}
cwe119_data_mcc = {}
cwe119_data_auc_pr = {}

for i in range(200): 
    cwe119_data_acc[i] = [np.array(codebert4vdcwe_small_cwe119_acc[i]).mean(),np.array(codebert4vdcwe_base_cwe119_acc[i]).mean(),np.array(codegen4vdcwe_small_cwe119_acc[i]).mean(),np.array(codegen4vdcwe_base_cwe119_acc[i]).mean(),np.array(codet54vdcwe_small_cwe119_acc[i]).mean(),np.array(codet54vdcwe_base_cwe119_acc[i]).mean(),np.array(codet54vdcwe_large_cwe119_acc[i]).mean(),np.array(polycoder4vdcwe_small_cwe119_acc[i]).mean(),np.array(polycoder4vdcwe_base_cwe119_acc[i]).mean(),np.array(polycoder4vdcwe_large_cwe119_acc[i]).mean()]
    cwe119_data_pre[i] = [np.array(codebert4vdcwe_small_cwe119_pre[i]).mean(),np.array(codebert4vdcwe_base_cwe119_pre[i]).mean(),np.array(codegen4vdcwe_small_cwe119_pre[i]).mean(),np.array(codegen4vdcwe_base_cwe119_pre[i]).mean(),np.array(codet54vdcwe_small_cwe119_pre[i]).mean(),np.array(codet54vdcwe_base_cwe119_pre[i]).mean(),np.array(codet54vdcwe_large_cwe119_pre[i]).mean(),np.array(polycoder4vdcwe_small_cwe119_pre[i]).mean(),np.array(polycoder4vdcwe_base_cwe119_pre[i]).mean(),np.array(polycoder4vdcwe_large_cwe119_pre[i]).mean()]
    cwe119_data_rec[i] = [np.array(codebert4vdcwe_small_cwe119_rec[i]).mean(),np.array(codebert4vdcwe_base_cwe119_rec[i]).mean(),np.array(codegen4vdcwe_small_cwe119_rec[i]).mean(),np.array(codegen4vdcwe_base_cwe119_rec[i]).mean(),np.array(codet54vdcwe_small_cwe119_rec[i]).mean(),np.array(codet54vdcwe_base_cwe119_rec[i]).mean(),np.array(codet54vdcwe_large_cwe119_rec[i]).mean(),np.array(polycoder4vdcwe_small_cwe119_rec[i]).mean(),np.array(polycoder4vdcwe_base_cwe119_rec[i]).mean(),np.array(polycoder4vdcwe_large_cwe119_rec[i]).mean()]
    cwe119_data_f1[i] = [np.array(codebert4vdcwe_small_cwe119_f1[i]).mean(),np.array(codebert4vdcwe_base_cwe119_f1[i]).mean(),np.array(codegen4vdcwe_small_cwe119_f1[i]).mean(),np.array(codegen4vdcwe_base_cwe119_f1[i]).mean(),np.array(codet54vdcwe_small_cwe119_f1[i]).mean(),np.array(codet54vdcwe_base_cwe119_f1[i]).mean(),np.array(codet54vdcwe_large_cwe119_f1[i]).mean(),np.array(polycoder4vdcwe_small_cwe119_f1[i]).mean(),np.array(polycoder4vdcwe_base_cwe119_f1[i]).mean(),np.array(polycoder4vdcwe_large_cwe119_f1[i]).mean()]
    cwe119_data_auc[i] = [np.array(codebert4vdcwe_small_cwe119_auc[i]).mean(),np.array(codebert4vdcwe_base_cwe119_auc[i]).mean(),np.array(codegen4vdcwe_small_cwe119_auc[i]).mean(),np.array(codegen4vdcwe_base_cwe119_auc[i]).mean(),np.array(codet54vdcwe_small_cwe119_auc[i]).mean(),np.array(codet54vdcwe_base_cwe119_auc[i]).mean(),np.array(codet54vdcwe_large_cwe119_auc[i]).mean(),np.array(polycoder4vdcwe_small_cwe119_auc[i]).mean(),np.array(polycoder4vdcwe_base_cwe119_auc[i]).mean(),np.array(polycoder4vdcwe_large_cwe119_auc[i]).mean()]
    cwe119_data_mcc[i] = [np.array(codebert4vdcwe_small_cwe119_mcc[i]).mean(),np.array(codebert4vdcwe_base_cwe119_mcc[i]).mean(),np.array(codegen4vdcwe_small_cwe119_mcc[i]).mean(),np.array(codegen4vdcwe_base_cwe119_mcc[i]).mean(),np.array(codet54vdcwe_small_cwe119_mcc[i]).mean(),np.array(codet54vdcwe_base_cwe119_mcc[i]).mean(),np.array(codet54vdcwe_large_cwe119_mcc[i]).mean(),np.array(polycoder4vdcwe_small_cwe119_mcc[i]).mean(),np.array(polycoder4vdcwe_base_cwe119_mcc[i]).mean(),np.array(polycoder4vdcwe_large_cwe119_mcc[i]).mean()]
    cwe119_data_auc_pr[i] = [np.array(codebert4vdcwe_small_cwe119_auc_pr[i]).mean(),np.array(codebert4vdcwe_base_cwe119_auc_pr[i]).mean(),np.array(codegen4vdcwe_small_cwe119_auc_pr[i]).mean(),np.array(codegen4vdcwe_base_cwe119_auc_pr[i]).mean(),np.array(codet54vdcwe_small_cwe119_auc_pr[i]).mean(),np.array(codet54vdcwe_base_cwe119_auc_pr[i]).mean(),np.array(codet54vdcwe_large_cwe119_auc_pr[i]).mean(),np.array(polycoder4vdcwe_small_cwe119_auc_pr[i]).mean(),np.array(polycoder4vdcwe_base_cwe119_auc_pr[i]).mean(),np.array(polycoder4vdcwe_large_cwe119_auc_pr[i]).mean()]

    
cwe399_data_acc = {}
cwe399_data_pre = {}
cwe399_data_rec = {}
cwe399_data_f1 = {}
cwe399_data_auc = {}
cwe399_data_mcc = {}
cwe399_data_auc_pr = {}

for i in range(200): 
    cwe399_data_acc[i] = [np.array(codebert4vdcwe_small_cwe399_acc[i]).mean(),np.array(codebert4vdcwe_base_cwe399_acc[i]).mean(),np.array(codegen4vdcwe_small_cwe399_acc[i]).mean(),np.array(codegen4vdcwe_base_cwe399_acc[i]).mean(),np.array(codet54vdcwe_small_cwe399_acc[i]).mean(),np.array(codet54vdcwe_base_cwe399_acc[i]).mean(),np.array(codet54vdcwe_large_cwe399_acc[i]).mean(),np.array(polycoder4vdcwe_small_cwe399_acc[i]).mean(),np.array(polycoder4vdcwe_base_cwe399_acc[i]).mean(),np.array(polycoder4vdcwe_large_cwe399_acc[i]).mean()]
    cwe399_data_pre[i] = [np.array(codebert4vdcwe_small_cwe399_pre[i]).mean(),np.array(codebert4vdcwe_base_cwe399_pre[i]).mean(),np.array(codegen4vdcwe_small_cwe399_pre[i]).mean(),np.array(codegen4vdcwe_base_cwe399_pre[i]).mean(),np.array(codet54vdcwe_small_cwe399_pre[i]).mean(),np.array(codet54vdcwe_base_cwe399_pre[i]).mean(),np.array(codet54vdcwe_large_cwe399_pre[i]).mean(),np.array(polycoder4vdcwe_small_cwe399_pre[i]).mean(),np.array(polycoder4vdcwe_base_cwe399_pre[i]).mean(),np.array(polycoder4vdcwe_large_cwe399_pre[i]).mean()]
    cwe399_data_rec[i] = [np.array(codebert4vdcwe_small_cwe399_rec[i]).mean(),np.array(codebert4vdcwe_base_cwe399_rec[i]).mean(),np.array(codegen4vdcwe_small_cwe399_rec[i]).mean(),np.array(codegen4vdcwe_base_cwe399_rec[i]).mean(),np.array(codet54vdcwe_small_cwe399_rec[i]).mean(),np.array(codet54vdcwe_base_cwe399_rec[i]).mean(),np.array(codet54vdcwe_large_cwe399_rec[i]).mean(),np.array(polycoder4vdcwe_small_cwe399_rec[i]).mean(),np.array(polycoder4vdcwe_base_cwe399_rec[i]).mean(),np.array(polycoder4vdcwe_large_cwe399_rec[i]).mean()]
    cwe399_data_f1[i] = [np.array(codebert4vdcwe_small_cwe399_f1[i]).mean(),np.array(codebert4vdcwe_base_cwe399_f1[i]).mean(),np.array(codegen4vdcwe_small_cwe399_f1[i]).mean(),np.array(codegen4vdcwe_base_cwe399_f1[i]).mean(),np.array(codet54vdcwe_small_cwe399_f1[i]).mean(),np.array(codet54vdcwe_base_cwe399_f1[i]).mean(),np.array(codet54vdcwe_large_cwe399_f1[i]).mean(),np.array(polycoder4vdcwe_small_cwe399_f1[i]).mean(),np.array(polycoder4vdcwe_base_cwe399_f1[i]).mean(),np.array(polycoder4vdcwe_large_cwe399_f1[i]).mean()]
    cwe399_data_auc[i] = [np.array(codebert4vdcwe_small_cwe399_auc[i]).mean(),np.array(codebert4vdcwe_base_cwe399_auc[i]).mean(),np.array(codegen4vdcwe_small_cwe399_auc[i]).mean(),np.array(codegen4vdcwe_base_cwe399_auc[i]).mean(),np.array(codet54vdcwe_small_cwe399_auc[i]).mean(),np.array(codet54vdcwe_base_cwe399_auc[i]).mean(),np.array(codet54vdcwe_large_cwe399_auc[i]).mean(),np.array(polycoder4vdcwe_small_cwe399_auc[i]).mean(),np.array(polycoder4vdcwe_base_cwe399_auc[i]).mean(),np.array(polycoder4vdcwe_large_cwe399_auc[i]).mean()]
    cwe399_data_mcc[i] = [np.array(codebert4vdcwe_small_cwe399_mcc[i]).mean(),np.array(codebert4vdcwe_base_cwe399_mcc[i]).mean(),np.array(codegen4vdcwe_small_cwe399_mcc[i]).mean(),np.array(codegen4vdcwe_base_cwe399_mcc[i]).mean(),np.array(codet54vdcwe_small_cwe399_mcc[i]).mean(),np.array(codet54vdcwe_base_cwe399_mcc[i]).mean(),np.array(codet54vdcwe_large_cwe399_mcc[i]).mean(),np.array(polycoder4vdcwe_small_cwe399_mcc[i]).mean(),np.array(polycoder4vdcwe_base_cwe399_mcc[i]).mean(),np.array(polycoder4vdcwe_large_cwe399_mcc[i]).mean()]
# [0.9859150675529564, 0.9784268434858643, 0.9831434454358272, 0.9797208798337737, 0.9856680208312856, 0.9858657896221359, 0.9834456473707467, 0.9866506637771364, 0.9859911057624504, 0.9878547235358826]
# [0.9853272111018138, 0.9804766314720622, 0.9825432724400862, 0.9783599369129661, 0.9847322925098143, 0.984506139468414, 0.9824055104784648, 0.9839893969594119, 0.9851214025817734, 0.9867450005171069]
# [0.9855809695283044, 0.9819170443113547, 0.9820219582365717, 0.9779132388751517, 0.9857892845207274, 0.986244546873384, 0.9834073814650106, 0.9852622201746882, 0.9862295860324742, 0.9870306432809018]
# [0.9846140385103561, 0.9790378404678407, 0.9815534359398651, 0.977931807711473, 0.9845809105524839, 0.9849828532074726, 0.9828224396160247, 0.9845047291770479, 0.9848858016566222, 0.9864426575530505]
# [0.9869886988651857, 0.9813136629027557, 0.9837415147469466, 0.9801787309258094, 0.9852862699160919, 0.9862066570453456, 0.9838782777521835, 0.9866795159880033, 0.986628063857993, 0.9875629224997885]
# [0.9849502167147733, 0.9781520012034488, 0.981114800067694, 0.9778795446639276, 0.9834878172194013, 0.9834096026739125, 0.9828383994133187, 0.9834460469533004, 0.9846726361166217, 0.9853288094320286]
# [0.9859786129314317, 0.980783393349066, 0.9824998824757195, 0.9794565207171801, 0.9849457807073851, 0.9861336627147168, 0.9832179793345306, 0.9860651108018915, 0.9861527839151567, 0.9875597728490707]
# [0.9854767019866305, 0.9792611718581059, 0.9828599886236498, 0.9796058705728603, 0.985174953054392, 0.9846201262680871, 0.9826327201699872, 0.9856406601103787, 0.9864343368339901, 0.9869482117505477]
# [0.9871818617726422, 0.9814645875837948, 0.9859030330666316, 0.9831444443922115, 0.9871168387934403, 0.9882670104643619, 0.9854731292485029, 0.9882312360733728, 0.9888809690582075, 0.9891178039883041]
# [0.988884095204069, 0.9828409849474902, 0.9844202292193568, 0.9819180667725952, 0.9874327974795957, 0.9877131772924287, 0.9851162550182867, 0.9877179252733616, 0.9880226187230281, 0.9894950921860456]
# [0.9869863601320032, 0.9820710716333994, 0.9855121708144902, 0.9816978732806199, 0.9867688280307804, 0.9866411678152704, 0.9857608051823507, 0.9871266841229398, 0.9876690116678105, 0.9880730248869417]
# [0.9839931929936725, 0.9793020468028695, 0.9811920487772774, 0.9781736256710637, 0.9835406817775826, 0.9852710815054389, 0.9821746692866746, 0.983029388121586, 0.9848088820150244, 0.9850872265209991]

# %%
PTM_str = ("codebert-small","codebert-base","codegen-small","codegen-base","codet5-small","codet5-base","codet5-large","polycoder-small","polycoder-base","polycoder-large")

true_dataset_class = {}
false_dataset_class = {}
true_tag = 1
false_tag = 0
    
for i in range(200):
    top_three_values = sorted(codexglue_data_auc[i], reverse=True)[:3]  
    top_three_indices = [codexglue_data_auc[i].index(value) for value in top_three_values]  
    top_three_PTMs = [PTM_str[index] for index in top_three_indices] 
    true_dataset_class[i] = [i, 'codexglue', top_three_PTMs, true_tag] 

    false_PTMs = set(PTM_str) - set(top_three_PTMs)
    false_dataset_class[i] = [i, 'codexglue', list(false_PTMs), false_tag]


df_codexglue_true = pd.DataFrame.from_dict(true_dataset_class, orient='index', columns=['Index', 'Dataset', 'PTM', 'Class'])
df_codexglue_false = pd.DataFrame.from_dict(false_dataset_class, orient='index', columns=['Index', 'Dataset', 'PTM', 'Class'])

print(df_codexglue_true)
print(df_codexglue_false)
# Out:
#      Index    Dataset                                                PTM  \
# 0        0  codexglue  [polycoder-base, polycoder-large, polycoder-sm...
# 1        1  codexglue  [polycoder-large, polycoder-small, polycoder-b...
# 2        2  codexglue  [polycoder-large, polycoder-base, polycoder-sm...
# 3        3  codexglue  [polycoder-large, polycoder-small, polycoder-b...
# 4        4  codexglue  [polycoder-large, polycoder-base, polycoder-sm...
# ..     ...        ...                                                ...
# 195    195  codexglue  [polycoder-large, polycoder-base, polycoder-sm...
# 196    196  codexglue  [polycoder-large, polycoder-base, polycoder-sm...
# 197    197  codexglue  [polycoder-large, polycoder-small, polycoder-b...
# 198    198  codexglue  [polycoder-large, polycoder-base, polycoder-sm...
# 199    199  codexglue  [polycoder-large, polycoder-base, polycoder-sm...
#
#      Class
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# 195      1
# 196      1
# 197      1
# 198      1
# 199      1
#
# [200 rows x 4 columns]
#      Index    Dataset                                                PTM  \
# 0        0  codexglue  [codegen-base, codet5-large, codet5-base, code...
# 1        1  codexglue  [codegen-base, codet5-large, codet5-base, code...
# 2        2  codexglue  [codegen-base, codet5-large, codet5-base, code...
# 3        3  codexglue  [codegen-base, codet5-large, codet5-base, code...
# 4        4  codexglue  [codegen-base, codet5-large, codet5-base, code...
# ..     ...        ...                                                ...
# 195    195  codexglue  [codegen-base, codet5-large, codet5-base, code...
# 196    196  codexglue  [codegen-base, codet5-large, codet5-base, code...
# 197    197  codexglue  [codegen-base, codet5-large, codet5-base, code...
# 198    198  codexglue  [codegen-base, codet5-large, codet5-base, code...
# 199    199  codexglue  [codegen-base, codet5-large, codet5-base, code...
#
#      Class
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 195      0
# 196      0
# 197      0
# 198      0
# 199      0
#
# [200 rows x 4 columns]

# %%
PTM_str = ("codebert-small","codebert-base","codegen-small","codegen-base","codet5-small","codet5-base","codet5-large","polycoder-small","polycoder-base","polycoder-large")

true_dataset_class = {}
false_dataset_class = {}
true_tag = 1
false_tag = 0
    
for i in range(200):
    top_three_values = sorted(reveal_data_auc[i], reverse=True)[:3]
    top_three_indices = [reveal_data_auc[i].index(value) for value in top_three_values] 
    top_three_PTMs = [PTM_str[index] for index in top_three_indices]
    true_dataset_class[i] = [i, 'reveal', top_three_PTMs, true_tag]     
    
    false_PTMs = set(PTM_str) - set(top_three_PTMs)
    false_dataset_class[i] = [i, 'reveal', list(false_PTMs), false_tag]


df_reveal_true = pd.DataFrame.from_dict(true_dataset_class, orient='index', columns=['Index', 'Dataset', 'PTM', 'Class'])
df_reveal_false = pd.DataFrame.from_dict(false_dataset_class, orient='index', columns=['Index', 'Dataset', 'PTM', 'Class'])

print(df_reveal_true)
print(df_reveal_false)
# Out:
#      Index Dataset                                                PTM  Class
# 0        0  reveal  [polycoder-base, polycoder-large, polycoder-sm...      1
# 1        1  reveal    [polycoder-large, polycoder-base, codet5-small]      1
# 2        2  reveal    [polycoder-large, codegen-base, polycoder-base]      1
# 3        3  reveal    [polycoder-large, polycoder-base, codegen-base]      1
# 4        4  reveal   [polycoder-large, polycoder-base, codegen-small]      1
# ..     ...     ...                                                ...    ...
# 195    195  reveal  [polycoder-large, polycoder-base, polycoder-sm...      1
# 196    196  reveal  [polycoder-large, polycoder-base, polycoder-sm...      1
# 197    197  reveal    [polycoder-large, polycoder-base, codegen-base]      1
# 198    198  reveal  [polycoder-large, polycoder-small, polycoder-b...      1
# 199    199  reveal   [polycoder-large, codegen-base, polycoder-small]      1
#
# [200 rows x 4 columns]
#      Index Dataset                                                PTM  Class
# 0        0  reveal  [codegen-base, codet5-large, codet5-base, code...      0
# 1        1  reveal  [codegen-base, codet5-large, codet5-base, code...      0
# 2        2  reveal  [codet5-large, codet5-base, codebert-base, cod...      0
# 3        3  reveal  [codet5-large, codet5-base, codebert-base, cod...      0
# 4        4  reveal  [codegen-base, codet5-large, codet5-base, code...      0
# ..     ...     ...                                                ...    ...
# 195    195  reveal  [codegen-base, codet5-large, codet5-base, code...      0
# 196    196  reveal  [codegen-base, codet5-large, codet5-base, code...      0
# 197    197  reveal  [codet5-large, codet5-base, codebert-base, cod...      0
# 198    198  reveal  [codegen-base, codet5-large, codet5-base, code...      0
# 199    199  reveal  [codet5-large, codet5-base, codebert-base, cod...      0
#
# [200 rows x 4 columns]

# %%
PTM_str = ("codebert-small","codebert-base","codegen-small","codegen-base","codet5-small","codet5-base","codet5-large","polycoder-small","polycoder-base","polycoder-large")

true_dataset_class = {}
false_dataset_class = {}
true_tag = 1
false_tag = 0
    
for i in range(200):
    top_three_values = sorted(cwe119_data_auc[i], reverse=True)[:3] 
    top_three_indices = [cwe119_data_auc[i].index(value) for value in top_three_values]  
    top_three_PTMs = [PTM_str[index] for index in top_three_indices]  
    true_dataset_class[i] = [i, 'cwe119', top_three_PTMs, true_tag]     
    
    false_PTMs = set(PTM_str) - set(top_three_PTMs)
    false_dataset_class[i] = [i, 'cwe119', list(false_PTMs), false_tag]


df_cwe119_true = pd.DataFrame.from_dict(true_dataset_class, orient='index', columns=['Index', 'Dataset', 'PTM', 'Class'])
df_cwe119_false = pd.DataFrame.from_dict(false_dataset_class, orient='index', columns=['Index', 'Dataset', 'PTM', 'Class'])

print(df_cwe119_true)
print(df_cwe119_false)
# Out:
#      Index Dataset                                                PTM  Class
# 0        0  cwe119     [polycoder-large, codet5-base, polycoder-base]      1
# 1        1  cwe119    [polycoder-large, codet5-small, polycoder-base]      1
# 2        2  cwe119       [polycoder-large, codet5-base, codet5-small]      1
# 3        3  cwe119  [polycoder-large, polycoder-base, polycoder-sm...      1
# 4        4  cwe119     [polycoder-large, codet5-base, codebert-small]      1
# ..     ...     ...                                                ...    ...
# 195    195  cwe119    [polycoder-large, polycoder-base, codet5-small]      1
# 196    196  cwe119     [polycoder-large, codet5-base, codebert-small]      1
# 197    197  cwe119       [polycoder-large, codet5-small, codet5-base]      1
# 198    198  cwe119     [polycoder-large, codet5-base, polycoder-base]      1
# 199    199  cwe119     [polycoder-large, polycoder-base, codet5-base]      1
#
# [200 rows x 4 columns]
#      Index Dataset                                                PTM  Class
# 0        0  cwe119  [codegen-base, codet5-large, codebert-base, co...      0
# 1        1  cwe119  [codegen-base, codet5-large, codet5-base, code...      0
# 2        2  cwe119  [codegen-base, codet5-large, codebert-base, co...      0
# 3        3  cwe119  [codegen-base, codet5-large, codet5-base, code...      0
# 4        4  cwe119  [codegen-base, codet5-large, codebert-base, co...      0
# ..     ...     ...                                                ...    ...
# 195    195  cwe119  [codegen-base, codet5-large, codet5-base, code...      0
# 196    196  cwe119  [codegen-base, codet5-large, codebert-base, co...      0
# 197    197  cwe119  [codegen-base, codet5-large, codebert-base, co...      0
# 198    198  cwe119  [codegen-base, codet5-large, codebert-base, co...      0
# 199    199  cwe119  [codegen-base, codet5-large, codebert-base, co...      0
#
# [200 rows x 4 columns]

# %%
PTM_str = ("codebert-small","codebert-base","codegen-small","codegen-base","codet5-small","codet5-base","codet5-large","polycoder-small","polycoder-base","polycoder-large")

true_dataset_class = {}
false_dataset_class = {}
true_tag = 1
false_tag = 0
    
for i in range(200):
    top_three_values = sorted(cwe399_data_auc[i], reverse=True)[:3]  # 
    top_three_indices = [cwe399_data_auc[i].index(value) for value in top_three_values] 
    top_three_PTMs = [PTM_str[index] for index in top_three_indices]  # 
    true_dataset_class[i] = [i, 'cwe399', top_three_PTMs, true_tag]  #   
    
    false_PTMs = set(PTM_str) - set(top_three_PTMs)
    false_dataset_class[i] = [i, 'cwe399', list(false_PTMs), false_tag]


df_cwe399_true = pd.DataFrame.from_dict(true_dataset_class, orient='index', columns=['Index', 'Dataset', 'PTM', 'Class'])
df_cwe399_false = pd.DataFrame.from_dict(false_dataset_class, orient='index', columns=['Index', 'Dataset', 'PTM', 'Class'])

print(df_cwe399_true)
print(df_cwe399_false)
# Out:
#      Index Dataset                                                PTM  Class
# 0        0  cwe399     [polycoder-large, polycoder-base, codet5-base]      1
# 1        1  cwe399  [polycoder-large, polycoder-base, polycoder-sm...      1
# 2        2  cwe399     [polycoder-large, polycoder-base, codet5-base]      1
# 3        3  cwe399  [polycoder-large, polycoder-base, codebert-small]      1
# 4        4  cwe399  [polycoder-large, polycoder-base, polycoder-sm...      1
# ..     ...     ...                                                ...    ...
# 195    195  cwe399  [polycoder-large, polycoder-base, polycoder-sm...      1
# 196    196  cwe399     [polycoder-large, polycoder-base, codet5-base]      1
# 197    197  cwe399  [polycoder-large, codebert-small, polycoder-base]      1
# 198    198  cwe399  [polycoder-large, polycoder-base, polycoder-sm...      1
# 199    199  cwe399     [codet5-base, polycoder-large, polycoder-base]      1
#
# [200 rows x 4 columns]
#      Index Dataset                                                PTM  Class
# 0        0  cwe399  [codegen-base, codet5-large, codebert-base, co...      0
# 1        1  cwe399  [codegen-base, codet5-large, codet5-base, code...      0
# 2        2  cwe399  [codegen-base, codet5-large, codebert-base, co...      0
# 3        3  cwe399  [codegen-base, codet5-large, codet5-base, code...      0
# 4        4  cwe399  [codegen-base, codet5-large, codet5-base, code...      0
# ..     ...     ...                                                ...    ...
# 195    195  cwe399  [codegen-base, codet5-large, codet5-base, code...      0
# 196    196  cwe399  [codegen-base, codet5-large, codebert-base, co...      0
# 197    197  cwe399  [codegen-base, codet5-large, codet5-base, code...      0
# 198    198  cwe399  [codegen-base, codet5-large, codet5-base, code...      0
# 199    199  cwe399  [codegen-base, codet5-large, codebert-base, co...      0
#
# [200 rows x 4 columns]

# %%
df_codebert4vdcwe_small_test=pd.read_csv('df_codebert4vdcwe_small_test_feature.csv' )  
df_codebert4vdcwe_base_test=pd.read_csv('df_codebert4vdcwe_base_test_feature.csv' )  
df_codegen4vdcwe_small_test=pd.read_csv('df_codegen4vdcwe_small_test_feature.csv' )    
df_codegen4vdcwe_base_test=pd.read_csv('df_codegen4vdcwe_base_test_feature.csv' )  
df_codet54vdcwe_small_test=pd.read_csv('df_codet54vdcwe_small_test_feature.csv' )  
df_codet54vdcwe_base_test=pd.read_csv('df_codet54vdcwe_base_test_feature.csv' )  
df_codet54vdcwe_large_test=pd.read_csv('df_codet54vdcwe_large_test_feature.csv' )   
df_polycoder4vdcwe_small_test=pd.read_csv('df_polycoder4vdcwe_small_test_feature.csv' )  
df_polycoder4vdcwe_base_test=pd.read_csv('df_polycoder4vdcwe_base_test_feature.csv' )  
df_polycoder4vdcwe_large_test=pd.read_csv('df_polycoder4vdcwe_large_test_feature.csv' )  

print(df_codebert4vdcwe_small_test)
# Out:
#        L2_norm  Nuclear_norm  L0_norm    L1_norm      Mean    Median  \
# 0    996.50370     8160.7460  4196352  8047.5580 -0.000229  0.000925
# 1    997.14734     8195.4920  4196352  8088.3057 -0.000233  0.001037
# 2    996.37555     8185.3880  4196352  8061.4883 -0.000232  0.001056
# 3    995.80700     8177.4640  4196352  8051.8896 -0.000231  0.001225
# 4    995.79333     8156.7500  4196352  8074.7790 -0.000231  0.001045
# ..         ...           ...      ...        ...       ...       ...
# 795  881.84190     5164.0450  3361536  6982.4243 -0.000192 -0.001037
# 796  881.91174     5160.5854  3361536  6990.0186 -0.000190 -0.000822
# 797  881.53986     5138.6733  3361536  6962.8030 -0.000189 -0.000995
# 798  880.41340     5086.6265  3361536  6973.9087 -0.000190 -0.000766
# 799  882.19330     5164.9297  3361536  6987.5970 -0.000187 -0.000732
#
#           Std       Var  Skewness  Kurtosis  Entropy     Range
# 0    0.486455  0.236639  0.024380  0.005154     -inf  4.837975
# 1    0.486770  0.236945  0.025057  0.007149     -inf  5.019687
# 2    0.486393  0.236578  0.024270  0.005733     -inf  5.126326
# 3    0.486115  0.236308  0.025219  0.004306     -inf  4.633761
# 4    0.486109  0.236302  0.024222  0.004975     -inf  4.751749
# ..        ...       ...       ...       ...      ...       ...
# 795  0.480974  0.231336  0.040957  0.050795     -inf  4.733880
# 796  0.481012  0.231373  0.041007  0.049975     -inf  4.790275
# 797  0.480809  0.231178  0.040764  0.052009     -inf  4.750762
# 798  0.480195  0.230587  0.040803  0.051817     -inf  4.859105
# 799  0.481166  0.231521  0.041760  0.055221     -inf  4.819252
#
# [800 rows x 12 columns]

# %%
df_codebert4vdcwe_small_test_codexglue = df_codebert4vdcwe_small_test.iloc[:200].copy().reset_index(drop=True)
df_codebert4vdcwe_small_test_reveal = df_codebert4vdcwe_small_test.iloc[200:400].copy().reset_index(drop=True)
df_codebert4vdcwe_small_test_cwe119 = df_codebert4vdcwe_small_test.iloc[400:600].copy().reset_index(drop=True)
df_codebert4vdcwe_small_test_cwe399 = df_codebert4vdcwe_small_test.iloc[600:800].copy().reset_index(drop=True)
df_codebert4vdcwe_base_test_codexglue = df_codebert4vdcwe_base_test.iloc[:200].copy().reset_index(drop=True)
df_codebert4vdcwe_base_test_reveal = df_codebert4vdcwe_base_test.iloc[200:400].copy().reset_index(drop=True)
df_codebert4vdcwe_base_test_cwe119 = df_codebert4vdcwe_base_test.iloc[400:600].copy().reset_index(drop=True)
df_codebert4vdcwe_base_test_cwe399 = df_codebert4vdcwe_base_test.iloc[600:800].copy().reset_index(drop=True)
df_codegen4vdcwe_small_test_codexglue = df_codegen4vdcwe_small_test.iloc[:200].copy().reset_index(drop=True)
df_codegen4vdcwe_small_test_reveal = df_codegen4vdcwe_small_test.iloc[200:400].copy().reset_index(drop=True)
df_codegen4vdcwe_small_test_cwe119 = df_codegen4vdcwe_small_test.iloc[400:600].copy().reset_index(drop=True)
df_codegen4vdcwe_small_test_cwe399 = df_codegen4vdcwe_small_test.iloc[600:800].copy().reset_index(drop=True)
df_codegen4vdcwe_base_test_codexglue = df_codegen4vdcwe_base_test.iloc[:200].copy().reset_index(drop=True)
df_codegen4vdcwe_base_test_reveal = df_codegen4vdcwe_base_test.iloc[200:400].copy().reset_index(drop=True)
df_codegen4vdcwe_base_test_cwe119 = df_codegen4vdcwe_base_test.iloc[400:600].copy().reset_index(drop=True)
df_codegen4vdcwe_base_test_cwe399 = df_codegen4vdcwe_base_test.iloc[600:800].copy().reset_index(drop=True)
df_codet54vdcwe_small_test_codexglue = df_codet54vdcwe_small_test.iloc[:200].copy().reset_index(drop=True)
df_codet54vdcwe_small_test_reveal = df_codet54vdcwe_small_test.iloc[200:400].copy().reset_index(drop=True)
df_codet54vdcwe_small_test_cwe119 = df_codet54vdcwe_small_test.iloc[400:600].copy().reset_index(drop=True)
df_codet54vdcwe_small_test_cwe399 = df_codet54vdcwe_small_test.iloc[600:800].copy().reset_index(drop=True)
df_codet54vdcwe_base_test_codexglue = df_codet54vdcwe_base_test.iloc[:200].copy().reset_index(drop=True)
df_codet54vdcwe_base_test_reveal = df_codet54vdcwe_base_test.iloc[200:400].copy().reset_index(drop=True)
df_codet54vdcwe_base_test_cwe119 = df_codet54vdcwe_base_test.iloc[400:600].copy().reset_index(drop=True)
df_codet54vdcwe_base_test_cwe399 = df_codet54vdcwe_base_test.iloc[600:800].copy().reset_index(drop=True)
df_codet54vdcwe_large_test_codexglue = df_codet54vdcwe_large_test.iloc[:200].copy().reset_index(drop=True)
df_codet54vdcwe_large_test_reveal = df_codet54vdcwe_large_test.iloc[200:400].copy().reset_index(drop=True)
df_codet54vdcwe_large_test_cwe119 = df_codet54vdcwe_large_test.iloc[400:600].copy().reset_index(drop=True)
df_codet54vdcwe_large_test_cwe399 = df_codet54vdcwe_large_test.iloc[600:800].copy().reset_index(drop=True)
df_polycoder4vdcwe_small_test_codexglue = df_polycoder4vdcwe_small_test.iloc[:200].copy().reset_index(drop=True)
df_polycoder4vdcwe_small_test_reveal = df_polycoder4vdcwe_small_test.iloc[200:400].copy().reset_index(drop=True)
df_polycoder4vdcwe_small_test_cwe119 = df_polycoder4vdcwe_small_test.iloc[400:600].copy().reset_index(drop=True)
df_polycoder4vdcwe_small_test_cwe399 = df_polycoder4vdcwe_small_test.iloc[600:800].copy().reset_index(drop=True)
df_polycoder4vdcwe_base_test_codexglue = df_polycoder4vdcwe_base_test.iloc[:200].copy().reset_index(drop=True)
df_polycoder4vdcwe_base_test_reveal = df_polycoder4vdcwe_base_test.iloc[200:400].copy().reset_index(drop=True)
df_polycoder4vdcwe_base_test_cwe119 = df_polycoder4vdcwe_base_test.iloc[400:600].copy().reset_index(drop=True)
df_polycoder4vdcwe_base_test_cwe399 = df_polycoder4vdcwe_base_test.iloc[600:800].copy().reset_index(drop=True)
df_polycoder4vdcwe_large_test_codexglue = df_polycoder4vdcwe_large_test.iloc[:200].copy().reset_index(drop=True)
df_polycoder4vdcwe_large_test_reveal = df_polycoder4vdcwe_large_test.iloc[200:400].copy().reset_index(drop=True)
df_polycoder4vdcwe_large_test_cwe119 = df_polycoder4vdcwe_large_test.iloc[400:600].copy().reset_index(drop=True)
df_polycoder4vdcwe_large_test_cwe399 = df_polycoder4vdcwe_large_test.iloc[600:800].copy().reset_index(drop=True)

df_codebert4vdcwe_small_test_codexglue['Index'] = df_codebert4vdcwe_small_test_codexglue.index
df_codebert4vdcwe_small_test_reveal['Index'] = df_codebert4vdcwe_small_test_reveal.index
df_codebert4vdcwe_small_test_cwe119['Index'] = df_codebert4vdcwe_small_test_cwe119.index
df_codebert4vdcwe_small_test_cwe399['Index'] = df_codebert4vdcwe_small_test_cwe399.index
df_codebert4vdcwe_base_test_codexglue['Index'] = df_codebert4vdcwe_base_test_codexglue.index
df_codebert4vdcwe_base_test_reveal['Index'] = df_codebert4vdcwe_base_test_reveal.index
df_codebert4vdcwe_base_test_cwe119['Index'] = df_codebert4vdcwe_base_test_cwe119.index
df_codebert4vdcwe_base_test_cwe399['Index'] = df_codebert4vdcwe_base_test_cwe399.index
df_codegen4vdcwe_small_test_codexglue['Index'] = df_codegen4vdcwe_small_test_codexglue.index
df_codegen4vdcwe_small_test_reveal['Index'] = df_codegen4vdcwe_small_test_reveal.index
df_codegen4vdcwe_small_test_cwe119['Index'] = df_codegen4vdcwe_small_test_cwe119.index
df_codegen4vdcwe_small_test_cwe399['Index'] = df_codegen4vdcwe_small_test_cwe399.index
df_codegen4vdcwe_base_test_codexglue['Index'] = df_codegen4vdcwe_base_test_codexglue.index
df_codegen4vdcwe_base_test_reveal['Index'] = df_codegen4vdcwe_base_test_reveal.index
df_codegen4vdcwe_base_test_cwe119['Index'] = df_codegen4vdcwe_base_test_cwe119.index
df_codegen4vdcwe_base_test_cwe399['Index'] = df_codegen4vdcwe_base_test_cwe399.index
df_codet54vdcwe_small_test_codexglue['Index'] = df_codet54vdcwe_small_test_codexglue.index
df_codet54vdcwe_small_test_reveal['Index'] = df_codet54vdcwe_small_test_reveal.index
df_codet54vdcwe_small_test_cwe119['Index'] = df_codet54vdcwe_small_test_cwe119.index
df_codet54vdcwe_small_test_cwe399['Index'] = df_codet54vdcwe_small_test_cwe399.index
df_codet54vdcwe_base_test_codexglue['Index'] = df_codet54vdcwe_base_test_codexglue.index
df_codet54vdcwe_base_test_reveal['Index'] = df_codet54vdcwe_base_test_reveal.index
df_codet54vdcwe_base_test_cwe119['Index'] = df_codet54vdcwe_base_test_cwe119.index
df_codet54vdcwe_base_test_cwe399['Index'] = df_codet54vdcwe_base_test_cwe399.index
df_codet54vdcwe_large_test_codexglue['Index'] = df_codet54vdcwe_large_test_codexglue.index
df_codet54vdcwe_large_test_reveal['Index'] = df_codet54vdcwe_large_test_reveal.index
df_codet54vdcwe_large_test_cwe119['Index'] = df_codet54vdcwe_large_test_cwe119.index
df_codet54vdcwe_large_test_cwe399['Index'] = df_codet54vdcwe_large_test_cwe399.index
df_polycoder4vdcwe_small_test_codexglue['Index'] = df_polycoder4vdcwe_small_test_codexglue.index
df_polycoder4vdcwe_small_test_reveal['Index'] = df_polycoder4vdcwe_small_test_reveal.index
df_polycoder4vdcwe_small_test_cwe119['Index'] = df_polycoder4vdcwe_small_test_cwe119.index
df_polycoder4vdcwe_small_test_cwe399['Index'] = df_polycoder4vdcwe_small_test_cwe399.index
df_polycoder4vdcwe_base_test_codexglue['Index'] = df_polycoder4vdcwe_base_test_codexglue.index
df_polycoder4vdcwe_base_test_reveal['Index'] = df_polycoder4vdcwe_base_test_reveal.index
df_polycoder4vdcwe_base_test_cwe119['Index'] = df_polycoder4vdcwe_base_test_cwe119.index
df_polycoder4vdcwe_base_test_cwe399['Index'] = df_polycoder4vdcwe_base_test_cwe399.index
df_polycoder4vdcwe_large_test_codexglue['Index'] = df_polycoder4vdcwe_large_test_codexglue.index
df_polycoder4vdcwe_large_test_reveal['Index'] = df_polycoder4vdcwe_large_test_reveal.index
df_polycoder4vdcwe_large_test_cwe119['Index'] = df_polycoder4vdcwe_large_test_cwe119.index
df_polycoder4vdcwe_large_test_cwe399['Index'] = df_polycoder4vdcwe_large_test_cwe399.index





df_codebert4vdcwe_small_test_codexglue['Dataset'] = 'codexglue'
df_codebert4vdcwe_small_test_codexglue['PTM'] = 'codebert-small'
df_codebert4vdcwe_small_test_reveal['Dataset'] = 'reveal'
df_codebert4vdcwe_small_test_reveal['PTM'] = 'codebert-small'
df_codebert4vdcwe_small_test_cwe119['Dataset'] = 'cwe119'
df_codebert4vdcwe_small_test_cwe119['PTM'] = 'codebert-small'
df_codebert4vdcwe_small_test_cwe399['Dataset'] = 'cwe399'
df_codebert4vdcwe_small_test_cwe399['PTM'] = 'codebert-small'
df_codebert4vdcwe_base_test_codexglue['Dataset'] = 'codexglue'
df_codebert4vdcwe_base_test_codexglue['PTM'] = 'codebert-base'
df_codebert4vdcwe_base_test_reveal['Dataset'] = 'reveal'
df_codebert4vdcwe_base_test_reveal['PTM'] = 'codebert-base'
df_codebert4vdcwe_base_test_cwe119['Dataset'] = 'cwe119'
df_codebert4vdcwe_base_test_cwe119['PTM'] = 'codebert-base'
df_codebert4vdcwe_base_test_cwe399['Dataset'] = 'cwe399'
df_codebert4vdcwe_base_test_cwe399['PTM'] = 'codebert-base'
df_codegen4vdcwe_small_test_codexglue['Dataset'] = 'codexglue'
df_codegen4vdcwe_small_test_codexglue['PTM'] = 'codegen-small'
df_codegen4vdcwe_small_test_reveal['Dataset'] = 'reveal'
df_codegen4vdcwe_small_test_reveal['PTM'] = 'codegen-small'
df_codegen4vdcwe_small_test_cwe119['Dataset'] = 'cwe119'
df_codegen4vdcwe_small_test_cwe119['PTM'] = 'codegen-small'
df_codegen4vdcwe_small_test_cwe399['Dataset'] = 'cwe399'
df_codegen4vdcwe_small_test_cwe399['PTM'] = 'codegen-small'
df_codegen4vdcwe_base_test_codexglue['Dataset'] = 'codexglue'
df_codegen4vdcwe_base_test_codexglue['PTM'] = 'codegen-base'
df_codegen4vdcwe_base_test_reveal['Dataset'] = 'reveal'
df_codegen4vdcwe_base_test_reveal['PTM'] = 'codegen-base'
df_codegen4vdcwe_base_test_cwe119['Dataset'] = 'cwe119'
df_codegen4vdcwe_base_test_cwe119['PTM'] = 'codegen-base'
df_codegen4vdcwe_base_test_cwe399['Dataset'] = 'cwe399'
df_codegen4vdcwe_base_test_cwe399['PTM'] = 'codegen-base'
df_codet54vdcwe_small_test_codexglue['Dataset'] = 'codexglue'
df_codet54vdcwe_small_test_codexglue['PTM'] = 'codet5-small'
df_codet54vdcwe_small_test_reveal['Dataset'] = 'reveal'
df_codet54vdcwe_small_test_reveal['PTM'] = 'codet5-small'
df_codet54vdcwe_small_test_cwe119['Dataset'] = 'cwe119'
df_codet54vdcwe_small_test_cwe119['PTM'] = 'codet5-small'
df_codet54vdcwe_small_test_cwe399['Dataset'] = 'cwe399'
df_codet54vdcwe_small_test_cwe399['PTM'] = 'codet5-small'
df_codet54vdcwe_base_test_codexglue['Dataset'] = 'codexglue'
df_codet54vdcwe_base_test_codexglue['PTM'] = 'codet5-base'
df_codet54vdcwe_base_test_reveal['Dataset'] = 'reveal'
df_codet54vdcwe_base_test_reveal['PTM'] = 'codet5-base'
df_codet54vdcwe_base_test_cwe119['Dataset'] = 'cwe119'
df_codet54vdcwe_base_test_cwe119['PTM'] = 'codet5-base'
df_codet54vdcwe_base_test_cwe399['Dataset'] = 'cwe399'
df_codet54vdcwe_base_test_cwe399['PTM'] = 'codet5-base'
df_codet54vdcwe_large_test_codexglue['Dataset'] = 'codexglue'
df_codet54vdcwe_large_test_codexglue['PTM'] = 'codet5-large'
df_codet54vdcwe_large_test_reveal['Dataset'] = 'reveal'
df_codet54vdcwe_large_test_reveal['PTM'] = 'codet5-large'
df_codet54vdcwe_large_test_cwe119['Dataset'] = 'cwe119'
df_codet54vdcwe_large_test_cwe119['PTM'] = 'codet5-large'
df_codet54vdcwe_large_test_cwe399['Dataset'] = 'cwe399'
df_codet54vdcwe_large_test_cwe399['PTM'] = 'codet5-large'
df_polycoder4vdcwe_small_test_codexglue['Dataset'] = 'codexglue'
df_polycoder4vdcwe_small_test_codexglue['PTM'] = 'polycoder-small'
df_polycoder4vdcwe_small_test_reveal['Dataset'] = 'reveal'
df_polycoder4vdcwe_small_test_reveal['PTM'] = 'polycoder-small'
df_polycoder4vdcwe_small_test_cwe119['Dataset'] = 'cwe119'
df_polycoder4vdcwe_small_test_cwe119['PTM'] = 'polycoder-small'
df_polycoder4vdcwe_small_test_cwe399['Dataset'] = 'cwe399'
df_polycoder4vdcwe_small_test_cwe399['PTM'] = 'polycoder-small'
df_polycoder4vdcwe_base_test_codexglue['Dataset'] = 'codexglue'
df_polycoder4vdcwe_base_test_codexglue['PTM'] = 'polycoder-base'
df_polycoder4vdcwe_base_test_reveal['Dataset'] = 'reveal'
df_polycoder4vdcwe_base_test_reveal['PTM'] = 'polycoder-base'
df_polycoder4vdcwe_base_test_cwe119['Dataset'] = 'cwe119'
df_polycoder4vdcwe_base_test_cwe119['PTM'] = 'polycoder-base'
df_polycoder4vdcwe_base_test_cwe399['Dataset'] = 'cwe399'
df_polycoder4vdcwe_base_test_cwe399['PTM'] = 'polycoder-base'
df_polycoder4vdcwe_large_test_codexglue['Dataset'] = 'codexglue'
df_polycoder4vdcwe_large_test_codexglue['PTM'] = 'polycoder-large'
df_polycoder4vdcwe_large_test_reveal['Dataset'] = 'reveal'
df_polycoder4vdcwe_large_test_reveal['PTM'] = 'polycoder-large'
df_polycoder4vdcwe_large_test_cwe119['Dataset'] = 'cwe119'
df_polycoder4vdcwe_large_test_cwe119['PTM'] = 'polycoder-large'
df_polycoder4vdcwe_large_test_cwe399['Dataset'] = 'cwe399'
df_polycoder4vdcwe_large_test_cwe399['PTM'] = 'polycoder-large'


print(df_codebert4vdcwe_small_test_codexglue)
print(df_codebert4vdcwe_small_test_reveal)
print(df_codebert4vdcwe_small_test_cwe119)
print(df_codebert4vdcwe_small_test_cwe399)
# Out:
#        L2_norm  Nuclear_norm  L0_norm    L1_norm      Mean    Median  \
# 0    996.50370     8160.7460  4196352  8047.5580 -0.000229  0.000925
# 1    997.14734     8195.4920  4196352  8088.3057 -0.000233  0.001037
# 2    996.37555     8185.3880  4196352  8061.4883 -0.000232  0.001056
# 3    995.80700     8177.4640  4196352  8051.8896 -0.000231  0.001225
# 4    995.79333     8156.7500  4196352  8074.7790 -0.000231  0.001045
# ..         ...           ...      ...        ...       ...       ...
# 195  996.78937     8178.0100  4196352  8094.4210 -0.000232  0.000992
# 196  996.41345     8163.5920  4196352  8055.6733 -0.000231  0.001086
# 197  996.83980     8179.5815  4196352  8066.2334 -0.000229  0.001143
# 198  995.49900     8157.5176  4196352  8097.0747 -0.000230  0.001230
# 199  996.27826     8159.0205  4196352  8089.2900 -0.000229  0.001241
#
#           Std       Var  Skewness  Kurtosis  Entropy     Range  Index  \
# 0    0.486455  0.236639  0.024380  0.005154     -inf  4.837975      0
# 1    0.486770  0.236945  0.025057  0.007149     -inf  5.019687      1
# 2    0.486393  0.236578  0.024270  0.005733     -inf  5.126326      2
# 3    0.486115  0.236308  0.025219  0.004306     -inf  4.633761      3
# 4    0.486109  0.236302  0.024222  0.004975     -inf  4.751749      4
# ..        ...       ...       ...       ...      ...       ...    ...
# 195  0.486595  0.236774  0.024230  0.006630     -inf  5.139545    195
# 196  0.486411  0.236596  0.024320  0.002143     -inf  4.809514    196
# 197  0.486619  0.236798  0.024646  0.006590     -inf  5.057982    197
# 198  0.485965  0.236162  0.023793  0.003690     -inf  5.004067    198
# 199  0.486345  0.236532  0.024081  0.002946     -inf  5.051674    199
#
#        Dataset             PTM
# 0    codexglue  codebert-small
# 1    codexglue  codebert-small
# 2    codexglue  codebert-small
# 3    codexglue  codebert-small
# 4    codexglue  codebert-small
# ..         ...             ...
# 195  codexglue  codebert-small
# 196  codexglue  codebert-small
# 197  codexglue  codebert-small
# 198  codexglue  codebert-small
# 199  codexglue  codebert-small
#
# [200 rows x 15 columns]
#        L2_norm  Nuclear_norm  L0_norm    L1_norm      Mean    Median  \
# 0    996.71387     7586.7850  3492096  7203.7256 -0.000239  0.002010
# 1    997.03394     7570.1120  3492096  7231.2470 -0.000239  0.002045
# 2    997.28400     7586.7130  3492096  7224.7610 -0.000238  0.001850
# 3    997.10364     7595.4710  3492096  7231.5220 -0.000240  0.001862
# 4    995.94260     7569.3735  3492096  7225.4014 -0.000242  0.001773
# ..         ...           ...      ...        ...       ...       ...
# 195  996.82070     7574.7954  3492096  7235.8490 -0.000240  0.001708
# 196  997.42220     7572.2830  3492096  7233.9740 -0.000239  0.001966
# 197  995.41690     7562.0503  3492096  7201.3496 -0.000240  0.002042
# 198  996.19403     7569.6900  3492096  7212.4453 -0.000241  0.001990
# 199  997.49695     7570.9300  3492096  7225.3154 -0.000238  0.001962
#
#           Std       Var  Skewness  Kurtosis  Entropy     Range  Index Dataset  \
# 0    0.533368  0.284482 -0.007326 -0.075534     -inf  5.087523      0  reveal
# 1    0.533540  0.284665 -0.006274 -0.078949     -inf  5.119061      1  reveal
# 2    0.533674  0.284807 -0.006339 -0.076358     -inf  5.294848      2  reveal
# 3    0.533577  0.284704 -0.007510 -0.080676     -inf  5.060970      3  reveal
# 4    0.532956  0.284042 -0.005546 -0.081758     -inf  5.309635      4  reveal
# ..        ...       ...       ...       ...      ...       ...    ...     ...
# 195  0.533425  0.284543 -0.005659 -0.079171     -inf  5.294848    195  reveal
# 196  0.533747  0.284886 -0.006587 -0.080054     -inf  5.417719    196  reveal
# 197  0.532675  0.283742 -0.007292 -0.079844     -inf  5.378071    197  reveal
# 198  0.533090  0.284185 -0.006517 -0.079658     -inf  5.326662    198  reveal
# 199  0.533788  0.284929 -0.005297 -0.084074     -inf  4.990917    199  reveal
#
#                 PTM
# 0    codebert-small
# 1    codebert-small
# 2    codebert-small
# 3    codebert-small
# 4    codebert-small
# ..              ...
# 195  codebert-small
# 196  codebert-small
# 197  codebert-small
# 198  codebert-small
# 199  codebert-small
#
# [200 rows x 15 columns]
#        L2_norm  Nuclear_norm  L0_norm     L1_norm      Mean    Median  \
# 0    1229.1951     7956.8467  6106368  12530.5750 -0.000150  0.000718
# 1    1229.5700     8036.6177  6106368  12532.8780 -0.000152  0.000723
# 2    1229.5574     7979.6060  6106368  12512.0870 -0.000153  0.000773
# 3    1226.2830     7945.5390  6106368  12512.6455 -0.000151  0.000693
# 4    1227.0602     7996.4688  6106368  12482.8500 -0.000151  0.000779
# ..         ...           ...      ...         ...       ...       ...
# 195  1227.3445     8008.6640  6106368  12477.0960 -0.000152  0.000782
# 196  1227.8928     7986.8890  6106368  12524.2295 -0.000152  0.000737
# 197  1228.4194     8027.7944  6106368  12513.1980 -0.000151  0.000863
# 198  1227.7185     7994.8154  6106368  12541.8360 -0.000152  0.000718
# 199  1225.8474     7967.9004  6106368  12509.3950 -0.000150  0.000831
#
#           Std       Var  Skewness  Kurtosis  Entropy     Range  Index Dataset  \
# 0    0.497427  0.247433  0.019899  0.073128     -inf  4.868251      0  cwe119
# 1    0.497578  0.247584  0.019770  0.082075     -inf  5.800451      1  cwe119
# 2    0.497574  0.247579  0.019901  0.077514     -inf  4.868251      2  cwe119
# 3    0.496248  0.246263  0.020448  0.076102     -inf  5.593909      3  cwe119
# 4    0.496563  0.246575  0.019355  0.078065     -inf  4.868251      4  cwe119
# ..        ...       ...       ...       ...      ...       ...    ...     ...
# 195  0.496678  0.246689  0.020327  0.076716     -inf  4.876407    195  cwe119
# 196  0.496900  0.246910  0.020964  0.076969     -inf  5.593909    196  cwe119
# 197  0.497113  0.247121  0.019114  0.081407     -inf  5.271709    197  cwe119
# 198  0.496829  0.246839  0.020798  0.076196     -inf  4.882479    198  cwe119
# 199  0.496072  0.246087  0.019866  0.075052     -inf  4.882479    199  cwe119
#
#                 PTM
# 0    codebert-small
# 1    codebert-small
# 2    codebert-small
# 3    codebert-small
# 4    codebert-small
# ..              ...
# 195  codebert-small
# 196  codebert-small
# 197  codebert-small
# 198  codebert-small
# 199  codebert-small
#
# [200 rows x 15 columns]
#        L2_norm  Nuclear_norm  L0_norm    L1_norm      Mean    Median  \
# 0    881.81903     5177.2190  3361536  6970.1597 -0.000191 -0.000960
# 1    881.20930     5154.6553  3361536  6994.1865 -0.000190 -0.000822
# 2    880.77637     5128.6533  3361536  6986.7150 -0.000190 -0.000790
# 3    882.15360     5173.9220  3361536  7001.1963 -0.000190 -0.000865
# 4    879.29250     5075.6970  3361536  6993.1206 -0.000188 -0.000960
# ..         ...           ...      ...        ...       ...       ...
# 195  881.84190     5164.0450  3361536  6982.4243 -0.000192 -0.001037
# 196  881.91174     5160.5854  3361536  6990.0186 -0.000190 -0.000822
# 197  881.53986     5138.6733  3361536  6962.8030 -0.000189 -0.000995
# 198  880.41340     5086.6265  3361536  6973.9087 -0.000190 -0.000766
# 199  882.19330     5164.9297  3361536  6987.5970 -0.000187 -0.000732
#
#           Std       Var  Skewness  Kurtosis  Entropy     Range  Index Dataset  \
# 0    0.480962  0.231324  0.042804  0.052968     -inf  4.859105      0  cwe399
# 1    0.480629  0.231004  0.042309  0.055147     -inf  4.835814      1  cwe399
# 2    0.480393  0.230778  0.042672  0.049773     -inf  4.938309      2  cwe399
# 3    0.481144  0.231500  0.042506  0.054097     -inf  4.697420      3  cwe399
# 4    0.479584  0.230001  0.042475  0.049851     -inf  4.835814      4  cwe399
# ..        ...       ...       ...       ...      ...       ...    ...     ...
# 195  0.480974  0.231336  0.040957  0.050795     -inf  4.733880    195  cwe399
# 196  0.481012  0.231373  0.041007  0.049975     -inf  4.790275    196  cwe399
# 197  0.480809  0.231178  0.040764  0.052009     -inf  4.750762    197  cwe399
# 198  0.480195  0.230587  0.040803  0.051817     -inf  4.859105    198  cwe399
# 199  0.481166  0.231521  0.041760  0.055221     -inf  4.819252    199  cwe399
#
#                 PTM
# 0    codebert-small
# 1    codebert-small
# 2    codebert-small
# 3    codebert-small
# 4    codebert-small
# ..              ...
# 195  codebert-small
# 196  codebert-small
# 197  codebert-small
# 198  codebert-small
# 199  codebert-small
#
# [200 rows x 15 columns]

# %%
df_codebert4vdcwe_small_distance=pd.read_csv('df_codebert4vdcwe_small_distance.csv' )  
df_codebert4vdcwe_base_distance=pd.read_csv('df_codebert4vdcwe_base_distance.csv' )  
df_codegen4vdcwe_small_distance=pd.read_csv('df_codegen4vdcwe_small_distance.csv' )    
df_codegen4vdcwe_base_distance=pd.read_csv('df_codegen4vdcwe_base_distance.csv' )  
df_codet54vdcwe_small_distance=pd.read_csv('df_codet54vdcwe_small_distance.csv' )  
df_codet54vdcwe_base_distance=pd.read_csv('df_codet54vdcwe_base_distance.csv' )  
df_codet54vdcwe_large_distance=pd.read_csv('df_codet54vdcwe_large_distance.csv' )   
df_polycoder4vdcwe_small_distance=pd.read_csv('df_polycoder4vdcwe_small_distance.csv' )  
df_polycoder4vdcwe_base_distance=pd.read_csv('df_polycoder4vdcwe_base_distance.csv' )  
df_polycoder4vdcwe_large_distance=pd.read_csv('df_polycoder4vdcwe_large_distance.csv' )  



df_codebert4vdcwe_small_distance_codexglue = df_codebert4vdcwe_small_distance.iloc[:200].copy().reset_index(drop=True)

df_codebert4vdcwe_small_distance_reveal = df_codebert4vdcwe_small_distance.iloc[200:400].copy().reset_index(drop=True)
df_codebert4vdcwe_small_distance_cwe119 = df_codebert4vdcwe_small_distance.iloc[400:600].copy().reset_index(drop=True)
df_codebert4vdcwe_small_distance_cwe399 = df_codebert4vdcwe_small_distance.iloc[600:800].copy().reset_index(drop=True)
df_codebert4vdcwe_base_distance_codexglue = df_codebert4vdcwe_base_distance.iloc[:200].copy().reset_index(drop=True)
df_codebert4vdcwe_base_distance_reveal = df_codebert4vdcwe_base_distance.iloc[200:400].copy().reset_index(drop=True)
df_codebert4vdcwe_base_distance_cwe119 = df_codebert4vdcwe_base_distance.iloc[400:600].copy().reset_index(drop=True)
df_codebert4vdcwe_base_distance_cwe399 = df_codebert4vdcwe_base_distance.iloc[600:800].copy().reset_index(drop=True)
df_codegen4vdcwe_small_distance_codexglue = df_codegen4vdcwe_small_distance.iloc[:200].copy().reset_index(drop=True)
df_codegen4vdcwe_small_distance_reveal = df_codegen4vdcwe_small_distance.iloc[200:400].copy().reset_index(drop=True)
df_codegen4vdcwe_small_distance_cwe119 = df_codegen4vdcwe_small_distance.iloc[400:600].copy().reset_index(drop=True)
df_codegen4vdcwe_small_distance_cwe399 = df_codegen4vdcwe_small_distance.iloc[600:800].copy().reset_index(drop=True)
df_codegen4vdcwe_base_distance_codexglue = df_codegen4vdcwe_base_distance.iloc[:200].copy().reset_index(drop=True)
df_codegen4vdcwe_base_distance_reveal = df_codegen4vdcwe_base_distance.iloc[200:400].copy().reset_index(drop=True)
df_codegen4vdcwe_base_distance_cwe119 = df_codegen4vdcwe_base_distance.iloc[400:600].copy().reset_index(drop=True)
df_codegen4vdcwe_base_distance_cwe399 = df_codegen4vdcwe_base_distance.iloc[600:800].copy().reset_index(drop=True)
df_codet54vdcwe_small_distance_codexglue = df_codet54vdcwe_small_distance.iloc[:200].copy().reset_index(drop=True)
df_codet54vdcwe_small_distance_reveal = df_codet54vdcwe_small_distance.iloc[200:400].copy().reset_index(drop=True)
df_codet54vdcwe_small_distance_cwe119 = df_codet54vdcwe_small_distance.iloc[400:600].copy().reset_index(drop=True)
df_codet54vdcwe_small_distance_cwe399 = df_codet54vdcwe_small_distance.iloc[600:800].copy().reset_index(drop=True)
df_codet54vdcwe_base_distance_codexglue = df_codet54vdcwe_base_distance.iloc[:200].copy().reset_index(drop=True)
df_codet54vdcwe_base_distance_reveal = df_codet54vdcwe_base_distance.iloc[200:400].copy().reset_index(drop=True)
df_codet54vdcwe_base_distance_cwe119 = df_codet54vdcwe_base_distance.iloc[400:600].copy().reset_index(drop=True)
df_codet54vdcwe_base_distance_cwe399 = df_codet54vdcwe_base_distance.iloc[600:800].copy().reset_index(drop=True)
df_codet54vdcwe_large_distance_codexglue = df_codet54vdcwe_large_distance.iloc[:200].copy().reset_index(drop=True)
df_codet54vdcwe_large_distance_reveal = df_codet54vdcwe_large_distance.iloc[200:400].copy().reset_index(drop=True)
df_codet54vdcwe_large_distance_cwe119 = df_codet54vdcwe_large_distance.iloc[400:600].copy().reset_index(drop=True)
df_codet54vdcwe_large_distance_cwe399 = df_codet54vdcwe_large_distance.iloc[600:800].copy().reset_index(drop=True)
df_polycoder4vdcwe_small_distance_codexglue = df_polycoder4vdcwe_small_distance.iloc[:200].copy().reset_index(drop=True)
df_polycoder4vdcwe_small_distance_reveal = df_polycoder4vdcwe_small_distance.iloc[200:400].copy().reset_index(drop=True)
df_polycoder4vdcwe_small_distance_cwe119 = df_polycoder4vdcwe_small_distance.iloc[400:600].copy().reset_index(drop=True)
df_polycoder4vdcwe_small_distance_cwe399 = df_polycoder4vdcwe_small_distance.iloc[600:800].copy().reset_index(drop=True)
df_polycoder4vdcwe_base_distance_codexglue = df_polycoder4vdcwe_base_distance.iloc[:200].copy().reset_index(drop=True)
df_polycoder4vdcwe_base_distance_reveal = df_polycoder4vdcwe_base_distance.iloc[200:400].copy().reset_index(drop=True)
df_polycoder4vdcwe_base_distance_cwe119 = df_polycoder4vdcwe_base_distance.iloc[400:600].copy().reset_index(drop=True)
df_polycoder4vdcwe_base_distance_cwe399 = df_polycoder4vdcwe_base_distance.iloc[600:800].copy().reset_index(drop=True)
df_polycoder4vdcwe_large_distance_codexglue = df_polycoder4vdcwe_large_distance.iloc[:200].copy().reset_index(drop=True)
df_polycoder4vdcwe_large_distance_reveal = df_polycoder4vdcwe_large_distance.iloc[200:400].copy().reset_index(drop=True)
df_polycoder4vdcwe_large_distance_cwe119 = df_polycoder4vdcwe_large_distance.iloc[400:600].copy().reset_index(drop=True)
df_polycoder4vdcwe_large_distance_cwe399 = df_polycoder4vdcwe_large_distance.iloc[600:800].copy().reset_index(drop=True)


df_codebert4vdcwe_small_distance_codexglue['Index'] = df_codebert4vdcwe_small_distance_codexglue.index
df_codebert4vdcwe_small_distance_reveal['Index'] = df_codebert4vdcwe_small_distance_reveal.index
df_codebert4vdcwe_small_distance_cwe119['Index'] = df_codebert4vdcwe_small_distance_cwe119.index
df_codebert4vdcwe_small_distance_cwe399['Index'] = df_codebert4vdcwe_small_distance_cwe399.index
df_codebert4vdcwe_base_distance_codexglue['Index'] = df_codebert4vdcwe_base_distance_codexglue.index
df_codebert4vdcwe_base_distance_reveal['Index'] = df_codebert4vdcwe_base_distance_reveal.index
df_codebert4vdcwe_base_distance_cwe119['Index'] = df_codebert4vdcwe_base_distance_cwe119.index
df_codebert4vdcwe_base_distance_cwe399['Index'] = df_codebert4vdcwe_base_distance_cwe399.index
df_codegen4vdcwe_small_distance_codexglue['Index'] = df_codegen4vdcwe_small_distance_codexglue.index
df_codegen4vdcwe_small_distance_reveal['Index'] = df_codegen4vdcwe_small_distance_reveal.index
df_codegen4vdcwe_small_distance_cwe119['Index'] = df_codegen4vdcwe_small_distance_cwe119.index
df_codegen4vdcwe_small_distance_cwe399['Index'] = df_codegen4vdcwe_small_distance_cwe399.index
df_codegen4vdcwe_base_distance_codexglue['Index'] = df_codegen4vdcwe_base_distance_codexglue.index
df_codegen4vdcwe_base_distance_reveal['Index'] = df_codegen4vdcwe_base_distance_reveal.index
df_codegen4vdcwe_base_distance_cwe119['Index'] = df_codegen4vdcwe_base_distance_cwe119.index
df_codegen4vdcwe_base_distance_cwe399['Index'] = df_codegen4vdcwe_base_distance_cwe399.index
df_codet54vdcwe_small_distance_codexglue['Index'] = df_codet54vdcwe_small_distance_codexglue.index
df_codet54vdcwe_small_distance_reveal['Index'] = df_codet54vdcwe_small_distance_reveal.index
df_codet54vdcwe_small_distance_cwe119['Index'] = df_codet54vdcwe_small_distance_cwe119.index
df_codet54vdcwe_small_distance_cwe399['Index'] = df_codet54vdcwe_small_distance_cwe399.index
df_codet54vdcwe_base_distance_codexglue['Index'] = df_codet54vdcwe_base_distance_codexglue.index
df_codet54vdcwe_base_distance_reveal['Index'] = df_codet54vdcwe_base_distance_reveal.index
df_codet54vdcwe_base_distance_cwe119['Index'] = df_codet54vdcwe_base_distance_cwe119.index
df_codet54vdcwe_base_distance_cwe399['Index'] = df_codet54vdcwe_base_distance_cwe399.index
df_codet54vdcwe_large_distance_codexglue['Index'] = df_codet54vdcwe_large_distance_codexglue.index
df_codet54vdcwe_large_distance_reveal['Index'] = df_codet54vdcwe_large_distance_reveal.index
df_codet54vdcwe_large_distance_cwe119['Index'] = df_codet54vdcwe_large_distance_cwe119.index
df_codet54vdcwe_large_distance_cwe399['Index'] = df_codet54vdcwe_large_distance_cwe399.index
df_polycoder4vdcwe_small_distance_codexglue['Index'] = df_polycoder4vdcwe_small_distance_codexglue.index
df_polycoder4vdcwe_small_distance_reveal['Index'] = df_polycoder4vdcwe_small_distance_reveal.index
df_polycoder4vdcwe_small_distance_cwe119['Index'] = df_polycoder4vdcwe_small_distance_cwe119.index
df_polycoder4vdcwe_small_distance_cwe399['Index'] = df_polycoder4vdcwe_small_distance_cwe399.index
df_polycoder4vdcwe_base_distance_codexglue['Index'] = df_polycoder4vdcwe_base_distance_codexglue.index
df_polycoder4vdcwe_base_distance_reveal['Index'] = df_polycoder4vdcwe_base_distance_reveal.index
df_polycoder4vdcwe_base_distance_cwe119['Index'] = df_polycoder4vdcwe_base_distance_cwe119.index
df_polycoder4vdcwe_base_distance_cwe399['Index'] = df_polycoder4vdcwe_base_distance_cwe399.index
df_polycoder4vdcwe_large_distance_codexglue['Index'] = df_polycoder4vdcwe_large_distance_codexglue.index
df_polycoder4vdcwe_large_distance_reveal['Index'] = df_polycoder4vdcwe_large_distance_reveal.index
df_polycoder4vdcwe_large_distance_cwe119['Index'] = df_polycoder4vdcwe_large_distance_cwe119.index
df_polycoder4vdcwe_large_distance_cwe399['Index'] = df_polycoder4vdcwe_large_distance_cwe399.index



df_codebert4vdcwe_small_distance_codexglue['Dataset'] = 'codexglue'
df_codebert4vdcwe_small_distance_codexglue['PTM'] = 'codebert-small'
df_codebert4vdcwe_small_distance_reveal['Dataset'] = 'reveal'
df_codebert4vdcwe_small_distance_reveal['PTM'] = 'codebert-small'
df_codebert4vdcwe_small_distance_cwe119['Dataset'] = 'cwe119'
df_codebert4vdcwe_small_distance_cwe119['PTM'] = 'codebert-small'
df_codebert4vdcwe_small_distance_cwe399['Dataset'] = 'cwe399'
df_codebert4vdcwe_small_distance_cwe399['PTM'] = 'codebert-small'
df_codebert4vdcwe_base_distance_codexglue['Dataset'] = 'codexglue'
df_codebert4vdcwe_base_distance_codexglue['PTM'] = 'codebert-base'
df_codebert4vdcwe_base_distance_reveal['Dataset'] = 'reveal'
df_codebert4vdcwe_base_distance_reveal['PTM'] = 'codebert-base'
df_codebert4vdcwe_base_distance_cwe119['Dataset'] = 'cwe119'
df_codebert4vdcwe_base_distance_cwe119['PTM'] = 'codebert-base'
df_codebert4vdcwe_base_distance_cwe399['Dataset'] = 'cwe399'
df_codebert4vdcwe_base_distance_cwe399['PTM'] = 'codebert-base'
df_codegen4vdcwe_small_distance_codexglue['Dataset'] = 'codexglue'
df_codegen4vdcwe_small_distance_codexglue['PTM'] = 'codegen-small'
df_codegen4vdcwe_small_distance_reveal['Dataset'] = 'reveal'
df_codegen4vdcwe_small_distance_reveal['PTM'] = 'codegen-small'
df_codegen4vdcwe_small_distance_cwe119['Dataset'] = 'cwe119'
df_codegen4vdcwe_small_distance_cwe119['PTM'] = 'codegen-small'
df_codegen4vdcwe_small_distance_cwe399['Dataset'] = 'cwe399'
df_codegen4vdcwe_small_distance_cwe399['PTM'] = 'codegen-small'
df_codegen4vdcwe_base_distance_codexglue['Dataset'] = 'codexglue'
df_codegen4vdcwe_base_distance_codexglue['PTM'] = 'codegen-base'
df_codegen4vdcwe_base_distance_reveal['Dataset'] = 'reveal'
df_codegen4vdcwe_base_distance_reveal['PTM'] = 'codegen-base'
df_codegen4vdcwe_base_distance_cwe119['Dataset'] = 'cwe119'
df_codegen4vdcwe_base_distance_cwe119['PTM'] = 'codegen-base'
df_codegen4vdcwe_base_distance_cwe399['Dataset'] = 'cwe399'
df_codegen4vdcwe_base_distance_cwe399['PTM'] = 'codegen-base'
df_codet54vdcwe_small_distance_codexglue['Dataset'] = 'codexglue'
df_codet54vdcwe_small_distance_codexglue['PTM'] = 'codet5-small'
df_codet54vdcwe_small_distance_reveal['Dataset'] = 'reveal'
df_codet54vdcwe_small_distance_reveal['PTM'] = 'codet5-small'
df_codet54vdcwe_small_distance_cwe119['Dataset'] = 'cwe119'
df_codet54vdcwe_small_distance_cwe119['PTM'] = 'codet5-small'
df_codet54vdcwe_small_distance_cwe399['Dataset'] = 'cwe399'
df_codet54vdcwe_small_distance_cwe399['PTM'] = 'codet5-small'
df_codet54vdcwe_base_distance_codexglue['Dataset'] = 'codexglue'
df_codet54vdcwe_base_distance_codexglue['PTM'] = 'codet5-base'
df_codet54vdcwe_base_distance_reveal['Dataset'] = 'reveal'
df_codet54vdcwe_base_distance_reveal['PTM'] = 'codet5-base'
df_codet54vdcwe_base_distance_cwe119['Dataset'] = 'cwe119'
df_codet54vdcwe_base_distance_cwe119['PTM'] = 'codet5-base'
df_codet54vdcwe_base_distance_cwe399['Dataset'] = 'cwe399'
df_codet54vdcwe_base_distance_cwe399['PTM'] = 'codet5-base'
df_codet54vdcwe_large_distance_codexglue['Dataset'] = 'codexglue'
df_codet54vdcwe_large_distance_codexglue['PTM'] = 'codet5-large'
df_codet54vdcwe_large_distance_reveal['Dataset'] = 'reveal'
df_codet54vdcwe_large_distance_reveal['PTM'] = 'codet5-large'
df_codet54vdcwe_large_distance_cwe119['Dataset'] = 'cwe119'
df_codet54vdcwe_large_distance_cwe119['PTM'] = 'codet5-large'
df_codet54vdcwe_large_distance_cwe399['Dataset'] = 'cwe399'
df_codet54vdcwe_large_distance_cwe399['PTM'] = 'codet5-large'
df_polycoder4vdcwe_small_distance_codexglue['Dataset'] = 'codexglue'
df_polycoder4vdcwe_small_distance_codexglue['PTM'] = 'polycoder-small'
df_polycoder4vdcwe_small_distance_reveal['Dataset'] = 'reveal'
df_polycoder4vdcwe_small_distance_reveal['PTM'] = 'polycoder-small'
df_polycoder4vdcwe_small_distance_cwe119['Dataset'] = 'cwe119'
df_polycoder4vdcwe_small_distance_cwe119['PTM'] = 'polycoder-small'
df_polycoder4vdcwe_small_distance_cwe399['Dataset'] = 'cwe399'
df_polycoder4vdcwe_small_distance_cwe399['PTM'] = 'polycoder-small'
df_polycoder4vdcwe_base_distance_codexglue['Dataset'] = 'codexglue'
df_polycoder4vdcwe_base_distance_codexglue['PTM'] = 'polycoder-base'
df_polycoder4vdcwe_base_distance_reveal['Dataset'] = 'reveal'
df_polycoder4vdcwe_base_distance_reveal['PTM'] = 'polycoder-base'
df_polycoder4vdcwe_base_distance_cwe119['Dataset'] = 'cwe119'
df_polycoder4vdcwe_base_distance_cwe119['PTM'] = 'polycoder-base'
df_polycoder4vdcwe_base_distance_cwe399['Dataset'] = 'cwe399'
df_polycoder4vdcwe_base_distance_cwe399['PTM'] = 'polycoder-base'
df_polycoder4vdcwe_large_distance_codexglue['Dataset'] = 'codexglue'
df_polycoder4vdcwe_large_distance_codexglue['PTM'] = 'polycoder-large'
df_polycoder4vdcwe_large_distance_reveal['Dataset'] = 'reveal'
df_polycoder4vdcwe_large_distance_reveal['PTM'] = 'polycoder-large'
df_polycoder4vdcwe_large_distance_cwe119['Dataset'] = 'cwe119'
df_polycoder4vdcwe_large_distance_cwe119['PTM'] = 'polycoder-large'
df_polycoder4vdcwe_large_distance_cwe399['Dataset'] = 'cwe399'
df_polycoder4vdcwe_large_distance_cwe399['PTM'] = 'polycoder-large'

print(df_codebert4vdcwe_small_distance_codexglue)
print(df_codebert4vdcwe_small_distance_reveal)
print(df_codebert4vdcwe_small_distance_cwe119)
print(df_codebert4vdcwe_small_distance_cwe399)
# Out:
#           MMD   L2_loss  L2_loss_norm    L2s_loss  L2s_loss_norm    Dot_loss  \
# 0    0.000245  9.910314      0.732023  100.055779       0.543153 -131.547943
# 1    0.000244  9.926476      0.732930  100.397621       0.544523 -131.511307
# 2    0.000243  9.911901      0.732159  100.109352       0.543429 -131.498154
# 3    0.000244  9.912246      0.732284  100.118958       0.543618 -131.445709
# 4    0.000245  9.901173      0.731569   99.863754       0.542503 -131.549088
# ..        ...       ...           ...         ...            ...         ...
# 195  0.000245  9.916616      0.732485  100.207855       0.543941 -131.462326
# 196  0.000244  9.915999      0.732310  100.178436       0.543599 -131.548920
# 197  0.000244  9.911435      0.731892  100.104034       0.543034 -131.617737
# 198  0.000244  9.895227      0.731281   99.751480       0.542080 -131.534744
# 199  0.000244  9.909656      0.732041  100.058586       0.543259 -131.520187
#
#      Dot_loss_norm  Index    Dataset             PTM
# 0        -0.728423      0  codexglue  codebert-small
# 1        -0.727738      1  codexglue  codebert-small
# 2        -0.728285      2  codexglue  codebert-small
# 3        -0.728191      3  codexglue  codebert-small
# 4        -0.728749      4  codexglue  codebert-small
# ..             ...    ...        ...             ...
# 195      -0.728029    195  codexglue  codebert-small
# 196      -0.728200    196  codexglue  codebert-small
# 197      -0.728483    197  codexglue  codebert-small
# 198      -0.728960    198  codexglue  codebert-small
# 199      -0.728370    199  codexglue  codebert-small
#
# [200 rows x 10 columns]
#           MMD    L2_loss  L2_loss_norm    L2s_loss  L2s_loss_norm    Dot_loss  \
# 0    0.000296  10.260440      0.690555  107.515274       0.484983 -164.718994
# 1    0.000294  10.254161      0.690361  107.371231       0.484676 -164.703232
# 2    0.000291  10.257152      0.690509  107.435402       0.484893 -164.697723
# 3    0.000296  10.262415      0.690720  107.525238       0.485154 -164.745468
# 4    0.000297  10.257477      0.690500  107.462662       0.484940 -164.699890
# ..        ...        ...           ...         ...            ...         ...
# 195  0.000294  10.263444      0.690641  107.548203       0.485025 -164.819519
# 196  0.000298  10.252898      0.690030  107.331909       0.484159 -164.874023
# 197  0.000291  10.242817      0.689936  107.128174       0.484066 -164.597610
# 198  0.000293  10.252145      0.690285  107.337196       0.484638 -164.692505
# 199  0.000297  10.254272      0.690024  107.366714       0.484232 -164.922150
#
#      Dot_loss_norm  Index Dataset             PTM
# 0        -0.757509      0  reveal  codebert-small
# 1        -0.757662      1  reveal  codebert-small
# 2        -0.757553      2  reveal  codebert-small
# 3        -0.757423      3  reveal  codebert-small
# 4        -0.757530      4  reveal  codebert-small
# ..             ...    ...     ...             ...
# 195      -0.757488    195  reveal  codebert-small
# 196      -0.757920    196  reveal  codebert-small
# 197      -0.757967    197  reveal  codebert-small
# 198      -0.757681    198  reveal  codebert-small
# 199      -0.757884    199  reveal  codebert-small
#
# [200 rows x 10 columns]
#           MMD    L2_loss  L2_loss_norm    L2s_loss  L2s_loss_norm    Dot_loss  \
# 0    0.000156  10.171770      0.733594  108.126060       0.559927 -135.848969
# 1    0.000169  10.193332      0.735015  108.592728       0.561881 -135.646484
# 2    0.000158  10.187616      0.734463  108.469292       0.561232 -135.805237
# 3    0.000176  10.168027      0.733739  108.113762       0.560312 -135.608322
# 4    0.000163  10.170378      0.733965  108.084038       0.560325 -135.603882
# ..        ...        ...           ...         ...            ...         ...
# 195  0.000143  10.188571      0.735316  108.494827       0.562547 -135.406158
# 196  0.000170  10.173971      0.733908  108.214096       0.560483 -135.701248
# 197  0.000184  10.178196      0.734120  108.303551       0.560748 -135.667557
# 198  0.000173  10.161643      0.733161  107.924278       0.559274 -135.780289
# 199  0.000157  10.160502      0.733675  107.897789       0.560084 -135.498627
#
#      Dot_loss_norm  Index Dataset             PTM
# 0        -0.720036      0  cwe119  codebert-small
# 1        -0.719060      1  cwe119  codebert-small
# 2        -0.719384      2  cwe119  codebert-small
# 3        -0.719844      3  cwe119  codebert-small
# 4        -0.719837      4  cwe119  codebert-small
# ..             ...    ...     ...             ...
# 195      -0.718726    195  cwe119  codebert-small
# 196      -0.719758    196  cwe119  codebert-small
# 197      -0.719626    197  cwe119  codebert-small
# 198      -0.720363    198  cwe119  codebert-small
# 199      -0.719958    199  cwe119  codebert-small
#
# [200 rows x 10 columns]
#           MMD   L2_loss  L2_loss_norm   L2s_loss  L2s_loss_norm    Dot_loss  \
# 0    0.000338  9.026101      0.673117  87.624443       0.483476 -133.730118
# 1    0.000260  9.012892      0.672367  87.347946       0.482343 -133.759308
# 2    0.000292  9.029318      0.673618  87.632027       0.484110 -133.638443
# 3    0.000293  9.019392      0.672577  87.455612       0.482568 -133.822983
# 4    0.000374  8.979428      0.670126  86.726776       0.479382 -133.950500
# ..        ...       ...           ...        ...            ...         ...
# 195  0.000251  9.024018      0.672966  87.556870       0.483265 -133.782639
# 196  0.000392  9.016862      0.672363  87.476349       0.482663 -133.863007
# 197  0.000312  9.004637      0.671675  87.236725       0.481670 -133.865723
# 198  0.000289  8.991247      0.670937  87.002693       0.480755 -133.855103
# 199  0.000338  9.036510      0.673590  87.878731       0.484323 -133.717148
#
#      Dot_loss_norm  Index Dataset             PTM
# 0        -0.758262      0  cwe399  codebert-small
# 1        -0.758829      1  cwe399  codebert-small
# 2        -0.757945      2  cwe399  codebert-small
# 3        -0.758716      3  cwe399  codebert-small
# 4        -0.760309      4  cwe399  codebert-small
# ..             ...    ...     ...             ...
# 195      -0.758367    195  cwe399  codebert-small
# 196      -0.758668    196  cwe399  codebert-small
# 197      -0.759165    197  cwe399  codebert-small
# 198      -0.759623    198  cwe399  codebert-small
# 199      -0.757839    199  cwe399  codebert-small
#
# [200 rows x 10 columns]

# %%
import pandas as pd

def process_data(df_true, df_false, df_test, df_distance):

    new_column_names = ['Class','L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range','MMD', 'L2_loss', 'L2_loss_norm', 'L2s_loss', 'L2s_loss_norm','Dot_loss','Dot_loss_norm','Index', 'Dataset','PTM']

    class_column = ['Class']
    feature_column = ['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range']
    distance_column = ['MMD', 'L2_loss', 'L2_loss_norm', 'L2s_loss', 'L2s_loss_norm','Dot_loss','Dot_loss_norm','Index', 'Dataset','PTM']


    df_dataset_tag1 = pd.DataFrame(columns=new_column_names)

    for i in range(200):
        ptm_value1 = df_distance.iloc[i]['PTM']  
        ptm_value2 = df_test.iloc[i]['PTM']  
        
        if ptm_value1 == ptm_value2:
            ptm_value = ptm_value1
            ptm_value_list_true = df_true.iloc[i]['PTM']
            ptm_value_list_false = df_false.iloc[i]['PTM']
            if ptm_value in ptm_value_list_true:
                class_value = df_true.loc[i, class_column]
                feature_value = df_test.loc[i, feature_column]
                distance_value = df_distance.loc[i, distance_column]
                

                new_row_data = {
                    'Class': class_value[0],
                    'L2_norm': feature_value[0],
                    'Nuclear_norm': feature_value[1],
                    'L0_norm': feature_value[2],
                    'L1_norm': feature_value[3],
                    'Mean': feature_value[4],
                    'Median': feature_value[5],
                    'Std': feature_value[6],
                    'Var': feature_value[7],
                    'Skewness': feature_value[8],
                    'Kurtosis': feature_value[9],
                    'Entropy': feature_value[10],
                    'Range': feature_value[11],
                    'MMD': distance_value[0],
                    'L2_loss': distance_value[1],
                    'L2_loss_norm': distance_value[2],
                    'L2s_loss': distance_value[3],
                    'L2s_loss_norm': distance_value[4],
                    'Dot_loss': distance_value[5],
                    'Dot_loss_norm': distance_value[6],
                    'Index': distance_value[7],
                    'Dataset': distance_value[8],
                    'PTM': distance_value[9]
                }
    

                new_row = pd.DataFrame(new_row_data, index=[0])
    

                df_dataset_tag1 = pd.concat([df_dataset_tag1, new_row], ignore_index=True)
            if ptm_value in ptm_value_list_false:
                class_value = df_false.loc[i, class_column]
                feature_value = df_test.loc[i, feature_column]
                distance_value = df_distance.loc[i, distance_column]
                

                new_row_data = {
                    'Class': class_value[0],
                    'L2_norm': feature_value[0],
                    'Nuclear_norm': feature_value[1],
                    'L0_norm': feature_value[2],
                    'L1_norm': feature_value[3],
                    'Mean': feature_value[4],
                    'Median': feature_value[5],
                    'Std': feature_value[6],
                    'Var': feature_value[7],
                    'Skewness': feature_value[8],
                    'Kurtosis': feature_value[9],
                    'Entropy': feature_value[10],
                    'Range': feature_value[11],
                    'MMD': distance_value[0],
                    'L2_loss': distance_value[1],
                    'L2_loss_norm': distance_value[2],
                    'L2s_loss': distance_value[3],
                    'L2s_loss_norm': distance_value[4],
                    'Dot_loss': distance_value[5],
                    'Dot_loss_norm': distance_value[6],
                    'Index': distance_value[7],
                    'Dataset': distance_value[8],
                    'PTM': distance_value[9]
                }
    
  
                new_row = pd.DataFrame(new_row_data, index=[0])
    

                df_dataset_tag1 = pd.concat([df_dataset_tag1, new_row], ignore_index=True)
    return  df_dataset_tag1         
            
            

df_dataset_tag1_codebert_small_codexglue = process_data(df_codexglue_true, df_codexglue_false, df_codebert4vdcwe_small_test_codexglue, df_codebert4vdcwe_small_distance_codexglue)
df_dataset_tag1_codebert_base_codexglue = process_data(df_codexglue_true, df_codexglue_false, df_codebert4vdcwe_base_test_codexglue, df_codebert4vdcwe_base_distance_codexglue)
df_dataset_tag1_codegen_small_codexglue = process_data(df_codexglue_true, df_codexglue_false, df_codegen4vdcwe_small_test_codexglue, df_codegen4vdcwe_small_distance_codexglue)
df_dataset_tag1_codegen_base_codexglue = process_data(df_codexglue_true, df_codexglue_false, df_codegen4vdcwe_base_test_codexglue, df_codegen4vdcwe_base_distance_codexglue)
df_dataset_tag1_codet5_small_codexglue = process_data(df_codexglue_true, df_codexglue_false, df_codet54vdcwe_small_test_codexglue, df_codet54vdcwe_small_distance_codexglue)
df_dataset_tag1_codet5_base_codexglue = process_data(df_codexglue_true, df_codexglue_false, df_codet54vdcwe_base_test_codexglue, df_codet54vdcwe_base_distance_codexglue)
df_dataset_tag1_codet5_large_codexglue = process_data(df_codexglue_true, df_codexglue_false, df_codet54vdcwe_large_test_codexglue, df_codet54vdcwe_large_distance_codexglue)
df_dataset_tag1_polycoder_small_codexglue = process_data(df_codexglue_true, df_codexglue_false, df_polycoder4vdcwe_small_test_codexglue, df_polycoder4vdcwe_small_distance_codexglue)
df_dataset_tag1_polycoder_base_codexglue = process_data(df_codexglue_true, df_codexglue_false, df_polycoder4vdcwe_base_test_codexglue, df_polycoder4vdcwe_base_distance_codexglue)
df_dataset_tag1_polycoder_large_codexglue = process_data(df_codexglue_true, df_codexglue_false, df_polycoder4vdcwe_large_test_codexglue, df_polycoder4vdcwe_large_distance_codexglue)

df_dataset_tag1_codebert_small_reveal = process_data(df_reveal_true, df_reveal_false, df_codebert4vdcwe_small_test_reveal, df_codebert4vdcwe_small_distance_reveal)
df_dataset_tag1_codebert_base_reveal = process_data(df_reveal_true, df_reveal_false, df_codebert4vdcwe_base_test_reveal, df_codebert4vdcwe_base_distance_reveal)
df_dataset_tag1_codegen_small_reveal = process_data(df_reveal_true, df_reveal_false, df_codegen4vdcwe_small_test_reveal, df_codegen4vdcwe_small_distance_reveal)
df_dataset_tag1_codegen_base_reveal = process_data(df_reveal_true, df_reveal_false, df_codegen4vdcwe_base_test_reveal, df_codegen4vdcwe_base_distance_reveal)
df_dataset_tag1_codet5_small_reveal = process_data(df_reveal_true, df_reveal_false, df_codet54vdcwe_small_test_reveal, df_codet54vdcwe_small_distance_reveal)
df_dataset_tag1_codet5_base_reveal = process_data(df_reveal_true, df_reveal_false, df_codet54vdcwe_base_test_reveal, df_codet54vdcwe_base_distance_reveal)
df_dataset_tag1_codet5_large_reveal = process_data(df_reveal_true, df_reveal_false, df_codet54vdcwe_large_test_reveal, df_codet54vdcwe_large_distance_reveal)
df_dataset_tag1_polycoder_small_reveal = process_data(df_reveal_true, df_reveal_false, df_polycoder4vdcwe_small_test_reveal, df_polycoder4vdcwe_small_distance_reveal)
df_dataset_tag1_polycoder_base_reveal = process_data(df_reveal_true, df_reveal_false, df_polycoder4vdcwe_base_test_reveal, df_polycoder4vdcwe_base_distance_reveal)
df_dataset_tag1_polycoder_large_reveal = process_data(df_reveal_true, df_reveal_false, df_polycoder4vdcwe_large_test_reveal, df_polycoder4vdcwe_large_distance_reveal)

df_dataset_tag1_codebert_small_cwe119 = process_data(df_cwe119_true, df_cwe119_false, df_codebert4vdcwe_small_test_cwe119, df_codebert4vdcwe_small_distance_cwe119)
df_dataset_tag1_codebert_base_cwe119 = process_data(df_cwe119_true, df_cwe119_false, df_codebert4vdcwe_base_test_cwe119, df_codebert4vdcwe_base_distance_cwe119)
df_dataset_tag1_codegen_small_cwe119 = process_data(df_cwe119_true, df_cwe119_false, df_codegen4vdcwe_small_test_cwe119, df_codegen4vdcwe_small_distance_cwe119)
df_dataset_tag1_codegen_base_cwe119 = process_data(df_cwe119_true, df_cwe119_false, df_codegen4vdcwe_base_test_cwe119, df_codegen4vdcwe_base_distance_cwe119)
df_dataset_tag1_codet5_small_cwe119 = process_data(df_cwe119_true, df_cwe119_false, df_codet54vdcwe_small_test_cwe119, df_codet54vdcwe_small_distance_cwe119)
df_dataset_tag1_codet5_base_cwe119 = process_data(df_cwe119_true, df_cwe119_false, df_codet54vdcwe_base_test_cwe119, df_codet54vdcwe_base_distance_cwe119)
df_dataset_tag1_codet5_large_cwe119 = process_data(df_cwe119_true, df_cwe119_false, df_codet54vdcwe_large_test_cwe119, df_codet54vdcwe_large_distance_cwe119)
df_dataset_tag1_polycoder_small_cwe119 = process_data(df_cwe119_true, df_cwe119_false, df_polycoder4vdcwe_small_test_cwe119, df_polycoder4vdcwe_small_distance_cwe119)
df_dataset_tag1_polycoder_base_cwe119 = process_data(df_cwe119_true, df_cwe119_false, df_polycoder4vdcwe_base_test_cwe119, df_polycoder4vdcwe_base_distance_cwe119)
df_dataset_tag1_polycoder_large_cwe119 = process_data(df_cwe119_true, df_cwe119_false, df_polycoder4vdcwe_large_test_cwe119, df_polycoder4vdcwe_large_distance_cwe119)

df_dataset_tag1_codebert_small_cwe399 = process_data(df_cwe399_true, df_cwe399_false, df_codebert4vdcwe_small_test_cwe399, df_codebert4vdcwe_small_distance_cwe399)
df_dataset_tag1_codebert_base_cwe399 = process_data(df_cwe399_true, df_cwe399_false, df_codebert4vdcwe_base_test_cwe399, df_codebert4vdcwe_base_distance_cwe399)
df_dataset_tag1_codegen_small_cwe399 = process_data(df_cwe399_true, df_cwe399_false, df_codegen4vdcwe_small_test_cwe399, df_codegen4vdcwe_small_distance_cwe399)
df_dataset_tag1_codegen_base_cwe399 = process_data(df_cwe399_true, df_cwe399_false, df_codegen4vdcwe_base_test_cwe399, df_codegen4vdcwe_base_distance_cwe399)
df_dataset_tag1_codet5_small_cwe399 = process_data(df_cwe399_true, df_cwe399_false, df_codet54vdcwe_small_test_cwe399, df_codet54vdcwe_small_distance_cwe399)
df_dataset_tag1_codet5_base_cwe399 = process_data(df_cwe399_true, df_cwe399_false, df_codet54vdcwe_base_test_cwe399, df_codet54vdcwe_base_distance_cwe399)
df_dataset_tag1_codet5_large_cwe399 = process_data(df_cwe399_true, df_cwe399_false, df_codet54vdcwe_large_test_cwe399, df_codet54vdcwe_large_distance_cwe399)
df_dataset_tag1_polycoder_small_cwe399 = process_data(df_cwe399_true, df_cwe399_false, df_polycoder4vdcwe_small_test_cwe399, df_polycoder4vdcwe_small_distance_cwe399)
df_dataset_tag1_polycoder_base_cwe399 = process_data(df_cwe399_true, df_cwe399_false, df_polycoder4vdcwe_base_test_cwe399, df_polycoder4vdcwe_base_distance_cwe399)
df_dataset_tag1_polycoder_large_cwe399 = process_data(df_cwe399_true, df_cwe399_false, df_polycoder4vdcwe_large_test_cwe399, df_polycoder4vdcwe_large_distance_cwe399)


print(df_dataset_tag1_codebert_small_codexglue)
print(df_dataset_tag1_polycoder_small_codexglue)
print(df_dataset_tag1_polycoder_large_codexglue)
# Out:
#     Class    L2_norm  Nuclear_norm  L0_norm    L1_norm      Mean    Median  \
# 0       0  996.50370     8160.7460  4196352  8047.5580 -0.000229  0.000925
# 1       0  997.14734     8195.4920  4196352  8088.3057 -0.000233  0.001037
# 2       0  996.37555     8185.3880  4196352  8061.4883 -0.000232  0.001056
# 3       0  995.80700     8177.4640  4196352  8051.8896 -0.000231  0.001225
# 4       0  995.79333     8156.7500  4196352  8074.7790 -0.000231  0.001045
# ..    ...        ...           ...      ...        ...       ...       ...
# 195     0  996.78937     8178.0100  4196352  8094.4210 -0.000232  0.000992
# 196     0  996.41345     8163.5920  4196352  8055.6733 -0.000231  0.001086
# 3    0.396211  0.156983 -0.061507  ...  0.000244  23.093527      1.150879
# 4    0.396463  0.157183 -0.063234  ...  0.000244  23.109846      1.150778
# ..        ...       ...       ...  ...       ...        ...           ...
# 195  0.396568  0.157266 -0.060504  ...  0.000244  23.119799      1.151344
# 196  0.396873  0.157508 -0.057820  ...  0.000244  23.110363      1.150703
# 197  0.396973  0.157587 -0.060246  ...  0.000244  23.127285      1.151051
# 198  0.395421  0.156357 -0.062269  ...  0.000244  23.062426      1.150186
# 199  0.396982  0.157594 -0.060390  ...  0.000244  23.100735      1.150766
#
#        L2s_loss  L2s_loss_norm    Dot_loss  Dot_loss_norm  Index    Dataset  \
# 0    545.484985       1.335562 -130.094315      -0.332219      0  codexglue
# 1    545.085693       1.336762 -129.637421      -0.331619      1  codexglue
# 2    544.969421       1.336223 -129.793167      -0.331889      2  codexglue
# 3    544.400635       1.335834 -129.691727      -0.332083      3  codexglue
# 4    545.163452       1.335678 -129.943527      -0.332161      4  codexglue
# ..          ...            ...         ...            ...    ...        ...
# 195  545.563965       1.336885 -129.699249      -0.331557    195  codexglue
# 196  545.122681       1.335422 -130.031036      -0.332289    196  codexglue
# 197  545.952026       1.336226 -129.971817      -0.331887    197  codexglue
# 198  542.867981       1.334270 -129.847916      -0.332865    198  codexglue
# 199  544.690735       1.335609 -129.895721      -0.332196    199  codexglue
#
#                  PTM
# 0    polycoder-large
# 1    polycoder-large
# 2    polycoder-large
# 3    polycoder-large
# 4    polycoder-large
# ..               ...
# 195  polycoder-large
# 196  polycoder-large
# 197  polycoder-large
# 198  polycoder-large
# 199  polycoder-large
#
# [200 rows x 23 columns]

# %%
import pandas as pd


df_dataset_tag1_codexglue = pd.concat([df_dataset_tag1_codebert_small_codexglue, df_dataset_tag1_codebert_base_codexglue, df_dataset_tag1_codegen_small_codexglue, df_dataset_tag1_codegen_base_codexglue, df_dataset_tag1_codet5_small_codexglue, df_dataset_tag1_codet5_base_codexglue, df_dataset_tag1_codet5_large_codexglue, df_dataset_tag1_polycoder_small_codexglue, df_dataset_tag1_polycoder_base_codexglue, df_dataset_tag1_polycoder_large_codexglue], ignore_index=True)
df_dataset_tag1_reveal = pd.concat([df_dataset_tag1_codebert_small_reveal, df_dataset_tag1_codebert_base_reveal, df_dataset_tag1_codegen_small_reveal, df_dataset_tag1_codegen_base_reveal, df_dataset_tag1_codet5_small_reveal, df_dataset_tag1_codet5_base_reveal, df_dataset_tag1_codet5_large_reveal, df_dataset_tag1_polycoder_small_reveal, df_dataset_tag1_polycoder_base_reveal, df_dataset_tag1_polycoder_large_reveal], ignore_index=True)
df_dataset_tag1_cwe119 = pd.concat([df_dataset_tag1_codebert_small_cwe119, df_dataset_tag1_codebert_base_cwe119, df_dataset_tag1_codegen_small_cwe119, df_dataset_tag1_codegen_base_cwe119, df_dataset_tag1_codet5_small_cwe119, df_dataset_tag1_codet5_base_cwe119, df_dataset_tag1_codet5_large_cwe119, df_dataset_tag1_polycoder_small_cwe119, df_dataset_tag1_polycoder_base_cwe119, df_dataset_tag1_polycoder_large_cwe119], ignore_index=True)
df_dataset_tag1_cwe399 = pd.concat([df_dataset_tag1_codebert_small_cwe399, df_dataset_tag1_codebert_base_cwe399, df_dataset_tag1_codegen_small_cwe399, df_dataset_tag1_codegen_base_cwe399, df_dataset_tag1_codet5_small_cwe399, df_dataset_tag1_codet5_base_cwe399, df_dataset_tag1_codet5_large_cwe399, df_dataset_tag1_polycoder_small_cwe399, df_dataset_tag1_polycoder_base_cwe399, df_dataset_tag1_polycoder_large_cwe399], ignore_index=True)



print(df_dataset_tag1_codexglue)
print(df_dataset_tag1_reveal)
print(df_dataset_tag1_cwe119)
print(df_dataset_tag1_cwe399)
# Out:
#      Class     L2_norm  Nuclear_norm   L0_norm     L1_norm      Mean  \
# 0        0   996.50370      8160.746   4196352   8047.5580 -0.000229
# 1        0   997.14734      8195.492   4196352   8088.3057 -0.000233
# 2        0   996.37555      8185.388   4196352   8061.4883 -0.000232
# 3        0   995.80700      8177.464   4196352   8051.8896 -0.000231
# 4        0   995.79333      8156.750   4196352   8074.7790 -0.000231
# ...    ...         ...           ...       ...         ...       ...
# 1995     1  1483.63070     35786.180  13987840  13853.4670  0.009818
# 1996     1  1484.77420     35694.990  13987840  13793.7310  0.009844
# 1997     1  1485.14140     35834.645  13987840  13895.9520  0.009783
# 1998     1  1479.33950     35674.055  13987840  13937.7640  0.009803
# 1999     1  1485.17940     35736.360  13987840  13877.5290  0.009831
#
#         Median       Std       Var  Skewness  ...       MMD    L2_loss  \
# 0     0.000925  0.486455  0.236639  0.024380  ...  0.000245   9.910314
# 1     0.001037  0.486770  0.236945  0.025057  ...  0.000244   9.926476
# 2     0.001056  0.486393  0.236578  0.024270  ...  0.000243   9.911901
# 3     0.001225  0.486115  0.236308  0.025219  ...  0.000244   9.912246
# 4     0.001045  0.486109  0.236302  0.024222  ...  0.000245   9.901173
# ...        ...       ...       ...       ...  ...       ...        ...
# 1995  0.009210  0.396568  0.157266 -0.060504  ...  0.000244  23.119799
# 1996  0.008998  0.396873  0.157508 -0.057820  ...  0.000244  23.110363
# 1997  0.008956  0.396973  0.157587 -0.060246  ...  0.000244  23.127285
# 1998  0.009266  0.395421  0.156357 -0.062269  ...  0.000244  23.062426
# 1999  0.009057  0.396982  0.157594 -0.060390  ...  0.000244  23.100735
#
#       L2_loss_norm    L2s_loss  L2s_loss_norm    Dot_loss  Dot_loss_norm  \
# 0         0.732023  100.055779       0.543153 -131.547943      -0.728423
# 1         0.732930  100.397621       0.544523 -131.511307      -0.727738
# 2         0.732159  100.109352       0.543429 -131.498154      -0.728285
# 3         0.732284  100.118958       0.543618 -131.445709      -0.728191
# 4         0.731569   99.863754       0.542503 -131.549088      -0.728749
# ...            ...         ...            ...         ...            ...
# 1995      1.151344  545.563965       1.336885 -129.699249      -0.331557
# 1996      1.150703  545.122681       1.335422 -130.031036      -0.332289
# 1997      1.151051  545.952026       1.336226 -129.971817      -0.331887
# 1998      1.150186  542.867981       1.334270 -129.847916      -0.332865
# 1999      1.150766  544.690735       1.335609 -129.895721      -0.332196
#
#       Index    Dataset              PTM
# 0         0  codexglue   codebert-small
# 1         1  codexglue   codebert-small
# 2         2  codexglue   codebert-small
# 3         3  codexglue   codebert-small
# 4         4  codexglue   codebert-small
# ...     ...        ...              ...
# 1995    195  codexglue  polycoder-large
# 1996    196  codexglue  polycoder-large
# 1997    197  codexglue  polycoder-large
# 1998    198  codexglue  polycoder-large
# 1999    199  codexglue  polycoder-large
#
# [2000 rows x 23 columns]
#      Class     L2_norm  Nuclear_norm   L0_norm     L1_norm      Mean  \
# 0        0   996.71387     7586.7850   3492096   7203.7256 -0.000239
# 1        0   997.03394     7570.1120   3492096   7231.2470 -0.000239
# 2        0   997.28400     7586.7130   3492096   7224.7610 -0.000238
# 3        0   997.10364     7595.4710   3492096   7231.5220 -0.000240
# 4        0   995.94260     7569.3735   3492096   7225.4014 -0.000242
# ...    ...         ...           ...       ...         ...       ...
# 1995     1  1311.16380    28684.1860  11640320  15062.7730  0.009826
# 1996     1  1306.96510    28594.4650  11640320  15197.6410  0.009831
# 1997     1  1311.16830    28616.4750  11640320  14990.7210  0.009868
# 1998     1  1312.49740    28611.8750  11640320  15091.6930  0.009838
# 1999     1  1307.25850    28560.3500  11640320  15069.1130  0.009856
#
#         Median       Std       Var  Skewness  ...       MMD    L2_loss  \
# 0     0.002010  0.533368  0.284482 -0.007326  ...  0.000296  10.260440
# 1     0.002045  0.533540  0.284665 -0.006274  ...  0.000294  10.254161
# 2     0.001850  0.533674  0.284807 -0.006339  ...  0.000291  10.257152
# 3     0.001862  0.533577  0.284704 -0.007510  ...  0.000296  10.262415
# 4     0.001773  0.532956  0.284042 -0.005546  ...  0.000297  10.257477
# ...        ...       ...       ...       ...  ...       ...        ...
# 1995  0.009086  0.384178  0.147593 -0.158483  ...  0.000294  21.349558
# 1996  0.009143  0.382947  0.146648 -0.161624  ...  0.000299  21.317097
# 1997  0.009331  0.384178  0.147593 -0.155286  ...  0.000291  21.330091
# 1998  0.009208  0.384569  0.147893 -0.158934  ...  0.000292  21.341356
# 1999  0.009170  0.383032  0.146714 -0.159306  ...  0.000297  21.299284
#
#       L2_loss_norm    L2s_loss  L2s_loss_norm    Dot_loss  Dot_loss_norm  \
# 0         0.690555  107.515274       0.484983 -164.718994      -0.757509
# 1         0.690361  107.371231       0.484676 -164.703232      -0.757662
# 2         0.690509  107.435402       0.484893 -164.697723      -0.757553
# 3         0.690720  107.525238       0.485154 -164.745468      -0.757423
# 4         0.690500  107.462662       0.484940 -164.699890      -0.757530
# ...            ...         ...            ...         ...            ...
# 1995      1.094883  467.425659       1.210858 -143.721970      -0.394571
# 1996      1.094422  465.862488       1.209806 -143.699585      -0.395097
# 1997      1.094762  466.577209       1.210654 -143.540558      -0.394673
# 1998      1.094843  466.991180       1.210800 -143.731400      -0.394600
# 1999      1.094278  465.083344       1.209504 -143.572922      -0.395248
#
#       Index  Dataset              PTM
# 0         0   reveal   codebert-small
# 1         1   reveal   codebert-small
# 2         2   reveal   codebert-small
# 3         3   reveal   codebert-small
# 4         4   reveal   codebert-small
# 1999  polycoder-large
#
# [2000 rows x 23 columns]
#      Class     L2_norm  Nuclear_norm   L0_norm    L1_norm      Mean    Median  \
# 0        0   881.81903     5177.2190   3361536  6970.1597 -0.000191 -0.000960
# 1        0   881.20930     5154.6553   3361536  6994.1865 -0.000190 -0.000822
# 2        0   880.77637     5128.6533   3361536  6986.7150 -0.000190 -0.000790
# 3        1   882.15360     5173.9220   3361536  7001.1963 -0.000190 -0.000865
# 4        0   879.29250     5075.6970   3361536  6993.1206 -0.000188 -0.000960
# ...    ...         ...           ...       ...        ...       ...       ...
# 1995     1  1166.46570    13771.0970  11205120  9701.5400  0.010300  0.010167
# 1996     1  1166.77810    13695.7600  11205120  9706.9050  0.010320  0.010179
# 1997     1  1166.34440    13659.8170  11205120  9697.7370  0.010362  0.010203
# 1998     1  1166.70520    13525.3910  11205120  9725.1230  0.010323  0.010152
# 1999     1  1161.03150    13632.6330  11205120  9817.4090  0.010358  0.010302
#
#            Std       Var  Skewness  ...       MMD    L2_loss  L2_loss_norm  \
# 0     0.480962  0.231324  0.042804  ...  0.000338   9.026101      0.673117
# 1     0.480629  0.231004  0.042309  ...  0.000260   9.012892      0.672367
# 2     0.480393  0.230778  0.042672  ...  0.000292   9.029318      0.673618
# 3     0.481144  0.231500  0.042506  ...  0.000293   9.019392      0.672577
# 4     0.479584  0.230001  0.042475  ...  0.000374   8.979428      0.670126
# ...        ...       ...       ...  ...       ...        ...           ...
# 1995  0.348316  0.121324 -0.081488  ...  0.000255  17.989599      1.007375
# 1996  0.348409  0.121389 -0.082080  ...  0.000390  17.972990      1.006453
# 1997  0.348278  0.121298 -0.081422  ...  0.000306  17.945957      1.004924
# 1998  0.348387  0.121374 -0.082524  ...  0.000286  17.952293      1.004751
# 1999  0.346691  0.120194 -0.084440  ...  0.000337  17.962502      1.007236
#
#         L2s_loss  L2s_loss_norm    Dot_loss  Dot_loss_norm  Index  Dataset  \
# 0      87.624443       0.483476 -133.730118      -0.758262      0   cwe399
# 1      87.347946       0.482343 -133.759308      -0.758829      1   cwe399
# 2      87.632027       0.484110 -133.638443      -0.757945      2   cwe399
# 3      87.455612       0.482568 -133.822983      -0.758716      3   cwe399
# 4      86.726776       0.479382 -133.950500      -0.760309      4   cwe399
# ...          ...            ...         ...            ...    ...      ...
# 1995  351.118958       1.062996 -134.883316      -0.468502    195   cwe399
# 1996  350.416595       1.061247 -135.186966      -0.469376    196   cwe399
# 1997  349.567139       1.058183 -135.554260      -0.470908    197   cwe399
# 1998  349.857910       1.057933 -135.700577      -0.471033    198   cwe399
# 1999  350.039642       1.062837 -134.629608      -0.468582    199   cwe399
#
#                   PTM
# 0      codebert-small
# 1      codebert-small
# 2      codebert-small
# 3      codebert-small
# 4      codebert-small
# ...               ...
# 1995  polycoder-large
# 1996  polycoder-large
# 1997  polycoder-large
# 1998  polycoder-large
# 1999  polycoder-large
#
# [2000 rows x 23 columns]

# %% [markdown]
# **RF

# %%
# RF target is cwe399
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, matthews_corrcoef
import shap

df_dataset_tag1  = pd.concat([df_dataset_tag1_codexglue, df_dataset_tag1_reveal, df_dataset_tag1_cwe119], ignore_index=True)
print(df_dataset_tag1)

print(df_dataset_tag1_cwe399)

train = df_dataset_tag1.iloc[:,0:-3].drop(columns=['Entropy','L2_loss','L2_loss_norm','L2s_loss','L2s_loss_norm','Dot_loss_norm'])
print(train.head())
test = df_dataset_tag1_cwe399.iloc[:,0:-3].drop(columns=['Entropy','L2_loss','L2_loss_norm','L2s_loss','L2s_loss_norm','Dot_loss_norm'])
print(test.head())


train_data = train.iloc[:,1:]
train_label = train["Class"]
test_data = test.iloc[:,1:]
test_label = test["Class"]
print(train_data.head())
print(train_label.head())
print(test_data.head())
print(test_label.head())

train_label = train_label.astype(int)
test_label = test_label.astype(int)

print(train_data.head())
print(train_label.head())
print(test_data.head())
print(test_label.head())


model = RandomForestClassifier(random_state=0)
model.fit(train_data, train_label)
y_predict = model.predict(test_data)

print("y_predict:\n", y_predict)

accuracy = accuracy_score(test_label, y_predict)
precision = precision_score(test_label, y_predict)
recall = recall_score(test_label, y_predict)
f1 = f1_score(test_label, y_predict)
auc = roc_auc_score(test_label, y_predict)
mcc = matthews_corrcoef(test_label, y_predict)

# %%
explainer = shap.KernelExplainer(model.predict,test_data)


shap_values = explainer.shap_values(test_data)
# Out:
# Using 2000 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
shap.summary_plot(shap_values, test_data)

# %%
shap.summary_plot(shap_values, test_data, plot_type="bar") 

# permutation

# %%
# RF target is cwe119

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, matthews_corrcoef

df_dataset_tag1  = pd.concat([df_dataset_tag1_codexglue, df_dataset_tag1_reveal, df_dataset_tag1_cwe399], ignore_index=True)
print(df_dataset_tag1)

print(df_dataset_tag1_cwe119)

train = df_dataset_tag1.iloc[:,0:-3].drop(columns=['Entropy','L2_loss','L2_loss_norm','L2s_loss','L2s_loss_norm','Dot_loss_norm'])
print(train.head())
test = df_dataset_tag1_cwe119.iloc[:,0:-3].drop(columns=['Entropy','L2_loss','L2_loss_norm','L2s_loss','L2s_loss_norm','Dot_loss_norm'])
print(test.head())


train_data = train.iloc[:,1:]
train_label = train["Class"]
test_data = test.iloc[:,1:]
test_label = test["Class"]
print(train_data.head())
print(train_label.head())
print(test_data.head())
print(test_label.head())


train_label = train_label.astype(int)

test_label = test_label.astype(int)
print(train_data.head())
print(train_label.head())
print(test_data.head())
print(test_label.head())



model = RandomForestClassifier(random_state=0)
model.fit(train_data, train_label)
y_predict = model.predict(test_data)
print("y_predict:\n", y_predict)


accuracy = accuracy_score(test_label, y_predict)
precision = precision_score(test_label, y_predict)
recall = recall_score(test_label, y_predict)
f1 = f1_score(test_label, y_predict)
auc = roc_auc_score(test_label, y_predict)
mcc = matthews_corrcoef(test_label, y_predict)

# %%
explainer = shap.KernelExplainer(model.predict,test_data)


shap_values = explainer.shap_values(test_data)
# Out:
# Using 2000 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
shap.summary_plot(shap_values, test_data)

# %%
shap.summary_plot(shap_values, test_data, plot_type="bar") 

# permutation

# %%
# RF target is reveal

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, matthews_corrcoef

df_dataset_tag1  = pd.concat([df_dataset_tag1_codexglue, df_dataset_tag1_cwe119, df_dataset_tag1_cwe399], ignore_index=True)
print(df_dataset_tag1)

print(df_dataset_tag1_reveal)

train = df_dataset_tag1.iloc[:,0:-3].drop(columns=['Entropy','L2_loss','L2_loss_norm','L2s_loss','L2s_loss_norm','Dot_loss_norm'])
print(train.head())
test = df_dataset_tag1_reveal.iloc[:,0:-3].drop(columns=['Entropy','L2_loss','L2_loss_norm','L2s_loss','L2s_loss_norm','Dot_loss_norm'])
print(test.head())


train_data = train.iloc[:,1:]
train_label = train["Class"]
test_data = test.iloc[:,1:]
test_label = test["Class"]
print(train_data.head())
print(train_label.head())
print(test_data.head())
print(test_label.head())


train_label = train_label.astype(int)

test_label = test_label.astype(int)
print(train_data.head())
print(train_label.head())
print(test_data.head())
print(test_label.head())




model = RandomForestClassifier(random_state=0)
model.fit(train_data, train_label)
y_predict = model.predict(test_data)
print("y_predict:\n", y_predict)


accuracy = accuracy_score(test_label, y_predict)
precision = precision_score(test_label, y_predict)
recall = recall_score(test_label, y_predict)
f1 = f1_score(test_label, y_predict)
auc = roc_auc_score(test_label, y_predict)
mcc = matthews_corrcoef(test_label, y_predict)

# %%
explainer = shap.KernelExplainer(model.predict,test_data)

shap_values = explainer.shap_values(test_data)
# Out:
# Using 2000 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
shap.summary_plot(shap_values, test_data)

# %%
shap.summary_plot(shap_values, test_data, plot_type="bar") 

# permutation

# %%
# RF target is devign

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, matthews_corrcoef

df_dataset_tag1  = pd.concat([df_dataset_tag1_reveal, df_dataset_tag1_cwe119, df_dataset_tag1_cwe399], ignore_index=True)
print(df_dataset_tag1)

print(df_dataset_tag1_codexglue)

train = df_dataset_tag1.iloc[:,0:-3].drop(columns=['Entropy','L2_loss','L2_loss_norm','L2s_loss','L2s_loss_norm','Dot_loss_norm'])
print(train.head())
test = df_dataset_tag1_codexglue.iloc[:,0:-3].drop(columns=['Entropy','L2_loss','L2_loss_norm','L2s_loss','L2s_loss_norm','Dot_loss_norm'])
print(test.head())


train_data = train.iloc[:,1:]
train_label = train["Class"]
test_data = test.iloc[:,1:]
test_label = test["Class"]
print(train_data.head())
print(train_label.head())
print(test_data.head())
print(test_label.head())


train_label = train_label.astype(int)

test_label = test_label.astype(int)
print(train_data.head())
print(train_label.head())
print(test_data.head())
print(test_label.head())





model = RandomForestClassifier(random_state=0)
model.fit(train_data, train_label)
y_predict = model.predict(test_data)
print("y_predict:\n", y_predict)


accuracy = accuracy_score(test_label, y_predict)
precision = precision_score(test_label, y_predict)
recall = recall_score(test_label, y_predict)
f1 = f1_score(test_label, y_predict)
auc = roc_auc_score(test_label, y_predict)
mcc = matthews_corrcoef(test_label, y_predict)

# %%
explainer = shap.KernelExplainer(model.predict,test_data)


shap_values = explainer.shap_values(test_data)
# Out:
# Using 2000 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
shap.summary_plot(shap_values, test_data)

# %%
shap.summary_plot(shap_values, test_data, plot_type="bar") 

# permutation
