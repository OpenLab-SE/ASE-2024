# %%
import numpy as np
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from scipy.stats import kendalltau
import statistics 
import pandas as pd
import math
import os
import random
import torch
import torch.nn as nn
import sys
from statistics import mean, median 
from sklearn import svm
import torch.nn.functional as F
import torch
from geomloss import SamplesLoss
from scipy.spatial import distance
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
from scipy.stats import entropy

# %%
codebert4vdcwe_small = 'codebert4vdcwe-small/'
codebert4vdcwe_base = 'codebert4vdcwe-base/'
codegen4vdcwe_small = 'codegen4vdcwe-small/'
codegen4vdcwe_base = 'codegen4vdcwe-base/'
codet54vdcwe_small = 'codet54vdcwe-small/'
codet54vdcwe_base = 'codet54vdcwe-base/'
codet54vdcwe_large = 'codet54vdcwe-large/'
polycoder4vdcwe_small = 'polycoder4vdcwe-small/'
polycoder4vdcwe_base = 'polycoder4vdcwe-base/'
polycoder4vdcwe_large = 'polycoder4vdcwe-large/'



trained_codexglue_path = 'CLS/trained_codexglue/CLS/'
trained_reveal_path = 'CLS/trained_reveal/CLS/'
trained_cwe119_path = 'CLS/trained_cwe119/CLS/'
trained_cwe399_path = 'CLS/trained_cwe399/CLS/'

# %%
# 
codebert4vdcwe_small_codexglue_train = {}
codebert4vdcwe_small_codexglue_test = {}
codebert4vdcwe_base_codexglue_train = {}
codebert4vdcwe_base_codexglue_test = {}
codegen4vdcwe_small_codexglue_train = {}
codegen4vdcwe_small_codexglue_test = {}
codegen4vdcwe_base_codexglue_train = {}
codegen4vdcwe_base_codexglue_test = {}
codet54vdcwe_small_codexglue_train = {}
codet54vdcwe_small_codexglue_test = {}
codet54vdcwe_base_codexglue_train = {}
codet54vdcwe_base_codexglue_test = {}
codet54vdcwe_large_codexglue_train = {}
codet54vdcwe_large_codexglue_test = {}
polycoder4vdcwe_small_codexglue_train = {}
polycoder4vdcwe_small_codexglue_test = {}
polycoder4vdcwe_base_codexglue_train = {}
polycoder4vdcwe_base_codexglue_test = {}
polycoder4vdcwe_large_codexglue_train = {}
polycoder4vdcwe_large_codexglue_test = {}

codebert4vdcwe_small_codexglue_train_features = {}
codebert4vdcwe_small_codexglue_test_features = {}
codebert4vdcwe_base_codexglue_train_features = {}
codebert4vdcwe_base_codexglue_test_features = {}
codegen4vdcwe_small_codexglue_train_features = {}
codegen4vdcwe_small_codexglue_test_features = {}
codegen4vdcwe_base_codexglue_train_features = {}
codegen4vdcwe_base_codexglue_test_features = {}
codet54vdcwe_small_codexglue_train_features = {}
codet54vdcwe_small_codexglue_test_features = {}
codet54vdcwe_base_codexglue_train_features = {}
codet54vdcwe_base_codexglue_test_features = {}
codet54vdcwe_large_codexglue_train_features = {}
codet54vdcwe_large_codexglue_test_features = {}
polycoder4vdcwe_small_codexglue_train_features = {}
polycoder4vdcwe_small_codexglue_test_features = {}
polycoder4vdcwe_base_codexglue_train_features = {}
polycoder4vdcwe_base_codexglue_test_features = {}
polycoder4vdcwe_large_codexglue_train_features = {}
polycoder4vdcwe_large_codexglue_test_features = {}


for i in range(200):  
    codebert4vdcwe_small_codexglue_train[i] = np.load(codebert4vdcwe_small+trained_codexglue_path+'codexglue_train{}'.format(i)+'-data.npy')
    codebert4vdcwe_small_codexglue_test[i] = np.load(codebert4vdcwe_small+trained_codexglue_path+'codexglue_test{}'.format(i)+'-data.npy')
    #print(np.shape(codebert4vdcwe_small_codexglue_train[i]))  
    #print(np.shape(codebert4vdcwe_small_codexglue_test[i]))
    
    codebert4vdcwe_small_codexglue_train_features[i] = [np.linalg.norm(codebert4vdcwe_small_codexglue_train[i], ord='fro'), 
                                                       np.linalg.norm(codebert4vdcwe_small_codexglue_train[i], ord='nuc'),
                                                       np.count_nonzero(codebert4vdcwe_small_codexglue_train[i]), 
                                                       np.linalg.norm(codebert4vdcwe_small_codexglue_train[i], ord=1), 
                                                       np.mean(codebert4vdcwe_small_codexglue_train[i]),
                                                       np.median(codebert4vdcwe_small_codexglue_train[i]),
                                                       np.std(codebert4vdcwe_small_codexglue_train[i]), 
                                                       np.var(codebert4vdcwe_small_codexglue_train[i]), 
                                                       matrix_skewness(codebert4vdcwe_small_codexglue_train[i]),
                                                       matrix_kurtosis(codebert4vdcwe_small_codexglue_train[i]), 
                                                       matrix_entropy(codebert4vdcwe_small_codexglue_train[i]), 
                                                       matrix_range(codebert4vdcwe_small_codexglue_train[i])
                                                       ]
    
    codebert4vdcwe_small_codexglue_test_features[i] = [np.linalg.norm(codebert4vdcwe_small_codexglue_test[i], ord='fro'), 
                                                       np.linalg.norm(codebert4vdcwe_small_codexglue_test[i], ord='nuc'),
                                                       np.count_nonzero(codebert4vdcwe_small_codexglue_test[i]), 
                                                       np.linalg.norm(codebert4vdcwe_small_codexglue_test[i], ord=1), 
                                                       np.mean(codebert4vdcwe_small_codexglue_test[i]),
                                                       np.median(codebert4vdcwe_small_codexglue_test[i]),
                                                       np.std(codebert4vdcwe_small_codexglue_test[i]), 
                                                       np.var(codebert4vdcwe_small_codexglue_test[i]), 
                                                       matrix_skewness(codebert4vdcwe_small_codexglue_test[i]),
                                                       matrix_kurtosis(codebert4vdcwe_small_codexglue_test[i]), 
                                                       matrix_entropy(codebert4vdcwe_small_codexglue_test[i]), 
                                                       matrix_range(codebert4vdcwe_small_codexglue_test[i])
                                                       ]    

    codebert4vdcwe_base_codexglue_train[i] = np.load(codebert4vdcwe_base+trained_codexglue_path+'codexglue_train{}'.format(i)+'-data.npy')
    codebert4vdcwe_base_codexglue_test[i] = np.load(codebert4vdcwe_base+trained_codexglue_path+'codexglue_test{}'.format(i)+'-data.npy')
    codebert4vdcwe_base_codexglue_train_features[i] = [np.linalg.norm(codebert4vdcwe_base_codexglue_train[i], ord='fro'), 
                                                       np.linalg.norm(codebert4vdcwe_base_codexglue_train[i], ord='nuc'),
                                                       np.count_nonzero(codebert4vdcwe_base_codexglue_train[i]), 
                                                       np.linalg.norm(codebert4vdcwe_base_codexglue_train[i], ord=1), 
                                                       np.mean(codebert4vdcwe_base_codexglue_train[i]),
                                                       np.median(codebert4vdcwe_base_codexglue_train[i]),
                                                       np.std(codebert4vdcwe_base_codexglue_train[i]), 
                                                       np.var(codebert4vdcwe_base_codexglue_train[i]), 
                                                       matrix_skewness(codebert4vdcwe_base_codexglue_train[i]),
                                                       matrix_kurtosis(codebert4vdcwe_base_codexglue_train[i]), 
                                                       matrix_entropy(codebert4vdcwe_base_codexglue_train[i]), 
                                                       matrix_range(codebert4vdcwe_base_codexglue_train[i])
                                                       ]
    
    codebert4vdcwe_base_codexglue_test_features[i] = [np.linalg.norm(codebert4vdcwe_base_codexglue_test[i], ord='fro'), 
                                                       np.linalg.norm(codebert4vdcwe_base_codexglue_test[i], ord='nuc'),
                                                       np.count_nonzero(codebert4vdcwe_base_codexglue_test[i]), 
                                                       np.linalg.norm(codebert4vdcwe_base_codexglue_test[i], ord=1), 
                                                       np.mean(codebert4vdcwe_base_codexglue_test[i]),
                                                       np.median(codebert4vdcwe_base_codexglue_test[i]),
                                                       np.std(codebert4vdcwe_base_codexglue_test[i]), 
                                                       np.var(codebert4vdcwe_base_codexglue_test[i]), 
                                                       matrix_skewness(codebert4vdcwe_base_codexglue_test[i]),
                                                       matrix_kurtosis(codebert4vdcwe_base_codexglue_test[i]), 
                                                       matrix_entropy(codebert4vdcwe_base_codexglue_test[i]), 
                                                       matrix_range(codebert4vdcwe_base_codexglue_test[i])
                                                       ]   
    
    codegen4vdcwe_small_codexglue_train[i] = np.load(codegen4vdcwe_small+trained_codexglue_path+'codexglue_train{}'.format(i)+'-data.npy')
    codegen4vdcwe_small_codexglue_test[i] = np.load(codegen4vdcwe_small+trained_codexglue_path+'codexglue_test{}'.format(i)+'-data.npy')
    codegen4vdcwe_small_codexglue_train_features[i] = [np.linalg.norm(codegen4vdcwe_small_codexglue_train[i], ord='fro'), 
                                                       np.linalg.norm(codegen4vdcwe_small_codexglue_train[i], ord='nuc'),
                                                       np.count_nonzero(codegen4vdcwe_small_codexglue_train[i]), 
                                                       np.linalg.norm(codegen4vdcwe_small_codexglue_train[i], ord=1), 
                                                       np.mean(codegen4vdcwe_small_codexglue_train[i]),
                                                       np.median(codegen4vdcwe_small_codexglue_train[i]),
                                                       np.std(codegen4vdcwe_small_codexglue_train[i]), 
                                                       np.var(codegen4vdcwe_small_codexglue_train[i]), 
                                                       matrix_skewness(codegen4vdcwe_small_codexglue_train[i]),
                                                       matrix_kurtosis(codegen4vdcwe_small_codexglue_train[i]), 
                                                       matrix_entropy(codegen4vdcwe_small_codexglue_train[i]), 
                                                       matrix_range(codegen4vdcwe_small_codexglue_train[i])
                                                       ]
    
    codegen4vdcwe_small_codexglue_test_features[i] = [np.linalg.norm(codegen4vdcwe_small_codexglue_test[i], ord='fro'), 
                                                       np.linalg.norm(codegen4vdcwe_small_codexglue_test[i], ord='nuc'),
                                                       np.count_nonzero(codegen4vdcwe_small_codexglue_test[i]), 
                                                       np.linalg.norm(codegen4vdcwe_small_codexglue_test[i], ord=1), 
                                                       np.mean(codegen4vdcwe_small_codexglue_test[i]),
                                                       np.median(codegen4vdcwe_small_codexglue_test[i]),
                                                       np.std(codegen4vdcwe_small_codexglue_test[i]), 
                                                       np.var(codegen4vdcwe_small_codexglue_test[i]), 
                                                       matrix_skewness(codegen4vdcwe_small_codexglue_test[i]),
                                                       matrix_kurtosis(codegen4vdcwe_small_codexglue_test[i]), 
                                                       matrix_entropy(codegen4vdcwe_small_codexglue_test[i]), 
                                                       matrix_range(codegen4vdcwe_small_codexglue_test[i])
                                                       ]         
    
    
    codegen4vdcwe_base_codexglue_train[i] = np.load(codegen4vdcwe_base+trained_codexglue_path+'codexglue_train{}'.format(i)+'-data.npy')
    codegen4vdcwe_base_codexglue_test[i] = np.load(codegen4vdcwe_base+trained_codexglue_path+'codexglue_test{}'.format(i)+'-data.npy')
    codegen4vdcwe_base_codexglue_train_features[i] = [np.linalg.norm(codegen4vdcwe_base_codexglue_train[i], ord='fro'), 
                                                       np.linalg.norm(codegen4vdcwe_base_codexglue_train[i], ord='nuc'),
                                                       np.count_nonzero(codegen4vdcwe_base_codexglue_train[i]), 
                                                       np.linalg.norm(codegen4vdcwe_base_codexglue_train[i], ord=1), 
                                                       np.mean(codegen4vdcwe_base_codexglue_train[i]),
                                                       np.median(codegen4vdcwe_base_codexglue_train[i]),
                                                       np.std(codegen4vdcwe_base_codexglue_train[i]), 
                                                       np.var(codegen4vdcwe_base_codexglue_train[i]), 
                                                       matrix_skewness(codegen4vdcwe_base_codexglue_train[i]),
                                                       matrix_kurtosis(codegen4vdcwe_base_codexglue_train[i]), 
                                                       matrix_entropy(codegen4vdcwe_base_codexglue_train[i]), 
                                                       matrix_range(codegen4vdcwe_base_codexglue_train[i])
                                                       ]
    
    codegen4vdcwe_base_codexglue_test_features[i] = [np.linalg.norm(codegen4vdcwe_base_codexglue_test[i], ord='fro'), 
                                                       np.linalg.norm(codegen4vdcwe_base_codexglue_test[i], ord='nuc'),
                                                       np.count_nonzero(codegen4vdcwe_base_codexglue_test[i]), 
                                                       np.linalg.norm(codegen4vdcwe_base_codexglue_test[i], ord=1), 
                                                       np.mean(codegen4vdcwe_base_codexglue_test[i]),
                                                       np.median(codegen4vdcwe_base_codexglue_test[i]),
                                                       np.std(codegen4vdcwe_base_codexglue_test[i]), 
                                                       np.var(codegen4vdcwe_base_codexglue_test[i]), 
                                                       matrix_skewness(codegen4vdcwe_base_codexglue_test[i]),
                                                       matrix_kurtosis(codegen4vdcwe_base_codexglue_test[i]), 
                                                       matrix_entropy(codegen4vdcwe_base_codexglue_test[i]), 
                                                       matrix_range(codegen4vdcwe_base_codexglue_test[i])
                                                       ] 
    
    codet54vdcwe_small_codexglue_train[i] = np.load(codet54vdcwe_small+trained_codexglue_path+'codexglue_train{}'.format(i)+'-data.npy')
    codet54vdcwe_small_codexglue_test[i] = np.load(codet54vdcwe_small+trained_codexglue_path+'codexglue_test{}'.format(i)+'-data.npy')
    codet54vdcwe_small_codexglue_train_features[i] = [np.linalg.norm(codet54vdcwe_small_codexglue_train[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_small_codexglue_train[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_small_codexglue_train[i]), 
                                                       np.linalg.norm(codet54vdcwe_small_codexglue_train[i], ord=1), 
                                                       np.mean(codet54vdcwe_small_codexglue_train[i]),
                                                       np.median(codet54vdcwe_small_codexglue_train[i]),
                                                       np.std(codet54vdcwe_small_codexglue_train[i]), 
                                                       np.var(codet54vdcwe_small_codexglue_train[i]), 
                                                       matrix_skewness(codet54vdcwe_small_codexglue_train[i]),
                                                       matrix_kurtosis(codet54vdcwe_small_codexglue_train[i]), 
                                                       matrix_entropy(codet54vdcwe_small_codexglue_train[i]), 
                                                       matrix_range(codet54vdcwe_small_codexglue_train[i])
                                                       ]
    
    
    
    codet54vdcwe_small_codexglue_test_features[i] = [np.linalg.norm(codet54vdcwe_small_codexglue_test[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_small_codexglue_test[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_small_codexglue_test[i]), 
                                                       np.linalg.norm(codet54vdcwe_small_codexglue_test[i], ord=1), 
                                                       np.mean(codet54vdcwe_small_codexglue_test[i]),
                                                       np.median(codet54vdcwe_small_codexglue_test[i]),
                                                       np.std(codet54vdcwe_small_codexglue_test[i]), 
                                                       np.var(codet54vdcwe_small_codexglue_test[i]), 
                                                       matrix_skewness(codet54vdcwe_small_codexglue_test[i]),
                                                       matrix_kurtosis(codet54vdcwe_small_codexglue_test[i]), 
                                                       matrix_entropy(codet54vdcwe_small_codexglue_test[i]), 
                                                       matrix_range(codet54vdcwe_small_codexglue_test[i])
                                                       ]         
    
    
    
    codet54vdcwe_base_codexglue_train[i] = np.load(codet54vdcwe_base+trained_codexglue_path+'codexglue_train{}'.format(i)+'-data.npy')
    codet54vdcwe_base_codexglue_test[i] = np.load(codet54vdcwe_base+trained_codexglue_path+'codexglue_test{}'.format(i)+'-data.npy')
    codet54vdcwe_base_codexglue_train_features[i] = [np.linalg.norm(codet54vdcwe_base_codexglue_train[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_base_codexglue_train[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_base_codexglue_train[i]), 
                                                       np.linalg.norm(codet54vdcwe_base_codexglue_train[i], ord=1), 
                                                       np.mean(codet54vdcwe_base_codexglue_train[i]),
                                                       np.median(codet54vdcwe_base_codexglue_train[i]),
                                                       np.std(codet54vdcwe_base_codexglue_train[i]), 
                                                       np.var(codet54vdcwe_base_codexglue_train[i]), 
                                                       matrix_skewness(codet54vdcwe_base_codexglue_train[i]),
                                                       matrix_kurtosis(codet54vdcwe_base_codexglue_train[i]), 
                                                       matrix_entropy(codet54vdcwe_base_codexglue_train[i]), 
                                                       matrix_range(codet54vdcwe_base_codexglue_train[i])
                                                       ]
    
    codet54vdcwe_base_codexglue_test_features[i] = [np.linalg.norm(codet54vdcwe_base_codexglue_test[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_base_codexglue_test[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_base_codexglue_test[i]), 
                                                       np.linalg.norm(codet54vdcwe_base_codexglue_test[i], ord=1), 
                                                       np.mean(codet54vdcwe_base_codexglue_test[i]),
                                                       np.median(codet54vdcwe_base_codexglue_test[i]),
                                                       np.std(codet54vdcwe_base_codexglue_test[i]), 
                                                       np.var(codet54vdcwe_base_codexglue_test[i]), 
                                                       matrix_skewness(codet54vdcwe_base_codexglue_test[i]),
                                                       matrix_kurtosis(codet54vdcwe_base_codexglue_test[i]), 
                                                       matrix_entropy(codet54vdcwe_base_codexglue_test[i]), 
                                                       matrix_range(codet54vdcwe_base_codexglue_test[i])
                                                       ]     
    
    codet54vdcwe_large_codexglue_train[i] = np.load(codet54vdcwe_large+trained_codexglue_path+'codexglue_train{}'.format(i)+'-data.npy')
    codet54vdcwe_large_codexglue_test[i] = np.load(codet54vdcwe_large+trained_codexglue_path+'codexglue_test{}'.format(i)+'-data.npy')
    codet54vdcwe_large_codexglue_train_features[i] = [np.linalg.norm(codet54vdcwe_large_codexglue_train[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_large_codexglue_train[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_large_codexglue_train[i]), 
                                                       np.linalg.norm(codet54vdcwe_large_codexglue_train[i], ord=1), 
                                                       np.mean(codet54vdcwe_large_codexglue_train[i]),
                                                       np.median(codet54vdcwe_large_codexglue_train[i]),
                                                       np.std(codet54vdcwe_large_codexglue_train[i]), 
                                                       np.var(codet54vdcwe_large_codexglue_train[i]), 
                                                       matrix_skewness(codet54vdcwe_large_codexglue_train[i]),
                                                       matrix_kurtosis(codet54vdcwe_large_codexglue_train[i]), 
                                                       matrix_entropy(codet54vdcwe_large_codexglue_train[i]), 
                                                       matrix_range(codet54vdcwe_large_codexglue_train[i])
                                                       ]
    
    codet54vdcwe_large_codexglue_test_features[i] = [np.linalg.norm(codet54vdcwe_large_codexglue_test[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_large_codexglue_test[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_large_codexglue_test[i]), 
                                                       np.linalg.norm(codet54vdcwe_large_codexglue_test[i], ord=1), 
                                                       np.mean(codet54vdcwe_large_codexglue_test[i]),
                                                       np.median(codet54vdcwe_large_codexglue_test[i]),
                                                       np.std(codet54vdcwe_large_codexglue_test[i]), 
                                                       np.var(codet54vdcwe_large_codexglue_test[i]), 
                                                       matrix_skewness(codet54vdcwe_large_codexglue_test[i]),
                                                       matrix_kurtosis(codet54vdcwe_large_codexglue_test[i]), 
                                                       matrix_entropy(codet54vdcwe_large_codexglue_test[i]), 
                                                       matrix_range(codet54vdcwe_large_codexglue_test[i])
                                                       ]     

    polycoder4vdcwe_small_codexglue_train[i] = np.load(polycoder4vdcwe_small+trained_codexglue_path+'codexglue_train{}'.format(i)+'-data.npy')
    polycoder4vdcwe_small_codexglue_test[i] = np.load(polycoder4vdcwe_small+trained_codexglue_path+'codexglue_test{}'.format(i)+'-data.npy')
    polycoder4vdcwe_small_codexglue_train_features[i] = [np.linalg.norm(polycoder4vdcwe_small_codexglue_train[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_small_codexglue_train[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_small_codexglue_train[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_small_codexglue_train[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_small_codexglue_train[i]),
                                                       np.median(polycoder4vdcwe_small_codexglue_train[i]),
                                                       np.std(polycoder4vdcwe_small_codexglue_train[i]), 
                                                       np.var(polycoder4vdcwe_small_codexglue_train[i]), 
                                                       matrix_skewness(polycoder4vdcwe_small_codexglue_train[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_small_codexglue_train[i]), 
                                                       matrix_entropy(polycoder4vdcwe_small_codexglue_train[i]), 
                                                       matrix_range(polycoder4vdcwe_small_codexglue_train[i])
                                                       ]
    
    polycoder4vdcwe_small_codexglue_test_features[i] = [np.linalg.norm(polycoder4vdcwe_small_codexglue_test[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_small_codexglue_test[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_small_codexglue_test[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_small_codexglue_test[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_small_codexglue_test[i]),
                                                       np.median(polycoder4vdcwe_small_codexglue_test[i]),
                                                       np.std(polycoder4vdcwe_small_codexglue_test[i]), 
                                                       np.var(polycoder4vdcwe_small_codexglue_test[i]), 
                                                       matrix_skewness(polycoder4vdcwe_small_codexglue_test[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_small_codexglue_test[i]), 
                                                       matrix_entropy(polycoder4vdcwe_small_codexglue_test[i]), 
                                                       matrix_range(polycoder4vdcwe_small_codexglue_test[i])
                                                       ]         
    
    polycoder4vdcwe_base_codexglue_train[i] = np.load(polycoder4vdcwe_base+trained_codexglue_path+'codexglue_train{}'.format(i)+'-data.npy')
    polycoder4vdcwe_base_codexglue_test[i] = np.load(polycoder4vdcwe_base+trained_codexglue_path+'codexglue_test{}'.format(i)+'-data.npy')
    polycoder4vdcwe_base_codexglue_train_features[i] = [np.linalg.norm(polycoder4vdcwe_base_codexglue_train[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_base_codexglue_train[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_base_codexglue_train[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_base_codexglue_train[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_base_codexglue_train[i]),
                                                       np.median(polycoder4vdcwe_base_codexglue_train[i]),
                                                       np.std(polycoder4vdcwe_base_codexglue_train[i]), 
                                                       np.var(polycoder4vdcwe_base_codexglue_train[i]), 
                                                       matrix_skewness(polycoder4vdcwe_base_codexglue_train[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_base_codexglue_train[i]), 
                                                       matrix_entropy(polycoder4vdcwe_base_codexglue_train[i]), 
                                                       matrix_range(polycoder4vdcwe_base_codexglue_train[i])
                                                       ]
    
    polycoder4vdcwe_base_codexglue_test_features[i] = [np.linalg.norm(polycoder4vdcwe_base_codexglue_test[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_base_codexglue_test[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_base_codexglue_test[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_base_codexglue_test[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_base_codexglue_test[i]),
                                                       np.median(polycoder4vdcwe_base_codexglue_test[i]),
                                                       np.std(polycoder4vdcwe_base_codexglue_test[i]), 
                                                       np.var(polycoder4vdcwe_base_codexglue_test[i]), 
                                                       matrix_skewness(polycoder4vdcwe_base_codexglue_test[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_base_codexglue_test[i]), 
                                                       matrix_entropy(polycoder4vdcwe_base_codexglue_test[i]), 
                                                       matrix_range(polycoder4vdcwe_base_codexglue_test[i])
                                                       ]     
    
    polycoder4vdcwe_large_codexglue_train[i] = np.load(polycoder4vdcwe_large+trained_codexglue_path+'codexglue_train{}'.format(i)+'-data.npy')
    polycoder4vdcwe_large_codexglue_test[i] = np.load(polycoder4vdcwe_large+trained_codexglue_path+'codexglue_test{}'.format(i)+'-data.npy')
    polycoder4vdcwe_large_codexglue_train_features[i] = [np.linalg.norm(polycoder4vdcwe_large_codexglue_train[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_large_codexglue_train[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_large_codexglue_train[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_large_codexglue_train[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_large_codexglue_train[i]),
                                                       np.median(polycoder4vdcwe_large_codexglue_train[i]),
                                                       np.std(polycoder4vdcwe_large_codexglue_train[i]), 
                                                       np.var(polycoder4vdcwe_large_codexglue_train[i]), 
                                                       matrix_skewness(polycoder4vdcwe_large_codexglue_train[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_large_codexglue_train[i]), 
                                                       matrix_entropy(polycoder4vdcwe_large_codexglue_train[i]), 
                                                       matrix_range(polycoder4vdcwe_large_codexglue_train[i])
                                                       ]
    
    polycoder4vdcwe_large_codexglue_test_features[i] = [np.linalg.norm(polycoder4vdcwe_large_codexglue_test[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_large_codexglue_test[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_large_codexglue_test[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_large_codexglue_test[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_large_codexglue_test[i]),
                                                       np.median(polycoder4vdcwe_large_codexglue_test[i]),
                                                       np.std(polycoder4vdcwe_large_codexglue_test[i]), 
                                                       np.var(polycoder4vdcwe_large_codexglue_test[i]), 
                                                       matrix_skewness(polycoder4vdcwe_large_codexglue_test[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_large_codexglue_test[i]), 
                                                       matrix_entropy(polycoder4vdcwe_large_codexglue_test[i]), 
                                                       matrix_range(polycoder4vdcwe_large_codexglue_test[i])
                                                       ]
    
    
    
    
    codebert4vdcwe_small_codexglue_train[i] = None
    codebert4vdcwe_small_codexglue_test[i] = None
    codebert4vdcwe_base_codexglue_train[i] = None
    codebert4vdcwe_base_codexglue_test[i] = None
    codegen4vdcwe_small_codexglue_train[i] = None
    codegen4vdcwe_small_codexglue_test[i] = None
    codegen4vdcwe_base_codexglue_train[i] = None
    codegen4vdcwe_base_codexglue_test[i] = None
    codet54vdcwe_small_codexglue_train[i] = None
    codet54vdcwe_small_codexglue_test[i] = None
    codet54vdcwe_base_codexglue_train[i] = None
    codet54vdcwe_base_codexglue_test[i] = None
    codet54vdcwe_large_codexglue_train[i] = None
    codet54vdcwe_large_codexglue_test[i] = None
    polycoder4vdcwe_small_codexglue_train[i] = None
    polycoder4vdcwe_small_codexglue_test[i] = None
    polycoder4vdcwe_base_codexglue_train[i] = None
    polycoder4vdcwe_base_codexglue_test[i] = None
    polycoder4vdcwe_large_codexglue_train[i] = None
    polycoder4vdcwe_large_codexglue_test[i] = None

# %%
codebert4vdcwe_small_reveal_train = {}
codebert4vdcwe_small_reveal_test = {}
codebert4vdcwe_base_reveal_train = {}
codebert4vdcwe_base_reveal_test = {}
codegen4vdcwe_small_reveal_train = {}
codegen4vdcwe_small_reveal_test = {}
codegen4vdcwe_base_reveal_train = {}
codegen4vdcwe_base_reveal_test = {}
codet54vdcwe_small_reveal_train = {}
codet54vdcwe_small_reveal_test = {}
codet54vdcwe_base_reveal_train = {}
codet54vdcwe_base_reveal_test = {}
codet54vdcwe_large_reveal_train = {}
codet54vdcwe_large_reveal_test = {}
polycoder4vdcwe_small_reveal_train = {}
polycoder4vdcwe_small_reveal_test = {}
polycoder4vdcwe_base_reveal_train = {}
polycoder4vdcwe_base_reveal_test = {}
polycoder4vdcwe_large_reveal_train = {}
polycoder4vdcwe_large_reveal_test = {}

codebert4vdcwe_small_reveal_train_features = {}
codebert4vdcwe_small_reveal_test_features = {}
codebert4vdcwe_base_reveal_train_features = {}
codebert4vdcwe_base_reveal_test_features = {}
codegen4vdcwe_small_reveal_train_features = {}
codegen4vdcwe_small_reveal_test_features = {}
codegen4vdcwe_base_reveal_train_features = {}
codegen4vdcwe_base_reveal_test_features = {}
codet54vdcwe_small_reveal_train_features = {}
codet54vdcwe_small_reveal_test_features = {}
codet54vdcwe_base_reveal_train_features = {}
codet54vdcwe_base_reveal_test_features = {}
codet54vdcwe_large_reveal_train_features = {}
codet54vdcwe_large_reveal_test_features = {}
polycoder4vdcwe_small_reveal_train_features = {}
polycoder4vdcwe_small_reveal_test_features = {}
polycoder4vdcwe_base_reveal_train_features = {}
polycoder4vdcwe_base_reveal_test_features = {}
polycoder4vdcwe_large_reveal_train_features = {}
polycoder4vdcwe_large_reveal_test_features = {}


for i in range(200):  
    codebert4vdcwe_small_reveal_train[i] = np.load(codebert4vdcwe_small+trained_reveal_path+'reveal_train{}'.format(i)+'-data.npy')
    codebert4vdcwe_small_reveal_test[i] = np.load(codebert4vdcwe_small+trained_reveal_path+'reveal_test{}'.format(i)+'-data.npy')

    
    codebert4vdcwe_small_reveal_train_features[i] = [np.linalg.norm(codebert4vdcwe_small_reveal_train[i], ord='fro'), 
                                                       np.linalg.norm(codebert4vdcwe_small_reveal_train[i], ord='nuc'),
                                                       np.count_nonzero(codebert4vdcwe_small_reveal_train[i]), 
                                                       np.linalg.norm(codebert4vdcwe_small_reveal_train[i], ord=1), 
                                                       np.mean(codebert4vdcwe_small_reveal_train[i]),
                                                       np.median(codebert4vdcwe_small_reveal_train[i]),
                                                       np.std(codebert4vdcwe_small_reveal_train[i]), 
                                                       np.var(codebert4vdcwe_small_reveal_train[i]), 
                                                       matrix_skewness(codebert4vdcwe_small_reveal_train[i]),
                                                       matrix_kurtosis(codebert4vdcwe_small_reveal_train[i]), 
                                                       matrix_entropy(codebert4vdcwe_small_reveal_train[i]), 
                                                       matrix_range(codebert4vdcwe_small_reveal_train[i])
                                                       ]
    
    codebert4vdcwe_small_reveal_test_features[i] = [np.linalg.norm(codebert4vdcwe_small_reveal_test[i], ord='fro'), 
                                                       np.linalg.norm(codebert4vdcwe_small_reveal_test[i], ord='nuc'),
                                                       np.count_nonzero(codebert4vdcwe_small_reveal_test[i]), 
                                                       np.linalg.norm(codebert4vdcwe_small_reveal_test[i], ord=1), 
                                                       np.mean(codebert4vdcwe_small_reveal_test[i]),
                                                       np.median(codebert4vdcwe_small_reveal_test[i]),
                                                       np.std(codebert4vdcwe_small_reveal_test[i]), 
                                                       np.var(codebert4vdcwe_small_reveal_test[i]), 
                                                       matrix_skewness(codebert4vdcwe_small_reveal_test[i]),
                                                       matrix_kurtosis(codebert4vdcwe_small_reveal_test[i]), 
                                                       matrix_entropy(codebert4vdcwe_small_reveal_test[i]), 
                                                       matrix_range(codebert4vdcwe_small_reveal_test[i])
                                                       ]    

    codebert4vdcwe_base_reveal_train[i] = np.load(codebert4vdcwe_base+trained_reveal_path+'reveal_train{}'.format(i)+'-data.npy')
    codebert4vdcwe_base_reveal_test[i] = np.load(codebert4vdcwe_base+trained_reveal_path+'reveal_test{}'.format(i)+'-data.npy')
    codebert4vdcwe_base_reveal_train_features[i] = [np.linalg.norm(codebert4vdcwe_base_reveal_train[i], ord='fro'), 
                                                       np.linalg.norm(codebert4vdcwe_base_reveal_train[i], ord='nuc'),
                                                       np.count_nonzero(codebert4vdcwe_base_reveal_train[i]), 
                                                       np.linalg.norm(codebert4vdcwe_base_reveal_train[i], ord=1), 
                                                       np.mean(codebert4vdcwe_base_reveal_train[i]),
                                                       np.median(codebert4vdcwe_base_reveal_train[i]),
                                                       np.std(codebert4vdcwe_base_reveal_train[i]), 
                                                       np.var(codebert4vdcwe_base_reveal_train[i]), 
                                                       matrix_skewness(codebert4vdcwe_base_reveal_train[i]),
                                                       matrix_kurtosis(codebert4vdcwe_base_reveal_train[i]), 
                                                       matrix_entropy(codebert4vdcwe_base_reveal_train[i]), 
                                                       matrix_range(codebert4vdcwe_base_reveal_train[i])
                                                       ]
    
    codebert4vdcwe_base_reveal_test_features[i] = [np.linalg.norm(codebert4vdcwe_base_reveal_test[i], ord='fro'), 
                                                       np.linalg.norm(codebert4vdcwe_base_reveal_test[i], ord='nuc'),
                                                       np.count_nonzero(codebert4vdcwe_base_reveal_test[i]), 
                                                       np.linalg.norm(codebert4vdcwe_base_reveal_test[i], ord=1), 
                                                       np.mean(codebert4vdcwe_base_reveal_test[i]),
                                                       np.median(codebert4vdcwe_base_reveal_test[i]),
                                                       np.std(codebert4vdcwe_base_reveal_test[i]), 
                                                       np.var(codebert4vdcwe_base_reveal_test[i]), 
                                                       matrix_skewness(codebert4vdcwe_base_reveal_test[i]),
                                                       matrix_kurtosis(codebert4vdcwe_base_reveal_test[i]), 
                                                       matrix_entropy(codebert4vdcwe_base_reveal_test[i]), 
                                                       matrix_range(codebert4vdcwe_base_reveal_test[i])
                                                       ]   
    
    codegen4vdcwe_small_reveal_train[i] = np.load(codegen4vdcwe_small+trained_reveal_path+'reveal_train{}'.format(i)+'-data.npy')
    codegen4vdcwe_small_reveal_test[i] = np.load(codegen4vdcwe_small+trained_reveal_path+'reveal_test{}'.format(i)+'-data.npy')
    codegen4vdcwe_small_reveal_train_features[i] = [np.linalg.norm(codegen4vdcwe_small_reveal_train[i], ord='fro'), 
                                                       np.linalg.norm(codegen4vdcwe_small_reveal_train[i], ord='nuc'),
                                                       np.count_nonzero(codegen4vdcwe_small_reveal_train[i]), 
                                                       np.linalg.norm(codegen4vdcwe_small_reveal_train[i], ord=1), 
                                                       np.mean(codegen4vdcwe_small_reveal_train[i]),
                                                       np.median(codegen4vdcwe_small_reveal_train[i]),
                                                       np.std(codegen4vdcwe_small_reveal_train[i]), 
                                                       np.var(codegen4vdcwe_small_reveal_train[i]), 
                                                       matrix_skewness(codegen4vdcwe_small_reveal_train[i]),
                                                       matrix_kurtosis(codegen4vdcwe_small_reveal_train[i]), 
                                                       matrix_entropy(codegen4vdcwe_small_reveal_train[i]), 
                                                       matrix_range(codegen4vdcwe_small_reveal_train[i])
                                                       ]
    
    codegen4vdcwe_small_reveal_test_features[i] = [np.linalg.norm(codegen4vdcwe_small_reveal_test[i], ord='fro'), 
                                                       np.linalg.norm(codegen4vdcwe_small_reveal_test[i], ord='nuc'),
                                                       np.count_nonzero(codegen4vdcwe_small_reveal_test[i]), 
                                                       np.linalg.norm(codegen4vdcwe_small_reveal_test[i], ord=1), 
                                                       np.mean(codegen4vdcwe_small_reveal_test[i]),
                                                       np.median(codegen4vdcwe_small_reveal_test[i]),
                                                       np.std(codegen4vdcwe_small_reveal_test[i]), 
                                                       np.var(codegen4vdcwe_small_reveal_test[i]), 
                                                       matrix_skewness(codegen4vdcwe_small_reveal_test[i]),
                                                       matrix_kurtosis(codegen4vdcwe_small_reveal_test[i]), 
                                                       matrix_entropy(codegen4vdcwe_small_reveal_test[i]), 
                                                       matrix_range(codegen4vdcwe_small_reveal_test[i])
                                                       ]         
    
    
    codegen4vdcwe_base_reveal_train[i] = np.load(codegen4vdcwe_base+trained_reveal_path+'reveal_train{}'.format(i)+'-data.npy')
    codegen4vdcwe_base_reveal_test[i] = np.load(codegen4vdcwe_base+trained_reveal_path+'reveal_test{}'.format(i)+'-data.npy')
    codegen4vdcwe_base_reveal_train_features[i] = [np.linalg.norm(codegen4vdcwe_base_reveal_train[i], ord='fro'), 
                                                       np.linalg.norm(codegen4vdcwe_base_reveal_train[i], ord='nuc'),
                                                       np.count_nonzero(codegen4vdcwe_base_reveal_train[i]), 
                                                       np.linalg.norm(codegen4vdcwe_base_reveal_train[i], ord=1), 
                                                       np.mean(codegen4vdcwe_base_reveal_train[i]),
                                                       np.median(codegen4vdcwe_base_reveal_train[i]),
                                                       np.std(codegen4vdcwe_base_reveal_train[i]), 
                                                       np.var(codegen4vdcwe_base_reveal_train[i]), 
                                                       matrix_skewness(codegen4vdcwe_base_reveal_train[i]),
                                                       matrix_kurtosis(codegen4vdcwe_base_reveal_train[i]), 
                                                       matrix_entropy(codegen4vdcwe_base_reveal_train[i]), 
                                                       matrix_range(codegen4vdcwe_base_reveal_train[i])
                                                       ]
    
    codegen4vdcwe_base_reveal_test_features[i] = [np.linalg.norm(codegen4vdcwe_base_reveal_test[i], ord='fro'), 
                                                       np.linalg.norm(codegen4vdcwe_base_reveal_test[i], ord='nuc'),
                                                       np.count_nonzero(codegen4vdcwe_base_reveal_test[i]), 
                                                       np.linalg.norm(codegen4vdcwe_base_reveal_test[i], ord=1), 
                                                       np.mean(codegen4vdcwe_base_reveal_test[i]),
                                                       np.median(codegen4vdcwe_base_reveal_test[i]),
                                                       np.std(codegen4vdcwe_base_reveal_test[i]), 
                                                       np.var(codegen4vdcwe_base_reveal_test[i]), 
                                                       matrix_skewness(codegen4vdcwe_base_reveal_test[i]),
                                                       matrix_kurtosis(codegen4vdcwe_base_reveal_test[i]), 
                                                       matrix_entropy(codegen4vdcwe_base_reveal_test[i]), 
                                                       matrix_range(codegen4vdcwe_base_reveal_test[i])
                                                       ] 
    
    codet54vdcwe_small_reveal_train[i] = np.load(codet54vdcwe_small+trained_reveal_path+'reveal_train{}'.format(i)+'-data.npy')
    codet54vdcwe_small_reveal_test[i] = np.load(codet54vdcwe_small+trained_reveal_path+'reveal_test{}'.format(i)+'-data.npy')
    codet54vdcwe_small_reveal_train_features[i] = [np.linalg.norm(codet54vdcwe_small_reveal_train[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_small_reveal_train[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_small_reveal_train[i]), 
                                                       np.linalg.norm(codet54vdcwe_small_reveal_train[i], ord=1), 
                                                       np.mean(codet54vdcwe_small_reveal_train[i]),
                                                       np.median(codet54vdcwe_small_reveal_train[i]),
                                                       np.std(codet54vdcwe_small_reveal_train[i]), 
                                                       np.var(codet54vdcwe_small_reveal_train[i]), 
                                                       matrix_skewness(codet54vdcwe_small_reveal_train[i]),
                                                       matrix_kurtosis(codet54vdcwe_small_reveal_train[i]), 
                                                       matrix_entropy(codet54vdcwe_small_reveal_train[i]), 
                                                       matrix_range(codet54vdcwe_small_reveal_train[i])
                                                       ]
    
    
    
    codet54vdcwe_small_reveal_test_features[i] = [np.linalg.norm(codet54vdcwe_small_reveal_test[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_small_reveal_test[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_small_reveal_test[i]), 
                                                       np.linalg.norm(codet54vdcwe_small_reveal_test[i], ord=1), 
                                                       np.mean(codet54vdcwe_small_reveal_test[i]),
                                                       np.median(codet54vdcwe_small_reveal_test[i]),
                                                       np.std(codet54vdcwe_small_reveal_test[i]), 
                                                       np.var(codet54vdcwe_small_reveal_test[i]), 
                                                       matrix_skewness(codet54vdcwe_small_reveal_test[i]),
                                                       matrix_kurtosis(codet54vdcwe_small_reveal_test[i]), 
                                                       matrix_entropy(codet54vdcwe_small_reveal_test[i]), 
                                                       matrix_range(codet54vdcwe_small_reveal_test[i])
                                                       ]         
    
    
    
    codet54vdcwe_base_reveal_train[i] = np.load(codet54vdcwe_base+trained_reveal_path+'reveal_train{}'.format(i)+'-data.npy')
    codet54vdcwe_base_reveal_test[i] = np.load(codet54vdcwe_base+trained_reveal_path+'reveal_test{}'.format(i)+'-data.npy')
    codet54vdcwe_base_reveal_train_features[i] = [np.linalg.norm(codet54vdcwe_base_reveal_train[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_base_reveal_train[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_base_reveal_train[i]), 
                                                       np.linalg.norm(codet54vdcwe_base_reveal_train[i], ord=1), 
                                                       np.mean(codet54vdcwe_base_reveal_train[i]),
                                                       np.median(codet54vdcwe_base_reveal_train[i]),
                                                       np.std(codet54vdcwe_base_reveal_train[i]), 
                                                       np.var(codet54vdcwe_base_reveal_train[i]), 
                                                       matrix_skewness(codet54vdcwe_base_reveal_train[i]),
                                                       matrix_kurtosis(codet54vdcwe_base_reveal_train[i]), 
                                                       matrix_entropy(codet54vdcwe_base_reveal_train[i]), 
                                                       matrix_range(codet54vdcwe_base_reveal_train[i])
                                                       ]
    
    codet54vdcwe_base_reveal_test_features[i] = [np.linalg.norm(codet54vdcwe_base_reveal_test[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_base_reveal_test[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_base_reveal_test[i]), 
                                                       np.linalg.norm(codet54vdcwe_base_reveal_test[i], ord=1), 
                                                       np.mean(codet54vdcwe_base_reveal_test[i]),
                                                       np.median(codet54vdcwe_base_reveal_test[i]),
                                                       np.std(codet54vdcwe_base_reveal_test[i]), 
                                                       np.var(codet54vdcwe_base_reveal_test[i]), 
                                                       matrix_skewness(codet54vdcwe_base_reveal_test[i]),
                                                       matrix_kurtosis(codet54vdcwe_base_reveal_test[i]), 
                                                       matrix_entropy(codet54vdcwe_base_reveal_test[i]), 
                                                       matrix_range(codet54vdcwe_base_reveal_test[i])
                                                       ]     
    
    codet54vdcwe_large_reveal_train[i] = np.load(codet54vdcwe_large+trained_reveal_path+'reveal_train{}'.format(i)+'-data.npy')
    codet54vdcwe_large_reveal_test[i] = np.load(codet54vdcwe_large+trained_reveal_path+'reveal_test{}'.format(i)+'-data.npy')
    codet54vdcwe_large_reveal_train_features[i] = [np.linalg.norm(codet54vdcwe_large_reveal_train[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_large_reveal_train[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_large_reveal_train[i]), 
                                                       np.linalg.norm(codet54vdcwe_large_reveal_train[i], ord=1), 
                                                       np.mean(codet54vdcwe_large_reveal_train[i]),
                                                       np.median(codet54vdcwe_large_reveal_train[i]),
                                                       np.std(codet54vdcwe_large_reveal_train[i]), 
                                                       np.var(codet54vdcwe_large_reveal_train[i]), 
                                                       matrix_skewness(codet54vdcwe_large_reveal_train[i]),
                                                       matrix_kurtosis(codet54vdcwe_large_reveal_train[i]), 
                                                       matrix_entropy(codet54vdcwe_large_reveal_train[i]), 
                                                       matrix_range(codet54vdcwe_large_reveal_train[i])
                                                       ]
    
    codet54vdcwe_large_reveal_test_features[i] = [np.linalg.norm(codet54vdcwe_large_reveal_test[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_large_reveal_test[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_large_reveal_test[i]), 
                                                       np.linalg.norm(codet54vdcwe_large_reveal_test[i], ord=1), 
                                                       np.mean(codet54vdcwe_large_reveal_test[i]),
                                                       np.median(codet54vdcwe_large_reveal_test[i]),
                                                       np.std(codet54vdcwe_large_reveal_test[i]), 
                                                       np.var(codet54vdcwe_large_reveal_test[i]), 
                                                       matrix_skewness(codet54vdcwe_large_reveal_test[i]),
                                                       matrix_kurtosis(codet54vdcwe_large_reveal_test[i]), 
                                                       matrix_entropy(codet54vdcwe_large_reveal_test[i]), 
                                                       matrix_range(codet54vdcwe_large_reveal_test[i])
                                                       ]     

    polycoder4vdcwe_small_reveal_train[i] = np.load(polycoder4vdcwe_small+trained_reveal_path+'reveal_train{}'.format(i)+'-data.npy')
    polycoder4vdcwe_small_reveal_test[i] = np.load(polycoder4vdcwe_small+trained_reveal_path+'reveal_test{}'.format(i)+'-data.npy')
    polycoder4vdcwe_small_reveal_train_features[i] = [np.linalg.norm(polycoder4vdcwe_small_reveal_train[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_small_reveal_train[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_small_reveal_train[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_small_reveal_train[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_small_reveal_train[i]),
                                                       np.median(polycoder4vdcwe_small_reveal_train[i]),
                                                       np.std(polycoder4vdcwe_small_reveal_train[i]), 
                                                       np.var(polycoder4vdcwe_small_reveal_train[i]), 
                                                       matrix_skewness(polycoder4vdcwe_small_reveal_train[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_small_reveal_train[i]), 
                                                       matrix_entropy(polycoder4vdcwe_small_reveal_train[i]), 
                                                       matrix_range(polycoder4vdcwe_small_reveal_train[i])
                                                       ]
    
    polycoder4vdcwe_small_reveal_test_features[i] = [np.linalg.norm(polycoder4vdcwe_small_reveal_test[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_small_reveal_test[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_small_reveal_test[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_small_reveal_test[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_small_reveal_test[i]),
                                                       np.median(polycoder4vdcwe_small_reveal_test[i]),
                                                       np.std(polycoder4vdcwe_small_reveal_test[i]), 
                                                       np.var(polycoder4vdcwe_small_reveal_test[i]), 
                                                       matrix_skewness(polycoder4vdcwe_small_reveal_test[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_small_reveal_test[i]), 
                                                       matrix_entropy(polycoder4vdcwe_small_reveal_test[i]), 
                                                       matrix_range(polycoder4vdcwe_small_reveal_test[i])
                                                       ]         
    
    polycoder4vdcwe_base_reveal_train[i] = np.load(polycoder4vdcwe_base+trained_reveal_path+'reveal_train{}'.format(i)+'-data.npy')
    polycoder4vdcwe_base_reveal_test[i] = np.load(polycoder4vdcwe_base+trained_reveal_path+'reveal_test{}'.format(i)+'-data.npy')
    polycoder4vdcwe_base_reveal_train_features[i] = [np.linalg.norm(polycoder4vdcwe_base_reveal_train[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_base_reveal_train[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_base_reveal_train[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_base_reveal_train[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_base_reveal_train[i]),
                                                       np.median(polycoder4vdcwe_base_reveal_train[i]),
                                                       np.std(polycoder4vdcwe_base_reveal_train[i]), 
                                                       np.var(polycoder4vdcwe_base_reveal_train[i]), 
                                                       matrix_skewness(polycoder4vdcwe_base_reveal_train[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_base_reveal_train[i]), 
                                                       matrix_entropy(polycoder4vdcwe_base_reveal_train[i]), 
                                                       matrix_range(polycoder4vdcwe_base_reveal_train[i])
                                                       ]
    
    polycoder4vdcwe_base_reveal_test_features[i] = [np.linalg.norm(polycoder4vdcwe_base_reveal_test[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_base_reveal_test[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_base_reveal_test[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_base_reveal_test[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_base_reveal_test[i]),
                                                       np.median(polycoder4vdcwe_base_reveal_test[i]),
                                                       np.std(polycoder4vdcwe_base_reveal_test[i]), 
                                                       np.var(polycoder4vdcwe_base_reveal_test[i]), 
                                                       matrix_skewness(polycoder4vdcwe_base_reveal_test[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_base_reveal_test[i]), 
                                                       matrix_entropy(polycoder4vdcwe_base_reveal_test[i]), 
                                                       matrix_range(polycoder4vdcwe_base_reveal_test[i])
                                                       ]     
    
    polycoder4vdcwe_large_reveal_train[i] = np.load(polycoder4vdcwe_large+trained_reveal_path+'reveal_train{}'.format(i)+'-data.npy')
    polycoder4vdcwe_large_reveal_test[i] = np.load(polycoder4vdcwe_large+trained_reveal_path+'reveal_test{}'.format(i)+'-data.npy')
    polycoder4vdcwe_large_reveal_train_features[i] = [np.linalg.norm(polycoder4vdcwe_large_reveal_train[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_large_reveal_train[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_large_reveal_train[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_large_reveal_train[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_large_reveal_train[i]),
                                                       np.median(polycoder4vdcwe_large_reveal_train[i]),
                                                       np.std(polycoder4vdcwe_large_reveal_train[i]), 
                                                       np.var(polycoder4vdcwe_large_reveal_train[i]), 
                                                       matrix_skewness(polycoder4vdcwe_large_reveal_train[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_large_reveal_train[i]), 
                                                       matrix_entropy(polycoder4vdcwe_large_reveal_train[i]), 
                                                       matrix_range(polycoder4vdcwe_large_reveal_train[i])
                                                       ]
    
    polycoder4vdcwe_large_reveal_test_features[i] = [np.linalg.norm(polycoder4vdcwe_large_reveal_test[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_large_reveal_test[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_large_reveal_test[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_large_reveal_test[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_large_reveal_test[i]),
                                                       np.median(polycoder4vdcwe_large_reveal_test[i]),
                                                       np.std(polycoder4vdcwe_large_reveal_test[i]), 
                                                       np.var(polycoder4vdcwe_large_reveal_test[i]), 
                                                       matrix_skewness(polycoder4vdcwe_large_reveal_test[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_large_reveal_test[i]), 
                                                       matrix_entropy(polycoder4vdcwe_large_reveal_test[i]), 
                                                       matrix_range(polycoder4vdcwe_large_reveal_test[i])
                                                       ]
    
    codebert4vdcwe_small_reveal_train[i] = None
    codebert4vdcwe_small_reveal_test[i] = None
    codebert4vdcwe_base_reveal_train[i] = None
    codebert4vdcwe_base_reveal_test[i] = None
    codegen4vdcwe_small_reveal_train[i] = None
    codegen4vdcwe_small_reveal_test[i] = None
    codegen4vdcwe_base_reveal_train[i] = None
    codegen4vdcwe_base_reveal_test[i] = None
    codet54vdcwe_small_reveal_train[i] = None
    codet54vdcwe_small_reveal_test[i] = None
    codet54vdcwe_base_reveal_train[i] = None
    codet54vdcwe_base_reveal_test[i] = None
    codet54vdcwe_large_reveal_train[i] = None
    codet54vdcwe_large_reveal_test[i] = None
    polycoder4vdcwe_small_reveal_train[i] = None
    polycoder4vdcwe_small_reveal_test[i] = None
    polycoder4vdcwe_base_reveal_train[i] = None
    polycoder4vdcwe_base_reveal_test[i] = None
    polycoder4vdcwe_large_reveal_train[i] = None
    polycoder4vdcwe_large_reveal_test[i] = None

# %%
codebert4vdcwe_small_cwe119_train = {}
codebert4vdcwe_small_cwe119_test = {}
codebert4vdcwe_base_cwe119_train = {}
codebert4vdcwe_base_cwe119_test = {}
codegen4vdcwe_small_cwe119_train = {}
codegen4vdcwe_small_cwe119_test = {}
codegen4vdcwe_base_cwe119_train = {}
codegen4vdcwe_base_cwe119_test = {}
codet54vdcwe_small_cwe119_train = {}
codet54vdcwe_small_cwe119_test = {}
codet54vdcwe_base_cwe119_train = {}
codet54vdcwe_base_cwe119_test = {}
codet54vdcwe_large_cwe119_train = {}
codet54vdcwe_large_cwe119_test = {}
polycoder4vdcwe_small_cwe119_train = {}
polycoder4vdcwe_small_cwe119_test = {}
polycoder4vdcwe_base_cwe119_train = {}
polycoder4vdcwe_base_cwe119_test = {}
polycoder4vdcwe_large_cwe119_train = {}
polycoder4vdcwe_large_cwe119_test = {}

codebert4vdcwe_small_cwe119_train_features = {}
codebert4vdcwe_small_cwe119_test_features = {}
codebert4vdcwe_base_cwe119_train_features = {}
codebert4vdcwe_base_cwe119_test_features = {}
codegen4vdcwe_small_cwe119_train_features = {}
codegen4vdcwe_small_cwe119_test_features = {}
codegen4vdcwe_base_cwe119_train_features = {}
codegen4vdcwe_base_cwe119_test_features = {}
codet54vdcwe_small_cwe119_train_features = {}
codet54vdcwe_small_cwe119_test_features = {}
codet54vdcwe_base_cwe119_train_features = {}
codet54vdcwe_base_cwe119_test_features = {}
codet54vdcwe_large_cwe119_train_features = {}
codet54vdcwe_large_cwe119_test_features = {}
polycoder4vdcwe_small_cwe119_train_features = {}
polycoder4vdcwe_small_cwe119_test_features = {}
polycoder4vdcwe_base_cwe119_train_features = {}
polycoder4vdcwe_base_cwe119_test_features = {}
polycoder4vdcwe_large_cwe119_train_features = {}
polycoder4vdcwe_large_cwe119_test_features = {}


for i in range(200):  
    codebert4vdcwe_small_cwe119_train[i] = np.load(codebert4vdcwe_small+trained_cwe119_path+'cwe119_train{}'.format(i)+'-data.npy')
    codebert4vdcwe_small_cwe119_test[i] = np.load(codebert4vdcwe_small+trained_cwe119_path+'cwe119_test{}'.format(i)+'-data.npy')
    print(np.shape(codebert4vdcwe_small_cwe119_train[i]))  
    print(np.shape(codebert4vdcwe_small_cwe119_test[i]))
    
    codebert4vdcwe_small_cwe119_train_features[i] = [np.linalg.norm(codebert4vdcwe_small_cwe119_train[i], ord='fro'), 
                                                       np.linalg.norm(codebert4vdcwe_small_cwe119_train[i], ord='nuc'),
                                                       np.count_nonzero(codebert4vdcwe_small_cwe119_train[i]), 
                                                       np.linalg.norm(codebert4vdcwe_small_cwe119_train[i], ord=1), 
                                                       np.mean(codebert4vdcwe_small_cwe119_train[i]),
                                                       np.median(codebert4vdcwe_small_cwe119_train[i]),
                                                       np.std(codebert4vdcwe_small_cwe119_train[i]), 
                                                       np.var(codebert4vdcwe_small_cwe119_train[i]), 
                                                       matrix_skewness(codebert4vdcwe_small_cwe119_train[i]),
                                                       matrix_kurtosis(codebert4vdcwe_small_cwe119_train[i]), 
                                                       matrix_entropy(codebert4vdcwe_small_cwe119_train[i]), 
                                                       matrix_range(codebert4vdcwe_small_cwe119_train[i])
                                                       ]
    
    codebert4vdcwe_small_cwe119_test_features[i] = [np.linalg.norm(codebert4vdcwe_small_cwe119_test[i], ord='fro'), 
                                                       np.linalg.norm(codebert4vdcwe_small_cwe119_test[i], ord='nuc'),
                                                       np.count_nonzero(codebert4vdcwe_small_cwe119_test[i]), 
                                                       np.linalg.norm(codebert4vdcwe_small_cwe119_test[i], ord=1), 
                                                       np.mean(codebert4vdcwe_small_cwe119_test[i]),
                                                       np.median(codebert4vdcwe_small_cwe119_test[i]),
                                                       np.std(codebert4vdcwe_small_cwe119_test[i]), 
                                                       np.var(codebert4vdcwe_small_cwe119_test[i]), 
                                                       matrix_skewness(codebert4vdcwe_small_cwe119_test[i]),
                                                       matrix_kurtosis(codebert4vdcwe_small_cwe119_test[i]), 
                                                       matrix_entropy(codebert4vdcwe_small_cwe119_test[i]), 
                                                       matrix_range(codebert4vdcwe_small_cwe119_test[i])
                                                       ]    

    codebert4vdcwe_base_cwe119_train[i] = np.load(codebert4vdcwe_base+trained_cwe119_path+'cwe119_train{}'.format(i)+'-data.npy')
    codebert4vdcwe_base_cwe119_test[i] = np.load(codebert4vdcwe_base+trained_cwe119_path+'cwe119_test{}'.format(i)+'-data.npy')
    codebert4vdcwe_base_cwe119_train_features[i] = [np.linalg.norm(codebert4vdcwe_base_cwe119_train[i], ord='fro'), 
                                                       np.linalg.norm(codebert4vdcwe_base_cwe119_train[i], ord='nuc'),
                                                       np.count_nonzero(codebert4vdcwe_base_cwe119_train[i]), 
                                                       np.linalg.norm(codebert4vdcwe_base_cwe119_train[i], ord=1), 
                                                       np.mean(codebert4vdcwe_base_cwe119_train[i]),
                                                       np.median(codebert4vdcwe_base_cwe119_train[i]),
                                                       np.std(codebert4vdcwe_base_cwe119_train[i]), 
                                                       np.var(codebert4vdcwe_base_cwe119_train[i]), 
                                                       matrix_skewness(codebert4vdcwe_base_cwe119_train[i]),
                                                       matrix_kurtosis(codebert4vdcwe_base_cwe119_train[i]), 
                                                       matrix_entropy(codebert4vdcwe_base_cwe119_train[i]), 
                                                       matrix_range(codebert4vdcwe_base_cwe119_train[i])
                                                       ]
    
    codebert4vdcwe_base_cwe119_test_features[i] = [np.linalg.norm(codebert4vdcwe_base_cwe119_test[i], ord='fro'), 
                                                       np.linalg.norm(codebert4vdcwe_base_cwe119_test[i], ord='nuc'),
                                                       np.count_nonzero(codebert4vdcwe_base_cwe119_test[i]), 
                                                       np.linalg.norm(codebert4vdcwe_base_cwe119_test[i], ord=1), 
                                                       np.mean(codebert4vdcwe_base_cwe119_test[i]),
                                                       np.median(codebert4vdcwe_base_cwe119_test[i]),
                                                       np.std(codebert4vdcwe_base_cwe119_test[i]), 
                                                       np.var(codebert4vdcwe_base_cwe119_test[i]), 
                                                       matrix_skewness(codebert4vdcwe_base_cwe119_test[i]),
                                                       matrix_kurtosis(codebert4vdcwe_base_cwe119_test[i]), 
                                                       matrix_entropy(codebert4vdcwe_base_cwe119_test[i]), 
                                                       matrix_range(codebert4vdcwe_base_cwe119_test[i])
                                                       ]   
    
    codegen4vdcwe_small_cwe119_train[i] = np.load(codegen4vdcwe_small+trained_cwe119_path+'cwe119_train{}'.format(i)+'-data.npy')
    codegen4vdcwe_small_cwe119_test[i] = np.load(codegen4vdcwe_small+trained_cwe119_path+'cwe119_test{}'.format(i)+'-data.npy')
    codegen4vdcwe_small_cwe119_train_features[i] = [np.linalg.norm(codegen4vdcwe_small_cwe119_train[i], ord='fro'), 
                                                       np.linalg.norm(codegen4vdcwe_small_cwe119_train[i], ord='nuc'),
                                                       np.count_nonzero(codegen4vdcwe_small_cwe119_train[i]), 
                                                       np.linalg.norm(codegen4vdcwe_small_cwe119_train[i], ord=1), 
                                                       np.mean(codegen4vdcwe_small_cwe119_train[i]),
                                                       np.median(codegen4vdcwe_small_cwe119_train[i]),
                                                       np.std(codegen4vdcwe_small_cwe119_train[i]), 
                                                       np.var(codegen4vdcwe_small_cwe119_train[i]), 
                                                       matrix_skewness(codegen4vdcwe_small_cwe119_train[i]),
                                                       matrix_kurtosis(codegen4vdcwe_small_cwe119_train[i]), 
                                                       matrix_entropy(codegen4vdcwe_small_cwe119_train[i]), 
                                                       matrix_range(codegen4vdcwe_small_cwe119_train[i])
                                                       ]
    
    codegen4vdcwe_small_cwe119_test_features[i] = [np.linalg.norm(codegen4vdcwe_small_cwe119_test[i], ord='fro'), 
                                                       np.linalg.norm(codegen4vdcwe_small_cwe119_test[i], ord='nuc'),
                                                       np.count_nonzero(codegen4vdcwe_small_cwe119_test[i]), 
                                                       np.linalg.norm(codegen4vdcwe_small_cwe119_test[i], ord=1), 
                                                       np.mean(codegen4vdcwe_small_cwe119_test[i]),
                                                       np.median(codegen4vdcwe_small_cwe119_test[i]),
                                                       np.std(codegen4vdcwe_small_cwe119_test[i]), 
                                                       np.var(codegen4vdcwe_small_cwe119_test[i]), 
                                                       matrix_skewness(codegen4vdcwe_small_cwe119_test[i]),
                                                       matrix_kurtosis(codegen4vdcwe_small_cwe119_test[i]), 
                                                       matrix_entropy(codegen4vdcwe_small_cwe119_test[i]), 
                                                       matrix_range(codegen4vdcwe_small_cwe119_test[i])
                                                       ]         
    
    
    codegen4vdcwe_base_cwe119_train[i] = np.load(codegen4vdcwe_base+trained_cwe119_path+'cwe119_train{}'.format(i)+'-data.npy')
    codegen4vdcwe_base_cwe119_test[i] = np.load(codegen4vdcwe_base+trained_cwe119_path+'cwe119_test{}'.format(i)+'-data.npy')
    codegen4vdcwe_base_cwe119_train_features[i] = [np.linalg.norm(codegen4vdcwe_base_cwe119_train[i], ord='fro'), 
                                                       np.linalg.norm(codegen4vdcwe_base_cwe119_train[i], ord='nuc'),
                                                       np.count_nonzero(codegen4vdcwe_base_cwe119_train[i]), 
                                                       np.linalg.norm(codegen4vdcwe_base_cwe119_train[i], ord=1), 
                                                       np.mean(codegen4vdcwe_base_cwe119_train[i]),
                                                       np.median(codegen4vdcwe_base_cwe119_train[i]),
                                                       np.std(codegen4vdcwe_base_cwe119_train[i]), 
                                                       np.var(codegen4vdcwe_base_cwe119_train[i]), 
                                                       matrix_skewness(codegen4vdcwe_base_cwe119_train[i]),
                                                       matrix_kurtosis(codegen4vdcwe_base_cwe119_train[i]), 
                                                       matrix_entropy(codegen4vdcwe_base_cwe119_train[i]), 
                                                       matrix_range(codegen4vdcwe_base_cwe119_train[i])
                                                       ]
    
    codegen4vdcwe_base_cwe119_test_features[i] = [np.linalg.norm(codegen4vdcwe_base_cwe119_test[i], ord='fro'), 
                                                       np.linalg.norm(codegen4vdcwe_base_cwe119_test[i], ord='nuc'),
                                                       np.count_nonzero(codegen4vdcwe_base_cwe119_test[i]), 
                                                       np.linalg.norm(codegen4vdcwe_base_cwe119_test[i], ord=1), 
                                                       np.mean(codegen4vdcwe_base_cwe119_test[i]),
                                                       np.median(codegen4vdcwe_base_cwe119_test[i]),
                                                       np.std(codegen4vdcwe_base_cwe119_test[i]), 
                                                       np.var(codegen4vdcwe_base_cwe119_test[i]), 
                                                       matrix_skewness(codegen4vdcwe_base_cwe119_test[i]),
                                                       matrix_kurtosis(codegen4vdcwe_base_cwe119_test[i]), 
                                                       matrix_entropy(codegen4vdcwe_base_cwe119_test[i]), 
                                                       matrix_range(codegen4vdcwe_base_cwe119_test[i])
                                                       ] 
    
    codet54vdcwe_small_cwe119_train[i] = np.load(codet54vdcwe_small+trained_cwe119_path+'cwe119_train{}'.format(i)+'-data.npy')
    codet54vdcwe_small_cwe119_test[i] = np.load(codet54vdcwe_small+trained_cwe119_path+'cwe119_test{}'.format(i)+'-data.npy')
    codet54vdcwe_small_cwe119_train_features[i] = [np.linalg.norm(codet54vdcwe_small_cwe119_train[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_small_cwe119_train[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_small_cwe119_train[i]), 
                                                       np.linalg.norm(codet54vdcwe_small_cwe119_train[i], ord=1), 
                                                       np.mean(codet54vdcwe_small_cwe119_train[i]),
                                                       np.median(codet54vdcwe_small_cwe119_train[i]),
                                                       np.std(codet54vdcwe_small_cwe119_train[i]), 
                                                       np.var(codet54vdcwe_small_cwe119_train[i]), 
                                                       matrix_skewness(codet54vdcwe_small_cwe119_train[i]),
                                                       matrix_kurtosis(codet54vdcwe_small_cwe119_train[i]), 
                                                       matrix_entropy(codet54vdcwe_small_cwe119_train[i]), 
                                                       matrix_range(codet54vdcwe_small_cwe119_train[i])
                                                       ]
    
    
    
    codet54vdcwe_small_cwe119_test_features[i] = [np.linalg.norm(codet54vdcwe_small_cwe119_test[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_small_cwe119_test[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_small_cwe119_test[i]), 
                                                       np.linalg.norm(codet54vdcwe_small_cwe119_test[i], ord=1), 
                                                       np.mean(codet54vdcwe_small_cwe119_test[i]),
                                                       np.median(codet54vdcwe_small_cwe119_test[i]),
                                                       np.std(codet54vdcwe_small_cwe119_test[i]), 
                                                       np.var(codet54vdcwe_small_cwe119_test[i]), 
                                                       matrix_skewness(codet54vdcwe_small_cwe119_test[i]),
                                                       matrix_kurtosis(codet54vdcwe_small_cwe119_test[i]), 
                                                       matrix_entropy(codet54vdcwe_small_cwe119_test[i]), 
                                                       matrix_range(codet54vdcwe_small_cwe119_test[i])
                                                       ]         
    
    
    
    codet54vdcwe_base_cwe119_train[i] = np.load(codet54vdcwe_base+trained_cwe119_path+'cwe119_train{}'.format(i)+'-data.npy')
    codet54vdcwe_base_cwe119_test[i] = np.load(codet54vdcwe_base+trained_cwe119_path+'cwe119_test{}'.format(i)+'-data.npy')
    codet54vdcwe_base_cwe119_train_features[i] = [np.linalg.norm(codet54vdcwe_base_cwe119_train[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_base_cwe119_train[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_base_cwe119_train[i]), 
                                                       np.linalg.norm(codet54vdcwe_base_cwe119_train[i], ord=1), 
                                                       np.mean(codet54vdcwe_base_cwe119_train[i]),
                                                       np.median(codet54vdcwe_base_cwe119_train[i]),
                                                       np.std(codet54vdcwe_base_cwe119_train[i]), 
                                                       np.var(codet54vdcwe_base_cwe119_train[i]), 
                                                       matrix_skewness(codet54vdcwe_base_cwe119_train[i]),
                                                       matrix_kurtosis(codet54vdcwe_base_cwe119_train[i]), 
                                                       matrix_entropy(codet54vdcwe_base_cwe119_train[i]), 
                                                       matrix_range(codet54vdcwe_base_cwe119_train[i])
                                                       ]
    
    codet54vdcwe_base_cwe119_test_features[i] = [np.linalg.norm(codet54vdcwe_base_cwe119_test[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_base_cwe119_test[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_base_cwe119_test[i]), 
                                                       np.linalg.norm(codet54vdcwe_base_cwe119_test[i], ord=1), 
                                                       np.mean(codet54vdcwe_base_cwe119_test[i]),
                                                       np.median(codet54vdcwe_base_cwe119_test[i]),
                                                       np.std(codet54vdcwe_base_cwe119_test[i]), 
                                                       np.var(codet54vdcwe_base_cwe119_test[i]), 
                                                       matrix_skewness(codet54vdcwe_base_cwe119_test[i]),
                                                       matrix_kurtosis(codet54vdcwe_base_cwe119_test[i]), 
                                                       matrix_entropy(codet54vdcwe_base_cwe119_test[i]), 
                                                       matrix_range(codet54vdcwe_base_cwe119_test[i])
                                                       ]     
    
    codet54vdcwe_large_cwe119_train[i] = np.load(codet54vdcwe_large+trained_cwe119_path+'cwe119_train{}'.format(i)+'-data.npy')
    codet54vdcwe_large_cwe119_test[i] = np.load(codet54vdcwe_large+trained_cwe119_path+'cwe119_test{}'.format(i)+'-data.npy')
    codet54vdcwe_large_cwe119_train_features[i] = [np.linalg.norm(codet54vdcwe_large_cwe119_train[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_large_cwe119_train[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_large_cwe119_train[i]), 
                                                       np.linalg.norm(codet54vdcwe_large_cwe119_train[i], ord=1), 
                                                       np.mean(codet54vdcwe_large_cwe119_train[i]),
                                                       np.median(codet54vdcwe_large_cwe119_train[i]),
                                                       np.std(codet54vdcwe_large_cwe119_train[i]), 
                                                       np.var(codet54vdcwe_large_cwe119_train[i]), 
                                                       matrix_skewness(codet54vdcwe_large_cwe119_train[i]),
                                                       matrix_kurtosis(codet54vdcwe_large_cwe119_train[i]), 
                                                       matrix_entropy(codet54vdcwe_large_cwe119_train[i]), 
                                                       matrix_range(codet54vdcwe_large_cwe119_train[i])
                                                       ]
    
    codet54vdcwe_large_cwe119_test_features[i] = [np.linalg.norm(codet54vdcwe_large_cwe119_test[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_large_cwe119_test[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_large_cwe119_test[i]), 
                                                       np.linalg.norm(codet54vdcwe_large_cwe119_test[i], ord=1), 
                                                       np.mean(codet54vdcwe_large_cwe119_test[i]),
                                                       np.median(codet54vdcwe_large_cwe119_test[i]),
                                                       np.std(codet54vdcwe_large_cwe119_test[i]), 
                                                       np.var(codet54vdcwe_large_cwe119_test[i]), 
                                                       matrix_skewness(codet54vdcwe_large_cwe119_test[i]),
                                                       matrix_kurtosis(codet54vdcwe_large_cwe119_test[i]), 
                                                       matrix_entropy(codet54vdcwe_large_cwe119_test[i]), 
                                                       matrix_range(codet54vdcwe_large_cwe119_test[i])
                                                       ]     

    polycoder4vdcwe_small_cwe119_train[i] = np.load(polycoder4vdcwe_small+trained_cwe119_path+'cwe119_train{}'.format(i)+'-data.npy')
    polycoder4vdcwe_small_cwe119_test[i] = np.load(polycoder4vdcwe_small+trained_cwe119_path+'cwe119_test{}'.format(i)+'-data.npy')
    polycoder4vdcwe_small_cwe119_train_features[i] = [np.linalg.norm(polycoder4vdcwe_small_cwe119_train[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_small_cwe119_train[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_small_cwe119_train[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_small_cwe119_train[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_small_cwe119_train[i]),
                                                       np.median(polycoder4vdcwe_small_cwe119_train[i]),
                                                       np.std(polycoder4vdcwe_small_cwe119_train[i]), 
                                                       np.var(polycoder4vdcwe_small_cwe119_train[i]), 
                                                       matrix_skewness(polycoder4vdcwe_small_cwe119_train[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_small_cwe119_train[i]), 
                                                       matrix_entropy(polycoder4vdcwe_small_cwe119_train[i]), 
                                                       matrix_range(polycoder4vdcwe_small_cwe119_train[i])
                                                       ]
    
    polycoder4vdcwe_small_cwe119_test_features[i] = [np.linalg.norm(polycoder4vdcwe_small_cwe119_test[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_small_cwe119_test[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_small_cwe119_test[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_small_cwe119_test[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_small_cwe119_test[i]),
                                                       np.median(polycoder4vdcwe_small_cwe119_test[i]),
                                                       np.std(polycoder4vdcwe_small_cwe119_test[i]), 
                                                       np.var(polycoder4vdcwe_small_cwe119_test[i]), 
                                                       matrix_skewness(polycoder4vdcwe_small_cwe119_test[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_small_cwe119_test[i]), 
                                                       matrix_entropy(polycoder4vdcwe_small_cwe119_test[i]), 
                                                       matrix_range(polycoder4vdcwe_small_cwe119_test[i])
                                                       ]         
    
    polycoder4vdcwe_base_cwe119_train[i] = np.load(polycoder4vdcwe_base+trained_cwe119_path+'cwe119_train{}'.format(i)+'-data.npy')
    polycoder4vdcwe_base_cwe119_test[i] = np.load(polycoder4vdcwe_base+trained_cwe119_path+'cwe119_test{}'.format(i)+'-data.npy')
    polycoder4vdcwe_base_cwe119_train_features[i] = [np.linalg.norm(polycoder4vdcwe_base_cwe119_train[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_base_cwe119_train[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_base_cwe119_train[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_base_cwe119_train[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_base_cwe119_train[i]),
                                                       np.median(polycoder4vdcwe_base_cwe119_train[i]),
                                                       np.std(polycoder4vdcwe_base_cwe119_train[i]), 
                                                       np.var(polycoder4vdcwe_base_cwe119_train[i]), 
                                                       matrix_skewness(polycoder4vdcwe_base_cwe119_train[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_base_cwe119_train[i]), 
                                                       matrix_entropy(polycoder4vdcwe_base_cwe119_train[i]), 
                                                       matrix_range(polycoder4vdcwe_base_cwe119_train[i])
                                                       ]
    
    polycoder4vdcwe_base_cwe119_test_features[i] = [np.linalg.norm(polycoder4vdcwe_base_cwe119_test[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_base_cwe119_test[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_base_cwe119_test[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_base_cwe119_test[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_base_cwe119_test[i]),
                                                       np.median(polycoder4vdcwe_base_cwe119_test[i]),
                                                       np.std(polycoder4vdcwe_base_cwe119_test[i]), 
                                                       np.var(polycoder4vdcwe_base_cwe119_test[i]), 
                                                       matrix_skewness(polycoder4vdcwe_base_cwe119_test[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_base_cwe119_test[i]), 
                                                       matrix_entropy(polycoder4vdcwe_base_cwe119_test[i]), 
                                                       matrix_range(polycoder4vdcwe_base_cwe119_test[i])
                                                       ]     
    
    polycoder4vdcwe_large_cwe119_train[i] = np.load(polycoder4vdcwe_large+trained_cwe119_path+'cwe119_train{}'.format(i)+'-data.npy')
    polycoder4vdcwe_large_cwe119_test[i] = np.load(polycoder4vdcwe_large+trained_cwe119_path+'cwe119_test{}'.format(i)+'-data.npy')
    polycoder4vdcwe_large_cwe119_train_features[i] = [np.linalg.norm(polycoder4vdcwe_large_cwe119_train[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_large_cwe119_train[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_large_cwe119_train[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_large_cwe119_train[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_large_cwe119_train[i]),
                                                       np.median(polycoder4vdcwe_large_cwe119_train[i]),
                                                       np.std(polycoder4vdcwe_large_cwe119_train[i]), 
                                                       np.var(polycoder4vdcwe_large_cwe119_train[i]), 
                                                       matrix_skewness(polycoder4vdcwe_large_cwe119_train[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_large_cwe119_train[i]), 
                                                       matrix_entropy(polycoder4vdcwe_large_cwe119_train[i]), 
                                                       matrix_range(polycoder4vdcwe_large_cwe119_train[i])
                                                       ]
    
    polycoder4vdcwe_large_cwe119_test_features[i] = [np.linalg.norm(polycoder4vdcwe_large_cwe119_test[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_large_cwe119_test[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_large_cwe119_test[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_large_cwe119_test[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_large_cwe119_test[i]),
                                                       np.median(polycoder4vdcwe_large_cwe119_test[i]),
                                                       np.std(polycoder4vdcwe_large_cwe119_test[i]), 
                                                       np.var(polycoder4vdcwe_large_cwe119_test[i]), 
                                                       matrix_skewness(polycoder4vdcwe_large_cwe119_test[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_large_cwe119_test[i]), 
                                                       matrix_entropy(polycoder4vdcwe_large_cwe119_test[i]), 
                                                       matrix_range(polycoder4vdcwe_large_cwe119_test[i])
                                                       ]
    
    codebert4vdcwe_small_cwe119_train[i] = None
    codebert4vdcwe_small_cwe119_test[i] = None
    codebert4vdcwe_base_cwe119_train[i] = None
    codebert4vdcwe_base_cwe119_test[i] = None
    codegen4vdcwe_small_cwe119_train[i] = None
    codegen4vdcwe_small_cwe119_test[i] = None
    codegen4vdcwe_base_cwe119_train[i] = None
    codegen4vdcwe_base_cwe119_test[i] = None
    codet54vdcwe_small_cwe119_train[i] = None
    codet54vdcwe_small_cwe119_test[i] = None
    codet54vdcwe_base_cwe119_train[i] = None
    codet54vdcwe_base_cwe119_test[i] = None
    codet54vdcwe_large_cwe119_train[i] = None
    codet54vdcwe_large_cwe119_test[i] = None
    polycoder4vdcwe_small_cwe119_train[i] = None
    polycoder4vdcwe_small_cwe119_test[i] = None
    polycoder4vdcwe_base_cwe119_train[i] = None
    polycoder4vdcwe_base_cwe119_test[i] = None
    polycoder4vdcwe_large_cwe119_train[i] = None
    polycoder4vdcwe_large_cwe119_test[i] = None

# %%
codebert4vdcwe_small_cwe399_train = {}
codebert4vdcwe_small_cwe399_test = {}
codebert4vdcwe_base_cwe399_train = {}
codebert4vdcwe_base_cwe399_test = {}
codegen4vdcwe_small_cwe399_train = {}
codegen4vdcwe_small_cwe399_test = {}
codegen4vdcwe_base_cwe399_train = {}
codegen4vdcwe_base_cwe399_test = {}
codet54vdcwe_small_cwe399_train = {}
codet54vdcwe_small_cwe399_test = {}
codet54vdcwe_base_cwe399_train = {}
codet54vdcwe_base_cwe399_test = {}
codet54vdcwe_large_cwe399_train = {}
codet54vdcwe_large_cwe399_test = {}
polycoder4vdcwe_small_cwe399_train = {}
polycoder4vdcwe_small_cwe399_test = {}
polycoder4vdcwe_base_cwe399_train = {}
polycoder4vdcwe_base_cwe399_test = {}
polycoder4vdcwe_large_cwe399_train = {}
polycoder4vdcwe_large_cwe399_test = {}

codebert4vdcwe_small_cwe399_train_features = {}
codebert4vdcwe_small_cwe399_test_features = {}
codebert4vdcwe_base_cwe399_train_features = {}
codebert4vdcwe_base_cwe399_test_features = {}
codegen4vdcwe_small_cwe399_train_features = {}
codegen4vdcwe_small_cwe399_test_features = {}
codegen4vdcwe_base_cwe399_train_features = {}
codegen4vdcwe_base_cwe399_test_features = {}
codet54vdcwe_small_cwe399_train_features = {}
codet54vdcwe_small_cwe399_test_features = {}
codet54vdcwe_base_cwe399_train_features = {}
codet54vdcwe_base_cwe399_test_features = {}
codet54vdcwe_large_cwe399_train_features = {}
codet54vdcwe_large_cwe399_test_features = {}
polycoder4vdcwe_small_cwe399_train_features = {}
polycoder4vdcwe_small_cwe399_test_features = {}
polycoder4vdcwe_base_cwe399_train_features = {}
polycoder4vdcwe_base_cwe399_test_features = {}
polycoder4vdcwe_large_cwe399_train_features = {}
polycoder4vdcwe_large_cwe399_test_features = {}


for i in range(200):  
    codebert4vdcwe_small_cwe399_train[i] = np.load(codebert4vdcwe_small+trained_cwe399_path+'cwe399_train{}'.format(i)+'-data.npy')
    codebert4vdcwe_small_cwe399_test[i] = np.load(codebert4vdcwe_small+trained_cwe399_path+'cwe399_test{}'.format(i)+'-data.npy')
    print(np.shape(codebert4vdcwe_small_cwe399_train[i]))  
    print(np.shape(codebert4vdcwe_small_cwe399_test[i]))
    
    codebert4vdcwe_small_cwe399_train_features[i] = [np.linalg.norm(codebert4vdcwe_small_cwe399_train[i], ord='fro'), 
                                                       np.linalg.norm(codebert4vdcwe_small_cwe399_train[i], ord='nuc'),
                                                       np.count_nonzero(codebert4vdcwe_small_cwe399_train[i]), 
                                                       np.linalg.norm(codebert4vdcwe_small_cwe399_train[i], ord=1), 
                                                       np.mean(codebert4vdcwe_small_cwe399_train[i]),
                                                       np.median(codebert4vdcwe_small_cwe399_train[i]),
                                                       np.std(codebert4vdcwe_small_cwe399_train[i]), 
                                                       np.var(codebert4vdcwe_small_cwe399_train[i]), 
                                                       matrix_skewness(codebert4vdcwe_small_cwe399_train[i]),
                                                       matrix_kurtosis(codebert4vdcwe_small_cwe399_train[i]), 
                                                       matrix_entropy(codebert4vdcwe_small_cwe399_train[i]), 
                                                       matrix_range(codebert4vdcwe_small_cwe399_train[i])
                                                       ]
    
    codebert4vdcwe_small_cwe399_test_features[i] = [np.linalg.norm(codebert4vdcwe_small_cwe399_test[i], ord='fro'), 
                                                       np.linalg.norm(codebert4vdcwe_small_cwe399_test[i], ord='nuc'),
                                                       np.count_nonzero(codebert4vdcwe_small_cwe399_test[i]), 
                                                       np.linalg.norm(codebert4vdcwe_small_cwe399_test[i], ord=1), 
                                                       np.mean(codebert4vdcwe_small_cwe399_test[i]),
                                                       np.median(codebert4vdcwe_small_cwe399_test[i]),
                                                       np.std(codebert4vdcwe_small_cwe399_test[i]), 
                                                       np.var(codebert4vdcwe_small_cwe399_test[i]), 
                                                       matrix_skewness(codebert4vdcwe_small_cwe399_test[i]),
                                                       matrix_kurtosis(codebert4vdcwe_small_cwe399_test[i]), 
                                                       matrix_entropy(codebert4vdcwe_small_cwe399_test[i]), 
                                                       matrix_range(codebert4vdcwe_small_cwe399_test[i])
                                                       ]    

    codebert4vdcwe_base_cwe399_train[i] = np.load(codebert4vdcwe_base+trained_cwe399_path+'cwe399_train{}'.format(i)+'-data.npy')
    codebert4vdcwe_base_cwe399_test[i] = np.load(codebert4vdcwe_base+trained_cwe399_path+'cwe399_test{}'.format(i)+'-data.npy')
    codebert4vdcwe_base_cwe399_train_features[i] = [np.linalg.norm(codebert4vdcwe_base_cwe399_train[i], ord='fro'), 
                                                       np.linalg.norm(codebert4vdcwe_base_cwe399_train[i], ord='nuc'),
                                                       np.count_nonzero(codebert4vdcwe_base_cwe399_train[i]), 
                                                       np.linalg.norm(codebert4vdcwe_base_cwe399_train[i], ord=1), 
                                                       np.mean(codebert4vdcwe_base_cwe399_train[i]),
                                                       np.median(codebert4vdcwe_base_cwe399_train[i]),
                                                       np.std(codebert4vdcwe_base_cwe399_train[i]), 
                                                       np.var(codebert4vdcwe_base_cwe399_train[i]), 
                                                       matrix_skewness(codebert4vdcwe_base_cwe399_train[i]),
                                                       matrix_kurtosis(codebert4vdcwe_base_cwe399_train[i]), 
                                                       matrix_entropy(codebert4vdcwe_base_cwe399_train[i]), 
                                                       matrix_range(codebert4vdcwe_base_cwe399_train[i])
                                                       ]
    
    codebert4vdcwe_base_cwe399_test_features[i] = [np.linalg.norm(codebert4vdcwe_base_cwe399_test[i], ord='fro'), 
                                                       np.linalg.norm(codebert4vdcwe_base_cwe399_test[i], ord='nuc'),
                                                       np.count_nonzero(codebert4vdcwe_base_cwe399_test[i]), 
                                                       np.linalg.norm(codebert4vdcwe_base_cwe399_test[i], ord=1), 
                                                       np.mean(codebert4vdcwe_base_cwe399_test[i]),
                                                       np.median(codebert4vdcwe_base_cwe399_test[i]),
                                                       np.std(codebert4vdcwe_base_cwe399_test[i]), 
                                                       np.var(codebert4vdcwe_base_cwe399_test[i]), 
                                                       matrix_skewness(codebert4vdcwe_base_cwe399_test[i]),
                                                       matrix_kurtosis(codebert4vdcwe_base_cwe399_test[i]), 
                                                       matrix_entropy(codebert4vdcwe_base_cwe399_test[i]), 
                                                       matrix_range(codebert4vdcwe_base_cwe399_test[i])
                                                       ]   
    
    codegen4vdcwe_small_cwe399_train[i] = np.load(codegen4vdcwe_small+trained_cwe399_path+'cwe399_train{}'.format(i)+'-data.npy')
    codegen4vdcwe_small_cwe399_test[i] = np.load(codegen4vdcwe_small+trained_cwe399_path+'cwe399_test{}'.format(i)+'-data.npy')
    codegen4vdcwe_small_cwe399_train_features[i] = [np.linalg.norm(codegen4vdcwe_small_cwe399_train[i], ord='fro'), 
                                                       np.linalg.norm(codegen4vdcwe_small_cwe399_train[i], ord='nuc'),
                                                       np.count_nonzero(codegen4vdcwe_small_cwe399_train[i]), 
                                                       np.linalg.norm(codegen4vdcwe_small_cwe399_train[i], ord=1), 
                                                       np.mean(codegen4vdcwe_small_cwe399_train[i]),
                                                       np.median(codegen4vdcwe_small_cwe399_train[i]),
                                                       np.std(codegen4vdcwe_small_cwe399_train[i]), 
                                                       np.var(codegen4vdcwe_small_cwe399_train[i]), 
                                                       matrix_skewness(codegen4vdcwe_small_cwe399_train[i]),
                                                       matrix_kurtosis(codegen4vdcwe_small_cwe399_train[i]), 
                                                       matrix_entropy(codegen4vdcwe_small_cwe399_train[i]), 
                                                       matrix_range(codegen4vdcwe_small_cwe399_train[i])
                                                       ]
    
    codegen4vdcwe_small_cwe399_test_features[i] = [np.linalg.norm(codegen4vdcwe_small_cwe399_test[i], ord='fro'), 
                                                       np.linalg.norm(codegen4vdcwe_small_cwe399_test[i], ord='nuc'),
                                                       np.count_nonzero(codegen4vdcwe_small_cwe399_test[i]), 
                                                       np.linalg.norm(codegen4vdcwe_small_cwe399_test[i], ord=1), 
                                                       np.mean(codegen4vdcwe_small_cwe399_test[i]),
                                                       np.median(codegen4vdcwe_small_cwe399_test[i]),
                                                       np.std(codegen4vdcwe_small_cwe399_test[i]), 
                                                       np.var(codegen4vdcwe_small_cwe399_test[i]), 
                                                       matrix_skewness(codegen4vdcwe_small_cwe399_test[i]),
                                                       matrix_kurtosis(codegen4vdcwe_small_cwe399_test[i]), 
                                                       matrix_entropy(codegen4vdcwe_small_cwe399_test[i]), 
                                                       matrix_range(codegen4vdcwe_small_cwe399_test[i])
                                                       ]         
    
    
    codegen4vdcwe_base_cwe399_train[i] = np.load(codegen4vdcwe_base+trained_cwe399_path+'cwe399_train{}'.format(i)+'-data.npy')
    codegen4vdcwe_base_cwe399_test[i] = np.load(codegen4vdcwe_base+trained_cwe399_path+'cwe399_test{}'.format(i)+'-data.npy')
    codegen4vdcwe_base_cwe399_train_features[i] = [np.linalg.norm(codegen4vdcwe_base_cwe399_train[i], ord='fro'), 
                                                       np.linalg.norm(codegen4vdcwe_base_cwe399_train[i], ord='nuc'),
                                                       np.count_nonzero(codegen4vdcwe_base_cwe399_train[i]), 
                                                       np.linalg.norm(codegen4vdcwe_base_cwe399_train[i], ord=1), 
                                                       np.mean(codegen4vdcwe_base_cwe399_train[i]),
                                                       np.median(codegen4vdcwe_base_cwe399_train[i]),
                                                       np.std(codegen4vdcwe_base_cwe399_train[i]), 
                                                       np.var(codegen4vdcwe_base_cwe399_train[i]), 
                                                       matrix_skewness(codegen4vdcwe_base_cwe399_train[i]),
                                                       matrix_kurtosis(codegen4vdcwe_base_cwe399_train[i]), 
                                                       matrix_entropy(codegen4vdcwe_base_cwe399_train[i]), 
                                                       matrix_range(codegen4vdcwe_base_cwe399_train[i])
                                                       ]
    
    codegen4vdcwe_base_cwe399_test_features[i] = [np.linalg.norm(codegen4vdcwe_base_cwe399_test[i], ord='fro'), 
                                                       np.linalg.norm(codegen4vdcwe_base_cwe399_test[i], ord='nuc'),
                                                       np.count_nonzero(codegen4vdcwe_base_cwe399_test[i]), 
                                                       np.linalg.norm(codegen4vdcwe_base_cwe399_test[i], ord=1), 
                                                       np.mean(codegen4vdcwe_base_cwe399_test[i]),
                                                       np.median(codegen4vdcwe_base_cwe399_test[i]),
                                                       np.std(codegen4vdcwe_base_cwe399_test[i]), 
                                                       np.var(codegen4vdcwe_base_cwe399_test[i]), 
                                                       matrix_skewness(codegen4vdcwe_base_cwe399_test[i]),
                                                       matrix_kurtosis(codegen4vdcwe_base_cwe399_test[i]), 
                                                       matrix_entropy(codegen4vdcwe_base_cwe399_test[i]), 
                                                       matrix_range(codegen4vdcwe_base_cwe399_test[i])
                                                       ] 
    
    codet54vdcwe_small_cwe399_train[i] = np.load(codet54vdcwe_small+trained_cwe399_path+'cwe399_train{}'.format(i)+'-data.npy')
    codet54vdcwe_small_cwe399_test[i] = np.load(codet54vdcwe_small+trained_cwe399_path+'cwe399_test{}'.format(i)+'-data.npy')
    codet54vdcwe_small_cwe399_train_features[i] = [np.linalg.norm(codet54vdcwe_small_cwe399_train[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_small_cwe399_train[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_small_cwe399_train[i]), 
                                                       np.linalg.norm(codet54vdcwe_small_cwe399_train[i], ord=1), 
                                                       np.mean(codet54vdcwe_small_cwe399_train[i]),
                                                       np.median(codet54vdcwe_small_cwe399_train[i]),
                                                       np.std(codet54vdcwe_small_cwe399_train[i]), 
                                                       np.var(codet54vdcwe_small_cwe399_train[i]), 
                                                       matrix_skewness(codet54vdcwe_small_cwe399_train[i]),
                                                       matrix_kurtosis(codet54vdcwe_small_cwe399_train[i]), 
                                                       matrix_entropy(codet54vdcwe_small_cwe399_train[i]), 
                                                       matrix_range(codet54vdcwe_small_cwe399_train[i])
                                                       ]
    
    
    
    codet54vdcwe_small_cwe399_test_features[i] = [np.linalg.norm(codet54vdcwe_small_cwe399_test[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_small_cwe399_test[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_small_cwe399_test[i]), 
                                                       np.linalg.norm(codet54vdcwe_small_cwe399_test[i], ord=1), 
                                                       np.mean(codet54vdcwe_small_cwe399_test[i]),
                                                       np.median(codet54vdcwe_small_cwe399_test[i]),
                                                       np.std(codet54vdcwe_small_cwe399_test[i]), 
                                                       np.var(codet54vdcwe_small_cwe399_test[i]), 
                                                       matrix_skewness(codet54vdcwe_small_cwe399_test[i]),
                                                       matrix_kurtosis(codet54vdcwe_small_cwe399_test[i]), 
                                                       matrix_entropy(codet54vdcwe_small_cwe399_test[i]), 
                                                       matrix_range(codet54vdcwe_small_cwe399_test[i])
                                                       ]         
    
    
    
    codet54vdcwe_base_cwe399_train[i] = np.load(codet54vdcwe_base+trained_cwe399_path+'cwe399_train{}'.format(i)+'-data.npy')
    codet54vdcwe_base_cwe399_test[i] = np.load(codet54vdcwe_base+trained_cwe399_path+'cwe399_test{}'.format(i)+'-data.npy')
    codet54vdcwe_base_cwe399_train_features[i] = [np.linalg.norm(codet54vdcwe_base_cwe399_train[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_base_cwe399_train[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_base_cwe399_train[i]), 
                                                       np.linalg.norm(codet54vdcwe_base_cwe399_train[i], ord=1), 
                                                       np.mean(codet54vdcwe_base_cwe399_train[i]),
                                                       np.median(codet54vdcwe_base_cwe399_train[i]),
                                                       np.std(codet54vdcwe_base_cwe399_train[i]), 
                                                       np.var(codet54vdcwe_base_cwe399_train[i]), 
                                                       matrix_skewness(codet54vdcwe_base_cwe399_train[i]),
                                                       matrix_kurtosis(codet54vdcwe_base_cwe399_train[i]), 
                                                       matrix_entropy(codet54vdcwe_base_cwe399_train[i]), 
                                                       matrix_range(codet54vdcwe_base_cwe399_train[i])
                                                       ]
    
    codet54vdcwe_base_cwe399_test_features[i] = [np.linalg.norm(codet54vdcwe_base_cwe399_test[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_base_cwe399_test[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_base_cwe399_test[i]), 
                                                       np.linalg.norm(codet54vdcwe_base_cwe399_test[i], ord=1), 
                                                       np.mean(codet54vdcwe_base_cwe399_test[i]),
                                                       np.median(codet54vdcwe_base_cwe399_test[i]),
                                                       np.std(codet54vdcwe_base_cwe399_test[i]), 
                                                       np.var(codet54vdcwe_base_cwe399_test[i]), 
                                                       matrix_skewness(codet54vdcwe_base_cwe399_test[i]),
                                                       matrix_kurtosis(codet54vdcwe_base_cwe399_test[i]), 
                                                       matrix_entropy(codet54vdcwe_base_cwe399_test[i]), 
                                                       matrix_range(codet54vdcwe_base_cwe399_test[i])
                                                       ]     
    
    codet54vdcwe_large_cwe399_train[i] = np.load(codet54vdcwe_large+trained_cwe399_path+'cwe399_train{}'.format(i)+'-data.npy')
    codet54vdcwe_large_cwe399_test[i] = np.load(codet54vdcwe_large+trained_cwe399_path+'cwe399_test{}'.format(i)+'-data.npy')
    codet54vdcwe_large_cwe399_train_features[i] = [np.linalg.norm(codet54vdcwe_large_cwe399_train[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_large_cwe399_train[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_large_cwe399_train[i]), 
                                                       np.linalg.norm(codet54vdcwe_large_cwe399_train[i], ord=1), 
                                                       np.mean(codet54vdcwe_large_cwe399_train[i]),
                                                       np.median(codet54vdcwe_large_cwe399_train[i]),
                                                       np.std(codet54vdcwe_large_cwe399_train[i]), 
                                                       np.var(codet54vdcwe_large_cwe399_train[i]), 
                                                       matrix_skewness(codet54vdcwe_large_cwe399_train[i]),
                                                       matrix_kurtosis(codet54vdcwe_large_cwe399_train[i]), 
                                                       matrix_entropy(codet54vdcwe_large_cwe399_train[i]), 
                                                       matrix_range(codet54vdcwe_large_cwe399_train[i])
                                                       ]
    
    codet54vdcwe_large_cwe399_test_features[i] = [np.linalg.norm(codet54vdcwe_large_cwe399_test[i], ord='fro'), 
                                                       np.linalg.norm(codet54vdcwe_large_cwe399_test[i], ord='nuc'),
                                                       np.count_nonzero(codet54vdcwe_large_cwe399_test[i]), 
                                                       np.linalg.norm(codet54vdcwe_large_cwe399_test[i], ord=1), 
                                                       np.mean(codet54vdcwe_large_cwe399_test[i]),
                                                       np.median(codet54vdcwe_large_cwe399_test[i]),
                                                       np.std(codet54vdcwe_large_cwe399_test[i]), 
                                                       np.var(codet54vdcwe_large_cwe399_test[i]), 
                                                       matrix_skewness(codet54vdcwe_large_cwe399_test[i]),
                                                       matrix_kurtosis(codet54vdcwe_large_cwe399_test[i]), 
                                                       matrix_entropy(codet54vdcwe_large_cwe399_test[i]), 
                                                       matrix_range(codet54vdcwe_large_cwe399_test[i])
                                                       ]     

    polycoder4vdcwe_small_cwe399_train[i] = np.load(polycoder4vdcwe_small+trained_cwe399_path+'cwe399_train{}'.format(i)+'-data.npy')
    polycoder4vdcwe_small_cwe399_test[i] = np.load(polycoder4vdcwe_small+trained_cwe399_path+'cwe399_test{}'.format(i)+'-data.npy')
    polycoder4vdcwe_small_cwe399_train_features[i] = [np.linalg.norm(polycoder4vdcwe_small_cwe399_train[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_small_cwe399_train[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_small_cwe399_train[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_small_cwe399_train[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_small_cwe399_train[i]),
                                                       np.median(polycoder4vdcwe_small_cwe399_train[i]),
                                                       np.std(polycoder4vdcwe_small_cwe399_train[i]), 
                                                       np.var(polycoder4vdcwe_small_cwe399_train[i]), 
                                                       matrix_skewness(polycoder4vdcwe_small_cwe399_train[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_small_cwe399_train[i]), 
                                                       matrix_entropy(polycoder4vdcwe_small_cwe399_train[i]), 
                                                       matrix_range(polycoder4vdcwe_small_cwe399_train[i])
                                                       ]
    
    polycoder4vdcwe_small_cwe399_test_features[i] = [np.linalg.norm(polycoder4vdcwe_small_cwe399_test[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_small_cwe399_test[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_small_cwe399_test[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_small_cwe399_test[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_small_cwe399_test[i]),
                                                       np.median(polycoder4vdcwe_small_cwe399_test[i]),
                                                       np.std(polycoder4vdcwe_small_cwe399_test[i]), 
                                                       np.var(polycoder4vdcwe_small_cwe399_test[i]), 
                                                       matrix_skewness(polycoder4vdcwe_small_cwe399_test[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_small_cwe399_test[i]), 
                                                       matrix_entropy(polycoder4vdcwe_small_cwe399_test[i]), 
                                                       matrix_range(polycoder4vdcwe_small_cwe399_test[i])
                                                       ]         
    
    polycoder4vdcwe_base_cwe399_train[i] = np.load(polycoder4vdcwe_base+trained_cwe399_path+'cwe399_train{}'.format(i)+'-data.npy')
    polycoder4vdcwe_base_cwe399_test[i] = np.load(polycoder4vdcwe_base+trained_cwe399_path+'cwe399_test{}'.format(i)+'-data.npy')
    polycoder4vdcwe_base_cwe399_train_features[i] = [np.linalg.norm(polycoder4vdcwe_base_cwe399_train[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_base_cwe399_train[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_base_cwe399_train[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_base_cwe399_train[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_base_cwe399_train[i]),
                                                       np.median(polycoder4vdcwe_base_cwe399_train[i]),
                                                       np.std(polycoder4vdcwe_base_cwe399_train[i]), 
                                                       np.var(polycoder4vdcwe_base_cwe399_train[i]), 
                                                       matrix_skewness(polycoder4vdcwe_base_cwe399_train[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_base_cwe399_train[i]), 
                                                       matrix_entropy(polycoder4vdcwe_base_cwe399_train[i]), 
                                                       matrix_range(polycoder4vdcwe_base_cwe399_train[i])
                                                       ]
    
    polycoder4vdcwe_base_cwe399_test_features[i] = [np.linalg.norm(polycoder4vdcwe_base_cwe399_test[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_base_cwe399_test[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_base_cwe399_test[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_base_cwe399_test[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_base_cwe399_test[i]),
                                                       np.median(polycoder4vdcwe_base_cwe399_test[i]),
                                                       np.std(polycoder4vdcwe_base_cwe399_test[i]), 
                                                       np.var(polycoder4vdcwe_base_cwe399_test[i]), 
                                                       matrix_skewness(polycoder4vdcwe_base_cwe399_test[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_base_cwe399_test[i]), 
                                                       matrix_entropy(polycoder4vdcwe_base_cwe399_test[i]), 
                                                       matrix_range(polycoder4vdcwe_base_cwe399_test[i])
                                                       ]     
    
    polycoder4vdcwe_large_cwe399_train[i] = np.load(polycoder4vdcwe_large+trained_cwe399_path+'cwe399_train{}'.format(i)+'-data.npy')
    polycoder4vdcwe_large_cwe399_test[i] = np.load(polycoder4vdcwe_large+trained_cwe399_path+'cwe399_test{}'.format(i)+'-data.npy')
    polycoder4vdcwe_large_cwe399_train_features[i] = [np.linalg.norm(polycoder4vdcwe_large_cwe399_train[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_large_cwe399_train[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_large_cwe399_train[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_large_cwe399_train[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_large_cwe399_train[i]),
                                                       np.median(polycoder4vdcwe_large_cwe399_train[i]),
                                                       np.std(polycoder4vdcwe_large_cwe399_train[i]), 
                                                       np.var(polycoder4vdcwe_large_cwe399_train[i]), 
                                                       matrix_skewness(polycoder4vdcwe_large_cwe399_train[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_large_cwe399_train[i]), 
                                                       matrix_entropy(polycoder4vdcwe_large_cwe399_train[i]), 
                                                       matrix_range(polycoder4vdcwe_large_cwe399_train[i])
                                                       ]
    
    polycoder4vdcwe_large_cwe399_test_features[i] = [np.linalg.norm(polycoder4vdcwe_large_cwe399_test[i], ord='fro'), 
                                                       np.linalg.norm(polycoder4vdcwe_large_cwe399_test[i], ord='nuc'),
                                                       np.count_nonzero(polycoder4vdcwe_large_cwe399_test[i]), 
                                                       np.linalg.norm(polycoder4vdcwe_large_cwe399_test[i], ord=1), 
                                                       np.mean(polycoder4vdcwe_large_cwe399_test[i]),
                                                       np.median(polycoder4vdcwe_large_cwe399_test[i]),
                                                       np.std(polycoder4vdcwe_large_cwe399_test[i]), 
                                                       np.var(polycoder4vdcwe_large_cwe399_test[i]), 
                                                       matrix_skewness(polycoder4vdcwe_large_cwe399_test[i]),
                                                       matrix_kurtosis(polycoder4vdcwe_large_cwe399_test[i]), 
                                                       matrix_entropy(polycoder4vdcwe_large_cwe399_test[i]), 
                                                       matrix_range(polycoder4vdcwe_large_cwe399_test[i])
                                                       ]
    
    codebert4vdcwe_small_cwe399_train[i] = None
    codebert4vdcwe_small_cwe399_test[i] = None
    codebert4vdcwe_base_cwe399_train[i] = None
    codebert4vdcwe_base_cwe399_test[i] = None
    codegen4vdcwe_small_cwe399_train[i] = None
    codegen4vdcwe_small_cwe399_test[i] = None
    codegen4vdcwe_base_cwe399_train[i] = None
    codegen4vdcwe_base_cwe399_test[i] = None
    codet54vdcwe_small_cwe399_train[i] = None
    codet54vdcwe_small_cwe399_test[i] = None
    codet54vdcwe_base_cwe399_train[i] = None
    codet54vdcwe_base_cwe399_test[i] = None
    codet54vdcwe_large_cwe399_train[i] = None
    codet54vdcwe_large_cwe399_test[i] = None
    polycoder4vdcwe_small_cwe399_train[i] = None
    polycoder4vdcwe_small_cwe399_test[i] = None
    polycoder4vdcwe_base_cwe399_train[i] = None
    polycoder4vdcwe_base_cwe399_test[i] = None
    polycoder4vdcwe_large_cwe399_train[i] = None
    polycoder4vdcwe_large_cwe399_test[i] = None

# %%
print(codebert4vdcwe_small_cwe399_test_features[10])

# %%
df_codebert4vdcwe_small_codexglue_train = pd.DataFrame.from_dict(codebert4vdcwe_small_codexglue_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codebert4vdcwe_small_codexglue_test = pd.DataFrame.from_dict(codebert4vdcwe_small_codexglue_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codebert4vdcwe_base_codexglue_train = pd.DataFrame.from_dict(codebert4vdcwe_base_codexglue_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codebert4vdcwe_base_codexglue_test = pd.DataFrame.from_dict(codebert4vdcwe_base_codexglue_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codegen4vdcwe_small_codexglue_train = pd.DataFrame.from_dict(codegen4vdcwe_small_codexglue_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codegen4vdcwe_small_codexglue_test = pd.DataFrame.from_dict(codegen4vdcwe_small_codexglue_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codegen4vdcwe_base_codexglue_train = pd.DataFrame.from_dict(codegen4vdcwe_base_codexglue_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codegen4vdcwe_base_codexglue_test = pd.DataFrame.from_dict(codegen4vdcwe_base_codexglue_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_small_codexglue_train = pd.DataFrame.from_dict(codet54vdcwe_small_codexglue_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_small_codexglue_test = pd.DataFrame.from_dict(codet54vdcwe_small_codexglue_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_base_codexglue_train = pd.DataFrame.from_dict(codet54vdcwe_base_codexglue_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_base_codexglue_test = pd.DataFrame.from_dict(codet54vdcwe_base_codexglue_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_large_codexglue_train = pd.DataFrame.from_dict(codet54vdcwe_large_codexglue_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_large_codexglue_test = pd.DataFrame.from_dict(codet54vdcwe_large_codexglue_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_small_codexglue_train = pd.DataFrame.from_dict(polycoder4vdcwe_small_codexglue_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_small_codexglue_test = pd.DataFrame.from_dict(polycoder4vdcwe_small_codexglue_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_base_codexglue_train = pd.DataFrame.from_dict(polycoder4vdcwe_base_codexglue_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_base_codexglue_test = pd.DataFrame.from_dict(polycoder4vdcwe_base_codexglue_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_large_codexglue_train = pd.DataFrame.from_dict(polycoder4vdcwe_large_codexglue_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_large_codexglue_test = pd.DataFrame.from_dict(polycoder4vdcwe_large_codexglue_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])

df_codebert4vdcwe_small_reveal_train = pd.DataFrame.from_dict(codebert4vdcwe_small_reveal_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codebert4vdcwe_small_reveal_test = pd.DataFrame.from_dict(codebert4vdcwe_small_reveal_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codebert4vdcwe_base_reveal_train = pd.DataFrame.from_dict(codebert4vdcwe_base_reveal_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codebert4vdcwe_base_reveal_test = pd.DataFrame.from_dict(codebert4vdcwe_base_reveal_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codegen4vdcwe_small_reveal_train = pd.DataFrame.from_dict(codegen4vdcwe_small_reveal_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codegen4vdcwe_small_reveal_test = pd.DataFrame.from_dict(codegen4vdcwe_small_reveal_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codegen4vdcwe_base_reveal_train = pd.DataFrame.from_dict(codegen4vdcwe_base_reveal_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codegen4vdcwe_base_reveal_test = pd.DataFrame.from_dict(codegen4vdcwe_base_reveal_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_small_reveal_train = pd.DataFrame.from_dict(codet54vdcwe_small_reveal_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_small_reveal_test = pd.DataFrame.from_dict(codet54vdcwe_small_reveal_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_base_reveal_train = pd.DataFrame.from_dict(codet54vdcwe_base_reveal_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_base_reveal_test = pd.DataFrame.from_dict(codet54vdcwe_base_reveal_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_large_reveal_train = pd.DataFrame.from_dict(codet54vdcwe_large_reveal_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_large_reveal_test = pd.DataFrame.from_dict(codet54vdcwe_large_reveal_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_small_reveal_train = pd.DataFrame.from_dict(polycoder4vdcwe_small_reveal_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_small_reveal_test = pd.DataFrame.from_dict(polycoder4vdcwe_small_reveal_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_base_reveal_train = pd.DataFrame.from_dict(polycoder4vdcwe_base_reveal_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_base_reveal_test = pd.DataFrame.from_dict(polycoder4vdcwe_base_reveal_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_large_reveal_train = pd.DataFrame.from_dict(polycoder4vdcwe_large_reveal_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_large_reveal_test = pd.DataFrame.from_dict(polycoder4vdcwe_large_reveal_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])

df_codebert4vdcwe_small_cwe119_train = pd.DataFrame.from_dict(codebert4vdcwe_small_cwe119_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codebert4vdcwe_small_cwe119_test = pd.DataFrame.from_dict(codebert4vdcwe_small_cwe119_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codebert4vdcwe_base_cwe119_train = pd.DataFrame.from_dict(codebert4vdcwe_base_cwe119_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codebert4vdcwe_base_cwe119_test = pd.DataFrame.from_dict(codebert4vdcwe_base_cwe119_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codegen4vdcwe_small_cwe119_train = pd.DataFrame.from_dict(codegen4vdcwe_small_cwe119_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codegen4vdcwe_small_cwe119_test = pd.DataFrame.from_dict(codegen4vdcwe_small_cwe119_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codegen4vdcwe_base_cwe119_train = pd.DataFrame.from_dict(codegen4vdcwe_base_cwe119_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codegen4vdcwe_base_cwe119_test = pd.DataFrame.from_dict(codegen4vdcwe_base_cwe119_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_small_cwe119_train = pd.DataFrame.from_dict(codet54vdcwe_small_cwe119_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_small_cwe119_test = pd.DataFrame.from_dict(codet54vdcwe_small_cwe119_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_base_cwe119_train = pd.DataFrame.from_dict(codet54vdcwe_base_cwe119_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_base_cwe119_test = pd.DataFrame.from_dict(codet54vdcwe_base_cwe119_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_large_cwe119_train = pd.DataFrame.from_dict(codet54vdcwe_large_cwe119_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_large_cwe119_test = pd.DataFrame.from_dict(codet54vdcwe_large_cwe119_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_small_cwe119_train = pd.DataFrame.from_dict(polycoder4vdcwe_small_cwe119_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_small_cwe119_test = pd.DataFrame.from_dict(polycoder4vdcwe_small_cwe119_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_base_cwe119_train = pd.DataFrame.from_dict(polycoder4vdcwe_base_cwe119_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_base_cwe119_test = pd.DataFrame.from_dict(polycoder4vdcwe_base_cwe119_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_large_cwe119_train = pd.DataFrame.from_dict(polycoder4vdcwe_large_cwe119_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_large_cwe119_test = pd.DataFrame.from_dict(polycoder4vdcwe_large_cwe119_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])

df_codebert4vdcwe_small_cwe399_train = pd.DataFrame.from_dict(codebert4vdcwe_small_cwe399_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codebert4vdcwe_small_cwe399_test = pd.DataFrame.from_dict(codebert4vdcwe_small_cwe399_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codebert4vdcwe_base_cwe399_train = pd.DataFrame.from_dict(codebert4vdcwe_base_cwe399_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codebert4vdcwe_base_cwe399_test = pd.DataFrame.from_dict(codebert4vdcwe_base_cwe399_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codegen4vdcwe_small_cwe399_train = pd.DataFrame.from_dict(codegen4vdcwe_small_cwe399_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codegen4vdcwe_small_cwe399_test = pd.DataFrame.from_dict(codegen4vdcwe_small_cwe399_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codegen4vdcwe_base_cwe399_train = pd.DataFrame.from_dict(codegen4vdcwe_base_cwe399_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codegen4vdcwe_base_cwe399_test = pd.DataFrame.from_dict(codegen4vdcwe_base_cwe399_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_small_cwe399_train = pd.DataFrame.from_dict(codet54vdcwe_small_cwe399_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_small_cwe399_test = pd.DataFrame.from_dict(codet54vdcwe_small_cwe399_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_base_cwe399_train = pd.DataFrame.from_dict(codet54vdcwe_base_cwe399_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_base_cwe399_test = pd.DataFrame.from_dict(codet54vdcwe_base_cwe399_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_large_cwe399_train = pd.DataFrame.from_dict(codet54vdcwe_large_cwe399_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_codet54vdcwe_large_cwe399_test = pd.DataFrame.from_dict(codet54vdcwe_large_cwe399_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_small_cwe399_train = pd.DataFrame.from_dict(polycoder4vdcwe_small_cwe399_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_small_cwe399_test = pd.DataFrame.from_dict(polycoder4vdcwe_small_cwe399_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_base_cwe399_train = pd.DataFrame.from_dict(polycoder4vdcwe_base_cwe399_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_base_cwe399_test = pd.DataFrame.from_dict(polycoder4vdcwe_base_cwe399_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_large_cwe399_train = pd.DataFrame.from_dict(polycoder4vdcwe_large_cwe399_train_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])
df_polycoder4vdcwe_large_cwe399_test = pd.DataFrame.from_dict(polycoder4vdcwe_large_cwe399_test_features, orient='index', columns=['L2_norm', 'Nuclear_norm', 'L0_norm', 'L1_norm','Mean','Median','Std','Var','Skewness','Kurtosis','Entropy','Range',])

# %%
print(df_codebert4vdcwe_small_cwe399_train)

# %%
df_codebert4vdcwe_small_train = pd.concat([df_codebert4vdcwe_small_codexglue_train, df_codebert4vdcwe_small_reveal_train, df_codebert4vdcwe_small_cwe119_train, df_codebert4vdcwe_small_cwe399_train], ignore_index=True)
df_codebert4vdcwe_small_test = pd.concat([df_codebert4vdcwe_small_codexglue_test, df_codebert4vdcwe_small_reveal_test, df_codebert4vdcwe_small_cwe119_test, df_codebert4vdcwe_small_cwe399_test], ignore_index=True)
df_codebert4vdcwe_base_train = pd.concat([df_codebert4vdcwe_base_codexglue_train, df_codebert4vdcwe_base_reveal_train, df_codebert4vdcwe_base_cwe119_train, df_codebert4vdcwe_base_cwe399_train], ignore_index=True)
df_codebert4vdcwe_base_test = pd.concat([df_codebert4vdcwe_base_codexglue_test, df_codebert4vdcwe_base_reveal_test, df_codebert4vdcwe_base_cwe119_test, df_codebert4vdcwe_base_cwe399_test], ignore_index=True)
df_codegen4vdcwe_small_train = pd.concat([df_codegen4vdcwe_small_codexglue_train, df_codegen4vdcwe_small_reveal_train, df_codegen4vdcwe_small_cwe119_train, df_codegen4vdcwe_small_cwe399_train], ignore_index=True)
df_codegen4vdcwe_small_test = pd.concat([df_codegen4vdcwe_small_codexglue_test, df_codegen4vdcwe_small_reveal_test, df_codegen4vdcwe_small_cwe119_test, df_codegen4vdcwe_small_cwe399_test], ignore_index=True)
df_codegen4vdcwe_base_train = pd.concat([df_codegen4vdcwe_base_codexglue_train, df_codegen4vdcwe_base_reveal_train, df_codegen4vdcwe_base_cwe119_train, df_codegen4vdcwe_base_cwe399_train], ignore_index=True)
df_codegen4vdcwe_base_test = pd.concat([df_codegen4vdcwe_base_codexglue_test, df_codegen4vdcwe_base_reveal_test, df_codegen4vdcwe_base_cwe119_test, df_codegen4vdcwe_base_cwe399_test], ignore_index=True)
df_codet54vdcwe_small_train = pd.concat([df_codet54vdcwe_small_codexglue_train, df_codet54vdcwe_small_reveal_train, df_codet54vdcwe_small_cwe119_train, df_codet54vdcwe_small_cwe399_train], ignore_index=True)
df_codet54vdcwe_small_test = pd.concat([df_codet54vdcwe_small_codexglue_test, df_codet54vdcwe_small_reveal_test, df_codet54vdcwe_small_cwe119_test, df_codet54vdcwe_small_cwe399_test], ignore_index=True)
df_codet54vdcwe_base_train = pd.concat([df_codet54vdcwe_base_codexglue_train, df_codet54vdcwe_base_reveal_train, df_codet54vdcwe_base_cwe119_train, df_codet54vdcwe_base_cwe399_train], ignore_index=True)
df_codet54vdcwe_base_test = pd.concat([df_codet54vdcwe_base_codexglue_test, df_codet54vdcwe_base_reveal_test, df_codet54vdcwe_base_cwe119_test, df_codet54vdcwe_base_cwe399_test], ignore_index=True)
df_codet54vdcwe_large_train = pd.concat([df_codet54vdcwe_large_codexglue_train, df_codet54vdcwe_large_reveal_train, df_codet54vdcwe_large_cwe119_train, df_codet54vdcwe_large_cwe399_train], ignore_index=True)
df_codet54vdcwe_large_test = pd.concat([df_codet54vdcwe_large_codexglue_test, df_codet54vdcwe_large_reveal_test, df_codet54vdcwe_large_cwe119_test, df_codet54vdcwe_large_cwe399_test], ignore_index=True)
df_polycoder4vdcwe_small_train = pd.concat([df_polycoder4vdcwe_small_codexglue_train, df_polycoder4vdcwe_small_reveal_train, df_polycoder4vdcwe_small_cwe119_train, df_polycoder4vdcwe_small_cwe399_train], ignore_index=True)
df_polycoder4vdcwe_small_test = pd.concat([df_polycoder4vdcwe_small_codexglue_test, df_polycoder4vdcwe_small_reveal_test, df_polycoder4vdcwe_small_cwe119_test, df_polycoder4vdcwe_small_cwe399_test], ignore_index=True)
df_polycoder4vdcwe_base_train = pd.concat([df_polycoder4vdcwe_base_codexglue_train, df_polycoder4vdcwe_base_reveal_train, df_polycoder4vdcwe_base_cwe119_train, df_polycoder4vdcwe_base_cwe399_train], ignore_index=True)
df_polycoder4vdcwe_base_test = pd.concat([df_polycoder4vdcwe_base_codexglue_test, df_polycoder4vdcwe_base_reveal_test, df_polycoder4vdcwe_base_cwe119_test, df_polycoder4vdcwe_base_cwe399_test], ignore_index=True)
df_polycoder4vdcwe_large_train = pd.concat([df_polycoder4vdcwe_large_codexglue_train, df_polycoder4vdcwe_large_reveal_train, df_polycoder4vdcwe_large_cwe119_train, df_polycoder4vdcwe_large_cwe399_train], ignore_index=True)
df_polycoder4vdcwe_large_test = pd.concat([df_polycoder4vdcwe_large_codexglue_test, df_polycoder4vdcwe_large_reveal_test, df_polycoder4vdcwe_large_cwe119_test, df_polycoder4vdcwe_large_cwe399_test], ignore_index=True)




print(df_codebert4vdcwe_small_train[0:200])
print(df_codebert4vdcwe_small_train[200:400])
print(df_codebert4vdcwe_small_train[400:600])
print(df_codebert4vdcwe_small_train[600:800])

# %%
df_codebert4vdcwe_small_train.to_csv('df_codebert4vdcwe_small_train_feature.csv', index=False) 
df_codebert4vdcwe_small_test.to_csv('df_codebert4vdcwe_small_test_feature.csv', index=False) 
df_codebert4vdcwe_base_train.to_csv('df_codebert4vdcwe_base_train_feature.csv', index=False)  
df_codebert4vdcwe_base_test.to_csv('df_codebert4vdcwe_base_test_feature.csv', index=False)  
df_codegen4vdcwe_small_train.to_csv('df_codegen4vdcwe_small_train_feature.csv', index=False)  
df_codegen4vdcwe_small_test.to_csv('df_codegen4vdcwe_small_test_feature.csv', index=False) 
df_codegen4vdcwe_base_train.to_csv('df_codegen4vdcwe_base_train_feature.csv', index=False)  
df_codegen4vdcwe_base_test.to_csv('df_codegen4vdcwe_base_test_feature.csv', index=False)  
df_codet54vdcwe_small_train.to_csv('df_codet54vdcwe_small_train_feature.csv', index=False)  
df_codet54vdcwe_small_test.to_csv('df_codet54vdcwe_small_test_feature.csv', index=False) 
df_codet54vdcwe_base_train.to_csv('df_codet54vdcwe_base_train_feature.csv', index=False)  
df_codet54vdcwe_base_test.to_csv('df_codet54vdcwe_base_test_feature.csv', index=False)  
df_codet54vdcwe_large_train.to_csv('df_codet54vdcwe_large_train_feature.csv', index=False) 
df_codet54vdcwe_large_test.to_csv('df_codet54vdcwe_large_test_feature.csv', index=False)  
df_polycoder4vdcwe_small_train.to_csv('df_polycoder4vdcwe_small_train_feature.csv', index=False)  
df_polycoder4vdcwe_small_test.to_csv('df_polycoder4vdcwe_small_test_feature.csv', index=False)  
df_polycoder4vdcwe_base_train.to_csv('df_polycoder4vdcwe_base_train_feature.csv', index=False)  
df_polycoder4vdcwe_base_test.to_csv('df_polycoder4vdcwe_base_test_feature.csv', index=False) 
df_polycoder4vdcwe_large_train.to_csv('df_polycoder4vdcwe_large_train_feature.csv', index=False)  
df_polycoder4vdcwe_large_test.to_csv('df_polycoder4vdcwe_large_test_feature.csv', index=False)
